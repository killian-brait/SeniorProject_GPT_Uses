# %% [markdown]
# # Senior Project - GPT 3.5 Personalization
#
# This notebook explores applications of OpenAI's GPT (generative-pre-trained) NLP model gpt-3.5-turbo in providing subjective, personalized, and context-aware responses to user input. The model is not fine-tuned and is simply the available model trained by OpenAI.

# %% [markdown]
# ---
# ### Imports, Setup, Helper Functions

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
import json
import pickle
import sys

load_dotenv(".env")
client = OpenAI(
    api_key=os.environ["OPENAI_API_KEY"],
) 

save_folder = "./data/"

# %%
## Save Data (Save Money)
def save_data(data_structure, file_name):
    if not file_name.endswith('.pkl'):
        file_name += '.pkl'
    
    with open(save_folder + file_name, 'wb') as file:
        pickle.dump(data_structure, file)

# %%
## Load Data (Save Money)
def load_data(file_name):
    if not file_name.endswith('.pkl'):
        file_name += '.pkl'
    
    with open(save_folder + file_name, 'rb') as file:
        return pickle.load(file)

# %% [markdown]
# #### Cost Helper Functions

# %%
def calculate_usage_cost(model, c_tokens, p_tokens):
    cost = 0
    if model == "gpt-3.5-turbo":
        cost_per1k_prompt_token = 0.001 # 1/10th of a cent
        cost_per1k_completion_token = 0.002 # 1/5th of a cent
    elif model == "gpt-4-turbo":
        cost_per1k_prompt_token = 0.01 # 1 cent
        cost_per1k_completion_token = 0.03 # 3 cents

    cost += cost_per1k_prompt_token * p_tokens / 1000
    cost += cost_per1k_completion_token * c_tokens / 1000
    return cost

def print_cost(cost):
    print(f"Total Cost: ${cost:.8f}")
    if cost > 0:
        print(f"Number of Runs to Reach $1: {1/cost:.0f}")
    print("*"*50)

# %% [markdown]
# #### GPT-3.5-Turbo Test Setup

# %%
# THIS IS A TEST - 
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-3.5-turbo",
)

print(chat_completion.choices[0].message.content)
print_cost(
    calculate_usage_cost(
        "gpt-3.5-turbo",
        chat_completion.usage.completion_tokens,
        chat_completion.usage.prompt_tokens
    )
)
# Out:
# This is a test.
# Total Cost: $0.00002200
# Number of Runs to Reach $1: 45455
# **************************************************

# %% [markdown]
# #### Pretty Print Helper Function
#
# For printing the dictionary of questions + labels + uses + explanations that are generated by gpt.

# %%
# HELPER FUNCTIONS

def pretty_print(data):
    print(json.dumps(data, indent=4, sort_keys=False))

# %% [markdown]
# #### Init Questions List

# %%
import json

question_data_path = './Questions_Text.json'

# Function to load the JSON data into a Python data structure
def load_questions(json_path):
    with open(json_path, 'r', encoding='utf-8') as file:
        questions = json.load(file)
    return questions

# # Function to iterate through each question and retrieve the necessary information
# def process_questions(questions):
#     for question in questions:
#         question_text = question["text"]
#         answer_type = question["answer_type"]
#         # Here you can add the logic to pass the question_text and answer_type into a GPT prompt
#         # For example, you might call your GPT function here
#         # gpt_response = gpt_prompt(question_text, answer_type)
#         # For now, we'll just print them
#         print(f"Question Text: {question_text}\nAnswer Type: {answer_type}\n")

# Load the questions from the JSON file
questions = load_questions(question_data_path)

# # Process each question
# process_questions(questions)

# Note: In your actual implementation, you'd replace the print statement
# with the logic to call your GPT prompt function.

# %% [markdown]
# #### Functions for Adding, Removing, and Clearing Labeled Questions
#
# These represent API CRUD operations in a sense. Illustrating how this demo could easily be turned into a microservice that the main Trees app could call.

# %%
labeled_questions = []

def add_labeled_question(text, a_type, label, label_explain):
    # Only add if text is not already in labeled_questions
    for question in labeled_questions:
        if question["text"] == text:
            print(f"Question already labeled: {text}")
            return
    labeled_questions.append({
        "text": text,
        "answer_type": a_type,
        "label": label,
        "label_explain": label_explain,
        "primary_use": "",
        "secondary_use": "",
        "tertiary_use": "",
        "primary_explain": "",
        "secondary_explain": "",
        "tertiary_explain": "",
    })
    print(f"Added labeled question: {text}")
    print(f"Length of labeled questions: {len(labeled_questions)}")


def clear_labeled_questions():
    labeled_questions.clear()
    print("Cleared labeled questions")

def remove_labeled_question(text):
    for question in labeled_questions:
        if question["text"] == text:
            labeled_questions.remove(question)
            print(f"Removed labeled question: {text}")
            print(f"Length of labeled questions: {len(labeled_questions)}")
            return
    print(f"Could not find labeled question: {text}")

def add_uses_to_labeled_question(text, primary, secondary, tertiary):
    for question in labeled_questions:
        if question["text"] == text:
            question["primary_use"] = primary
            question["secondary_use"] = secondary
            question["tertiary_use"] = tertiary
            print(f"Added uses to labeled question: {text}")
            return
    print(f"Could not find labeled question: {text}")

def add_explain_to_labeled_question(text, primary, secondary, tertiary):
    for question in labeled_questions:
        if question["text"] == text:
            question["primary_explain"] = primary
            question["secondary_explain"] = secondary
            question["tertiary_explain"] = tertiary
            print(f"Added explain to labeled question: {text}")
            return
    print(f"Could not find labeled question: {text}")

# %% [markdown]
# #### "Major Statements" CRUD Functions
#
# These aren't used in this demo, but illustrate how admin users of the Trees app could add, remove, and clear major statements that can be used as context to further specify the GPT response. This could also be a microservice, and this could also be a feature within the mobile app that GPT-savvy user's can pay for to tweak the context that GPT gets when it generates labels, or personalized content recommendations for them. This gives user's power, and is cost effective since the cost to run these models is miniscule and user's would be paying for the frontend that makes these responses clean and useful rather than the backend that generates them with the GPT api for very cheap! (5x markup on cost would still be ~ $0.05 per user request, which seems very reasonable for a personalized response...however frontend costs may necessitate a higher cost in-app)

# %%
# Question major statements

major_statements = []

def add_major_statement(text):
    # Only add if text is not already in major_statements
    for statement in major_statements:
        if statement["text"] == text:
            print(f"Major statement already added: {text}")
            return
    major_statements.append({
        "text": text,
    })
    print(f"Added major statement: {text}")
    print(f"Length of major statements: {len(major_statements)}")

def clear_major_statements():
    major_statements.clear()
    print("Cleared major statements")

def remove_major_statement(text):
    for statement in major_statements:
        if statement["text"] == text:
            major_statements.remove(statement)
            print(f"Removed major statement: {text}")
            print(f"Length of major statements: {len(major_statements)}")
            return
    print(f"Could not find major statement: {text}")

# %% [markdown]
# ---
# ## Question Answering Console "App"
#
# This is a simple console app that allows you to answer all the questions in the list of questions (108 total questions). This allows this notebook demo to use real user answers to predict personality traits, goals, habits, and (hopefully) plan/content recommendations. Additionally, it (maybe, bc this is really out-of-scope) allows for gpt to generate personalized versions of generalized content for a specific user.

# %%
# DONT RUN THIS CELL UNLESS YOU WANT TO CLEAR ALL USER ANSWERS

# data structure to store user's and their answers to questions
user_answers = {} # { "username": { "question" : "answer" } }

# %%
def answer_questions(questions):
    username = input("Enter Username: ")

    if username not in user_answers:
        user_answers[username] = {}
    else:
        print(f"Username already exists: {username}")

    for i, question in enumerate(questions):
        if question["text"] not in user_answers[username]:
            print(f"----- Question #{i+1} -----")
            print(f"{question['text']}")

            answers =[]
                

            if (question["answer_type"] == "A slider displaying text values"):
                if (question["text"] == "How many hours per week do you work?"): # Special slider values, not 11-pt scale
                    answers = ["Some number between 0 and 80"]
                elif (question["text"] == "How many hours per week do you spend on schoolwork?"):
                    pass
                elif (question["text"] == "On average, how many hours do you sleep in each 24-hour period?"):
                    answers = ["A number between 4 and 12 hours with half-hour increments (0.5s) being acceptable"]
                elif (question["text"] == "From which socio-economic group would you consider your family to be?"):
                    answers = ["Low income", "Middle income", "High income"]
                elif (question["text"] == "Are you currently in a relationship?"):
                    answers = ["Yes", "Sort of", "No"]
                elif (question["text"] == "Are you currently in a romantic relationship?"):
                    answers = ["Yes", "Sort of", "No"]
                elif (question["text"] == "Do you have children?"):
                    answers = ["Yes", "Yes but they don't live with me", "No"]
                elif (question["text"] == "Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?"):
                    answers = ["0hrs", "1hr", "2hrs", "3hrs", "4hrs", "5hrs", "6hrs", "7hrs", 
                               "8hrs", "9hrs", "10hrs", "11hrs", "12hrs", "13hrs", "14hrs or more"]
                elif (question["text"] == "How intense are your exercise sessions?"):
                    answers = ["Incredibly intense", "Pretty intense", "Kind of intense", "Comfortable", "Relaxed"]
                elif (question["text"] == "How often do you exercise?"):
                    answers = ["7-10 times per week", "5-6 times per week", "3-4 times per week", "Twice per week", "Once per week", "Never"]
                else: # Regular 11-pt scale slider questions
                    answers = ["5, (YesYesYesYesYes)", "4, (YesYesYesYes)", "3, (YesYesYes)", "2, (YesYes)", "1, (Yes)",
                            "0, (Indifferent)", 
                            "-1, (No)", "-2, (NoNo)", "-3, (NoNoNo)", "-4, (NoNoNoNo)", "-5, (NoNoNoNoNo)"]
            else:    
                if (question["text"] == "Which of these learning preferences work best for you?"):
                    answers = ["Reading/Writing", "Audio", "Video", "Hands-On"]
                elif (question["text"] == "Did either of your parents (including step parents/guardian) complete university?"):
                    answers = ["Both did", "One did", "I don't know", "No"]
                elif (question["text"] == "Are you currently employed?"):
                    answers = ["Full-time", "Part-time", "Unemployed and currently looking for work",
                            "Unemployed and not currently looking for work", "Other", "Prefer not to say"] # Don't have Self-Employed?
                elif (question["text"] == "What is your race?"):
                    answers = ["Asian and South East Asian", "Black or African Canadian", "First Nation, Metis, Inuit or (Indigenous)",
                            "Middle Eastern", "White", "Other", "Prefer not to say"]
                elif (question["text"] == "How do you get to campus?"):
                    answers= ["Living on-campus", "Bike", "Walk", "Drive", "Bus", "Other"]
                elif (question["text"] == "Would you be interested in accessing resources and learning more about any of the following?"):
                    answers = ["Depression", "Anxiety", "OCD", "ADHD", "Eating disorders", "Stress reduction", "Time management", 
                            "None of the above"] # 'None of the above' makes no sense as an answer to this question... 
                                                    # (it's the same as just not answering...)
                elif (question["text"] == "What year of university are you in?"):
                    answers = ["1st", "2nd", "3rd", "4th", "5th or higher", "Graduate program"]
                elif (question["text"] == "What are your living arrangements?"):
                    answers = ["Living at home with family", "Living alone in residence", "Living in residence with roommate(s)",
                            "Living alone off campus", "Living off campus with roommate(s)", "Living off campus with a significant other"]
                elif (question["text"] == "How old are you?"):
                    answers = ["Answer with a number"]
                elif (question["text"] == "What is your gender?"):
                    answers = ["Prefer not to say", "Female", "Male", "Non-binary/non-conforming", "Gender fluid", 
                            "Transgender", "Other"]        
            

            print(f"---> Answer Type: {question['answer_type']}")
            for i, answer in enumerate(answers):
                print(f"{i+1}. {answer}")
            answer = input("Answer (if numbered enter the number of your answer): ")
            # if the answer is a valid number and there is more than one string in the answers list
            if answer.isnumeric() and int(answer) <= len(answers) and len(answers) > 1:
                answer = answers[int(answer)-1]

            print(f"You answered: {answer}")
            validate = input("Is this correct? (y/n): ")
            if validate.lower() == "y":
                # add answer to user_answers
                user_answers[username][question["text"]] = answer
            else:
                continue # continue to the next question if the answer was wrong
            
            print("-"*50)
        else:
            print(f"Question already answered: {question['text']}")

# %%
answer_questions(questions)
# Out:
# Username already exists: kbrait
# ----- Question #1 -----
# I care what people close to me think is best
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 1, (Yes)
# --------------------------------------------------
# Question already answered: I sympathize with others’ feelings.
# Question already answered: I can be pushy.
# Question already answered: I follow a schedule.
# Question already answered: I leave my belongings around.
# Question already answered: I often act on the spur of the moment.
# Question already answered: I am always prepared.
# Question already answered: I often forget to put things back in their proper place.
# ----- Question #9 -----
# I find it difficult to remember appointments or obligations.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: -5, (NoNoNoNoNo)
# --------------------------------------------------
# ----- Question #10 -----
# I make careless mistakes while working on a boring or difficult project.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 2, (YesYes)
# --------------------------------------------------
# Question already answered: I have trouble wrapping up the final details of a project once the challenging parts are done.
# Question already answered: My social life is important to me
# Question already answered: I like to talk with others when I'm trying to understand new things.
# Question already answered: I talk to a lot of different people at social gatherings.
# Question already answered: I like being the center of attention.
# Question already answered: I feel I can be my most authentic self.
# Question already answered: I am relaxed most of the time.
# Question already answered: I get stressed out easily.
# Question already answered: I change my mood a lot.
# Question already answered: I see myself as someone who has high self-esteem.
# Question already answered: I get irritated easily.
# Question already answered: I feel like I am in control of what happens to me.
# Question already answered: I feel like powerful others have a lot of control over how my life will turn out.
# Question already answered: I worry about making mistakes.
# Question already answered: Criticism hurts me.
# Question already answered: I feel worried when somebody is angry.
# Question already answered: I have very few fears compared to my friends.
# ----- Question #28 -----
# In the past two weeks, I have felt nervous, anxious or on edge.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: -2, (NoNo)
# --------------------------------------------------
# Question already answered: In the past two weeks, I have been unable to stop or control worrying.
# Question already answered: In the past two weeks, I have had trouble relaxing.
# Question already answered: In the past two weeks, I have been easily annoyed or irritable.
# Question already answered: I'm generally comfortable taking tests.
# Question already answered: In the past two weeks, I have felt afraid something awful might happen.
# Question already answered: I get upset easily.
# Question already answered: I thrive in diverse environments
# Question already answered: I have a vivid imagination.
# Question already answered: I enjoy thinking about things.
# Question already answered: I believe art is important.
# ----- Question #39 -----
# I like to take things apart to see how they work.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 4, (YesYesYesYes)
# --------------------------------------------------
# ----- Question #40 -----
# I'm always willing to try something new if I think it will be fun.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 5, (YesYesYesYesYes)
# --------------------------------------------------
# Question already answered: It's important that I make my family proud of me.
# Question already answered: I like a challenge.
# Question already answered: I go out of my way to get things I want.
# Question already answered: In the past couple of weeks, I have been fulfilling my potential.
# Question already answered: I am easily bored.
# Question already answered: I can easily connect with family and friends if I want.
# Question already answered: I learn well in a study group.
# Question already answered: I learn well when I'm alone.
# Question already answered: In the past two weeks, I have felt so restless, it is hard to keep still.
# Question already answered: I feel like my basic needs are met.
# Question already answered: I like to read.
# Question already answered: What is your race?
# Question already answered: From which socio-economic group would you consider your family to be?
# ----- Question #54 -----
# What are your living arrangements?
# ---> Answer Type: Multiple choices
# 1. Living at home with family
# 2. Living alone in residence
# 3. Living in residence with roommate(s)
# 4. Living alone off campus
# 5. Living off campus with roommate(s)
# 6. Living off campus with a significant other
# You answered: Living off campus with roommate(s)
# --------------------------------------------------
# Question already answered: Are you currently in a relationship?
# Question already answered: I worry about my finances.
# ----- Question #57 -----
# Did either of your parents (including step parents/guardian) complete university?
# ---> Answer Type: Multiple choices
# 1. Both did
# 2. One did
# 3. I don't know
# 4. No
# You answered: Both did
# --------------------------------------------------
# Question already answered: Are you currently in a romantic relationship?
# Question already answered: Do you have children?
# Question already answered: Faith is important to me.
# Question already answered: I have a safe place to live.
# Question already answered: What is your gender?
# Question already answered: How old are you?
# Question already answered: Are you currently employed?
# Question already answered: How many hours per week do you work?
# ----- Question #66 -----
# Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?
# ---> Answer Type: A slider displaying text values
# 1. 0hrs
# 2. 1hr
# 3. 2hrs
# 4. 3hrs
# 5. 4hrs
# 6. 5hrs
# 7. 6hrs
# 8. 7hrs
# 9. 8hrs
# 10. 9hrs
# 11. 10hrs
# 12. 11hrs
# 13. 12hrs
# 14. 13hrs
# 15. 14hrs or more
# You answered: 2hrs
# --------------------------------------------------
# Question already answered: Which of these learning preferences work best for you?
# Question already answered: Have you had any significant problems with mental health in the past?
# Question already answered: Have you had any significant problems with depression in the past?
# Question already answered: Have you had any significant problems with anxiety in the past?
# Question already answered: If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.
# Question already answered: If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.
# ----- Question #73 -----
# I take steps to work on my mental health regularly.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 0, (Indifferent)
# --------------------------------------------------
# Question already answered: What country were you born in?
# Question already answered: What activities do you do?
# Question already answered: Is there anything else you'd like to tell us that may help us help you?
# Question already answered: I worry about my physical health
# Question already answered: My physical health is out of control
# Question already answered: The people I care about take good care of their physical health.
# Question already answered: Would you say you have a healthy diet?
# ----- Question #81 -----
# How intense are your exercise sessions?
# ---> Answer Type: A slider displaying text values
# 1. Incredibly intense
# 2. Pretty intense
# 3. Kind of intense
# 4. Comfortable
# 5. Relaxed
# You answered: Pretty intense
# --------------------------------------------------
# Question already answered: I have access to healthy food.
# ----- Question #83 -----
# How often do you exercise?
# ---> Answer Type: A slider displaying text values
# 1. 7-10 times per week
# 2. 5-6 times per week
# 3. 3-4 times per week
# 4. Twice per week
# 5. Once per week
# 6. Never
# You answered: 5-6 times per week
# --------------------------------------------------
# Question already answered: On average, how many hours do you sleep in each 24-hour period?
# Question already answered: If you have a physical disability, please select any category(ies) your physical disability falls into.
# ----- Question #86 -----
# I get as much sleep as I need.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 0, (Indifferent)
# --------------------------------------------------
# Question already answered: Is your diet healthy?
# Question already answered: Do you feel confident in your resume?
# Question already answered: Do you feel confident writing a cover letter?
# ----- Question #90 -----
# Do you feel comfortable doing a job interview?
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 3, (YesYesYes)
# --------------------------------------------------
# Question already answered: Do you know what job you should work toward?
# Question already answered: Do you know how to identify an organization that's a good fit for you?
# Question already answered: I know what types of disability accommodations will support me.
# Question already answered: I know when to disclose my disability.
# Question already answered: I know how to create a disability accommodations plan with an employer.
# ----- Question #96 -----
# I feel overwhelmed by my need to find a job.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 1, (Yes)
# --------------------------------------------------
# Question already answered: When I look at a job description, I often feel I'm not qualified.
# ----- Question #98 -----
# I am comfortable and competent using a computer.
# ---> Answer Type: A slider displaying text values
# 1. 5, (YesYesYesYesYes)
# 2. 4, (YesYesYesYes)
# 3. 3, (YesYesYes)
# 4. 2, (YesYes)
# 5. 1, (Yes)
# 6. 0, (Indifferent)
# 7. -1, (No)
# 8. -2, (NoNo)
# 9. -3, (NoNoNo)
# 10. -4, (NoNoNoNo)
# 11. -5, (NoNoNoNoNo)
# You answered: 5, (YesYesYesYesYes)
# --------------------------------------------------
# Question already answered: I am comfortable and competent using apps on smartphones.
# Question already answered: I feel connected to the university
# ----- Question #101 -----
# What year of university are you in?
# ---> Answer Type: Multiple choices
# 1. 1st
# 2. 2nd
# 3. 3rd
# 4. 4th
# 5. 5th or higher
# 6. Graduate program
# You answered: 5th or higher
# --------------------------------------------------
# Question already answered: I am satisfied with my experience at university so far.
# Question already answered: I am satisfied with the support I have been offered by the university.
# Question already answered: How do you get to campus?
# Question already answered: Would you be interested in accessing resources and learning more about any of the following?
# Question already answered: I feel overwhelmed by university life.
# Question already answered: I feel like I belong at university.
# Question already answered: What program are you currently enrolled in?

# %%
print(f"User Answers: {user_answers}")

try:
    save_data(user_answers, "user_answers")
    print("Saved user answers")
except:
    print("Could not save user answers")
    print(f"Error Message: {sys.exc_info()[0]}")
# Out:
# User Answers: {'kbrait': {'I sympathize with others’ feelings.': '3, (YesYesYes)', 'I can be pushy.': '2, (YesYes)', 'I follow a schedule.': '-2, (NoNo)', 'I leave my belongings around.': '4, (YesYesYesYes)', 'I often act on the spur of the moment.': '5, (YesYesYesYesYes)', 'I am always prepared.': '2, (YesYes)', 'I often forget to put things back in their proper place.': '0, (Indifferent)', 'I have trouble wrapping up the final details of a project once the challenging parts are done.': '5, (YesYesYesYesYes)', 'My social life is important to me': '3, (YesYesYes)', "I like to talk with others when I'm trying to understand new things.": '4, (YesYesYesYes)', 'I talk to a lot of different people at social gatherings.': '2, (YesYes)', 'I like being the center of attention.': '2, (YesYes)', 'I feel I can be my most authentic self.': '3, (YesYesYes)', 'I am relaxed most of the time.': '1, (Yes)', 'I get stressed out easily.': '-3, (NoNoNo)', 'I change my mood a lot.': '1, (Yes)', 'I see myself as someone who has high self-esteem.': '4, (YesYesYesYes)', 'I get irritated easily.': '1, (Yes)', 'I feel like I am in control of what happens to me.': '3, (YesYesYes)', 'I feel like powerful others have a lot of control over how my life will turn out.': '-4, (NoNoNoNo)', 'I worry about making mistakes.': '-3, (NoNoNo)', 'Criticism hurts me.': '4, (YesYesYesYes)', 'I feel worried when somebody is angry.': '-5, (NoNoNoNoNo)', 'I have very few fears compared to my friends.': '4, (YesYesYesYes)', 'In the past two weeks, I have been unable to stop or control worrying.': '1, (Yes)', 'In the past two weeks, I have had trouble relaxing.': '1, (Yes)', 'In the past two weeks, I have been easily annoyed or irritable.': '-1, (No)', "I'm generally comfortable taking tests.": '4, (YesYesYesYes)', 'In the past two weeks, I have felt afraid something awful might happen.': '1, (Yes)', 'I get upset easily.': '-2, (NoNo)', 'I thrive in diverse environments': '-1, (No)', 'I have a vivid imagination.': '5, (YesYesYesYesYes)', 'I enjoy thinking about things.': '5, (YesYesYesYesYes)', 'I believe art is important.': '5, (YesYesYesYesYes)', "It's important that I make my family proud of me.": '4, (YesYesYesYes)', 'I like a challenge.': '3, (YesYesYes)', 'I go out of my way to get things I want.': '-2, (NoNo)', 'In the past couple of weeks, I have been fulfilling my potential.': '-1, (No)', 'I am easily bored.': '2, (YesYes)', 'I can easily connect with family and friends if I want.': '4, (YesYesYesYes)', 'I learn well in a study group.': '1, (Yes)', "I learn well when I'm alone.": '3, (YesYesYes)', 'In the past two weeks, I have felt so restless, it is hard to keep still.': '1, (Yes)', 'I feel like my basic needs are met.': '5, (YesYesYesYesYes)', 'I like to read.': '4, (YesYesYesYes)', 'What is your race?': 'White', 'From which socio-economic group would you consider your family to be?': 'High income', 'Are you currently in a relationship?': 'Sort of', 'I worry about my finances.': '4, (YesYesYesYes)', 'Are you currently in a romantic relationship?': 'Sort of', 'Do you have children?': 'No', 'Faith is important to me.': '0, (Indifferent)', 'I have a safe place to live.': '5, (YesYesYesYesYes)', 'What is your gender?': 'Male', 'How old are you?': '22', 'Are you currently employed?': 'Unemployed and currently looking for work', 'How many hours per week do you work?': '0', 'Which of these learning preferences work best for you?': 'Hands-On', 'Have you had any significant problems with mental health in the past?': '3, (YesYesYes)', 'Have you had any significant problems with depression in the past?': '2, (YesYes)', 'Have you had any significant problems with anxiety in the past?': '4, (YesYesYesYes)', 'If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.': '', 'If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.': '', ...
# Saved user answers

# %%
user_answers
# Out:
# {'kbrait': {'I sympathize with others’ feelings.': '3, (YesYesYes)',
#   'I can be pushy.': '2, (YesYes)',
#   'I follow a schedule.': '-2, (NoNo)',
#   'I leave my belongings around.': '4, (YesYesYesYes)',
#   'I often act on the spur of the moment.': '5, (YesYesYesYesYes)',
#   'I am always prepared.': '2, (YesYes)',
#   'I often forget to put things back in their proper place.': '0, (Indifferent)',
#   'I have trouble wrapping up the final details of a project once the challenging parts are done.': '5, (YesYesYesYesYes)',
#   'My social life is important to me': '3, (YesYesYes)',
#   "I like to talk with others when I'm trying to understand new things.": '4, (YesYesYesYes)',
#   'I talk to a lot of different people at social gatherings.': '2, (YesYes)',
#   'I like being the center of attention.': '2, (YesYes)',
#   'I feel I can be my most authentic self.': '3, (YesYesYes)',
#   'I am relaxed most of the time.': '1, (Yes)',
#   'I get stressed out easily.': '-3, (NoNoNo)',
#   'I change my mood a lot.': '1, (Yes)',
#   'I see myself as someone who has high self-esteem.': '4, (YesYesYesYes)',
#   'I get irritated easily.': '1, (Yes)',
#   'I feel like I am in control of what happens to me.': '3, (YesYesYes)',
#   'I feel like powerful others have a lot of control over how my life will turn out.': '-4, (NoNoNoNo)',
#   'I worry about making mistakes.': '-3, (NoNoNo)',
#   'Criticism hurts me.': '4, (YesYesYesYes)',
#   'I feel worried when somebody is angry.': '-5, (NoNoNoNoNo)',
#   'I have very few fears compared to my friends.': '4, (YesYesYesYes)',
#   'In the past two weeks, I have been unable to stop or control worrying.': '1, (Yes)',
#   'In the past two weeks, I have had trouble relaxing.': '1, (Yes)',
#   'In the past two weeks, I have been easily annoyed or irritable.': '-1, (No)',
#   "I'm generally comfortable taking tests.": '4, (YesYesYesYes)',
#   'In the past two weeks, I have felt afraid something awful might happen.': '1, (Yes)',
#   'I get upset easily.': '-2, (NoNo)',
#   'I thrive in diverse environments': '-1, (No)',
#   'I have a vivid imagination.': '5, (YesYesYesYesYes)',
#   'I enjoy thinking about things.': '5, (YesYesYesYesYes)',
#   'I believe art is important.': '5, (YesYesYesYesYes)',
#   "It's important that I make my family proud of me.": '4, (YesYesYesYes)',
#   'I like a challenge.': '3, (YesYesYes)',
#   'I go out of my way to get things I want.': '-2, (NoNo)',
#   'In the past couple of weeks, I have been fulfilling my potential.': '-1, (No)',
#   'I am easily bored.': '2, (YesYes)',
#   'I can easily connect with family and friends if I want.': '4, (YesYesYesYes)',
#   'I learn well in a study group.': '1, (Yes)',
#   "I learn well when I'm alone.": '3, (YesYesYes)',
#   'In the past two weeks, I have felt so restless, it is hard to keep still.': '1, (Yes)',
#   'I feel like my basic needs are met.': '5, (YesYesYesYesYes)',
#   'I like to read.': '4, (YesYesYesYes)',
#   'What is your race?': 'White',
#   'From which socio-economic group would you consider your family to be?': 'High income',
#   'Are you currently in a relationship?': 'Sort of',
#   'I worry about my finances.': '4, (YesYesYesYes)',
#   'Are you currently in a romantic relationship?': 'Sort of',
#   'Do you have children?': 'No',
#   'Faith is important to me.': '0, (Indifferent)',
#   'I have a safe place to live.': '5, (YesYesYesYesYes)',
#   'What is your gender?': 'Male',
#   'How old are you?': '22',
#   'Are you currently employed?': 'Unemployed and currently looking for work',
#   'How many hours per week do you work?': '0',
#   'Which of these learning preferences work best for you?': 'Hands-On',
#   'Have you had any significant problems with mental health in the past?': '3, (YesYesYes)',
#   'Have you had any significant problems with depression in the past?': '2, (YesYes)',
#   'Have you had any significant problems with anxiety in the past?': '4, (YesYesYesYes)',
#   'If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.': '',
#   'If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.': '',
#   'What country were you born in?': 'United States',
#   'What activities do you do?': 'Climbing, Hiking, Writing',
#   "Is there anything else you'd like to tell us that may help us help you?": 'No',
#   'I worry about my physical health': '-1, (No)',
#   'My physical health is out of control': '-3, (NoNoNo)',
#   'The people I care about take good care of their physical health.': '0, (Indifferent)',
#   'Would you say you have a healthy diet?': '-2, (NoNo)',
#   'I have access to healthy food.': '3, (YesYesYes)',
#   'On average, how many hours do you sleep in each 24-hour period?': '8',
#   'If you have a physical disability, please select any category(ies) your physical disability falls into.': '',
#   'Is your diet healthy?': '-1, (No)',
#   'Do you feel confident in your resume?': '1, (Yes)',
#   'Do you feel confident writing a cover letter?': '4, (YesYesYesYes)',
#   'Do you know what job you should work toward?': '-2, (NoNo)',
#   "Do you know how to identify an organization that's a good fit for you?": '-1, (No)',
#   'I know what types of disability accommodations will support me.': '0, (Indifferent)',
#   'I know when to disclose my disability.': '0, (Indifferent)',
#   'I know how to create a disability accommodations plan with an employer.': '0, (Indifferent)',
#   "When I look at a job description, I often feel I'm not qualified.": '1, (Yes)',
#   'I am comfortable and competent using apps on smartphones.': '5, (YesYesYesYesYes)',
#   'I feel connected to the university': '2, (YesYes)',
#   'I am satisfied with my experience at university so far.': '1, (Yes)',
#   'I am satisfied with the support I have been offered by the university.': '0, (Indifferent)',
#   'How do you get to campus?': 'Bike',
#   'Would you be interested in accessing resources and learning more about any of the following?': 'None of the above',
#   'I feel overwhelmed by university life.': '-3, (NoNoNo)',
#   'I feel like I belong at university.': '1, (Yes)',
#   'What program are you currently enrolled in?': 'computer science',
#   'I care what people close to me think is best': '1, (Yes)',
#   'I find it difficult to remember appointments or obligations.': '-5, (NoNoNoNoNo)',
#   'I make careless mistakes while working on a boring or difficult project.': '2, (YesYes)',
#   'In the past two weeks, I have felt nervous, anxious or on edge.': '-2, (NoNo)',
#   'I like to take things apart to see how they work.': '4, (YesYesYesYes)',
#   "I'm always willing to try something new if I think it will be fun.": '5, (YesYesYesYesYes)',
#   'What are your living arrangements?': 'Living off campus with roommate(s)',
#   'Did either of your parents (including step parents/guardian) complete university?': 'Both did',
#   'Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?': '2hrs',
#   'I take steps to work on my mental health regularly.': '0, (Indifferent)',
#   'How intense are your exercise sessions?': 'Pretty intense',
#   'How often do you exercise?': '5-6 times per week',
#   'I get as much sleep as I need.': '0, (Indifferent)',
#   'Do you feel comfortable doing a job interview?': '3, (YesYesYes)',
#   'I feel overwhelmed by my need to find a job.': '1, (Yes)',
#   'I am comfortable and competent using a computer.': '5, (YesYesYesYesYes)',
#   'What year of university are you in?': '5th or higher'}}

# %% [markdown]
# ---
# ## First Pipeline: Generate Additional Question Context for Given Question Text & Answer Type
#
# This pipeline is used to add more context to each question, this could be shown to user's to help them understand the purpose of different questions, however it needs to be specified that this is **AI-Generated** per OpenAI's terms of use. Additionally, it should be specified since at scale the generations will undoubtedly be wrong sometimes, and it's important to be transparent so that user's can laugh about it rather than be confused or upset.

# %% [markdown]
# ---
# #### Context statements that are being used in the following two prompts
#
# These context statements allow GPT to better "understand" what the questions are to the user's in-app experience (question_context_stmt) and how the generations that it makes will be used (generation_context_stmt).

# %%
# Important contexts for first part of the pipeline - Question labeling & use/explain analysis

question_context_stmt = "The questions that you are analyzing are asked in a mobile application directly on a single individual user. \
    The questions are in the for of a questionnaire with a slider, text box, or multiple choice selection. The questions \
    provide insight into the way a user is currently living and experiencing life. This is the context of the questions."

eventual_use_stmt = "The eventual use of the analysis you are providing on the questions will be twofold: (1) provide the user with a better \
    understanding of their current state of being, and (2) provide the user with recommendations on content within the mobile app that they \
    can use to improve themselves. Improve in this context is subjective, hence the need for question analysis. Eventually, \
    the analysis you currently provide on each question will be combined with specific answers to each question and the entire text content of \
    every plan in the mobile app. This is the context of how the analysis you provide will be used."

# %% [markdown]
# ---
# ### First Prompt: Generate Question Label & Explanation

# %%
# PROMPT #1: GENERAL QUESTION LABEL PROMPT

def gpt_question_label_prompt(text, answer_type, answers=None):
    gpt_system_message = "You are going to interpret the meaning behind various questions. You will be given the text of a question \
        and the type of answer that is expected. You will then label the question with a broad label that would help a user answering \
        the question to understand what aspect of their life the answer to this question will relate to. The following is an explanation \
        the context of the questions you are labeling:\n\
        \t{question_context}\n\
        The following is an explanation of the context of how this and further analysis will eventually be used:\n\
        \t{eventual_use}\n\
        Finally, you will be asked to provide a short explanation of why you chose this label for this question.\
        You will fill out the following information for each question: \
            Question Text: {text} \
            Question Label: {generated_label} \
            Label Explanation: {label_explanation}"
    
    real_answer_type = ''
    if answer_type == 'Text, open-ended question':
        real_answer_type = 'open-ended, question_text is representative of how the user will answer'
    elif answer_type == 'A slider displaying text values':
        real_answer_type = 'an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)'
    elif answer_type == 'Multiple choices':
        real_answer_type = 'multiple choice, question_text is representative of the choices, typically provides demographic information'
    else:
        real_answer_type = 'unknown'
    
    # implementation without explicit answers
    if answers is None:
        prompt = f"The question text is: {text} \
            The answer type is '{real_answer_type}'. Answer type is important because it illustrates the options a user has to answer the question. \
            Please fill out the template for this question and generate a label for this question."
        
        # Call the OpenAI API to generate a response
        completion = client.chat.completions.create(
            messages=[
                {
                    "role":"system",
                    "content":gpt_system_message
                },
                {
                    "role":"system",
                    "content":"Never include anything in the response except for the quetion text, question label, and label explanation as specified \
                        in the template. The parsing function relies on the template being followed."
                },
                {
                    "role":"user",
                    "content":prompt
                }
            ],
            model="gpt-3.5-turbo"
        )
        
        # Extract the generated text from the response
        generated_text = completion.choices[0].message.content

        # Print usage cost

        cost = calculate_usage_cost(
                "gpt-3.5-turbo",
                chat_completion.usage.completion_tokens,
                chat_completion.usage.prompt_tokens
            )
            

        return generated_text, real_answer_type, cost

# %% [markdown]
# #### Parsing Labels From the GPT Response

# %%
# parsing function needs to be figured out
def parse_label_output(output):
    output = output.split('\n')
    label = output[1].split(': ')[1]
    label_explain = output[2].split(': ')[1]
    return label, label_explain

# %% [markdown]
# #### Cell that Clears the Labeled Questions List

# %%
clear_labeled_questions()
# Out:
# Cleared labeled questions

# %% [markdown]
# #### Label All Questions
# Cost == ~$0.00237600

# %%
total_cost = 0

for question in questions:
    if question["text"] not in [question["text"] for question in labeled_questions]:
        print("*"*50)
        print("Labeling question: " + question["text"])
        output, real_answer_type, cost = gpt_question_label_prompt(question["text"], question["answer_type"])
        total_cost += cost
        try:
            add_labeled_question(question['text'], real_answer_type, parse_label_output(output)[0], parse_label_output(output)[1])
        except IndexError:
            print("!"*50); print("!"*50)
            print("Error: Can't Parse Prompt Output")
            print("-"*50); print(output); print("-"*50); 
            print("!"*50); print("!"*50)

        print("*"*50)
    else:
        print(f"Question already labeled: {question['text']}")
    # output, real_answer_type = gpt_question_label_prompt(question["text"], question["answer_type"])
    # add_labeled_question(question['text'], real_answer_type, parse_label_output(output)[0], parse_label_output(output)[1])

print_cost(total_cost)
# Out:
# Question already labeled: I care what people close to me think is best
# Question already labeled: I sympathize with others’ feelings.
# Question already labeled: I can be pushy.
# Question already labeled: I follow a schedule.
# Question already labeled: I leave my belongings around.
# Question already labeled: I often act on the spur of the moment.
# Question already labeled: I am always prepared.
# Question already labeled: I often forget to put things back in their proper place.
# Question already labeled: I find it difficult to remember appointments or obligations.
# Question already labeled: I make careless mistakes while working on a boring or difficult project.
# Question already labeled: I have trouble wrapping up the final details of a project once the challenging parts are done.
# Question already labeled: My social life is important to me
# Question already labeled: I like to talk with others when I'm trying to understand new things.
# Question already labeled: I talk to a lot of different people at social gatherings.
# Question already labeled: I like being the center of attention.
# Question already labeled: I feel I can be my most authentic self.
# Question already labeled: I am relaxed most of the time.
# Question already labeled: I get stressed out easily.
# Question already labeled: I change my mood a lot.
# Question already labeled: I see myself as someone who has high self-esteem.
# Question already labeled: I get irritated easily.
# Question already labeled: I feel like I am in control of what happens to me.
# Question already labeled: I feel like powerful others have a lot of control over how my life will turn out.
# Question already labeled: I worry about making mistakes.
# Question already labeled: Criticism hurts me.
# Question already labeled: I feel worried when somebody is angry.
# Question already labeled: I have very few fears compared to my friends.
# Question already labeled: In the past two weeks, I have felt nervous, anxious or on edge.
# Question already labeled: In the past two weeks, I have been unable to stop or control worrying.
# Question already labeled: In the past two weeks, I have had trouble relaxing.
# Question already labeled: In the past two weeks, I have been easily annoyed or irritable.
# Question already labeled: I'm generally comfortable taking tests.
# Question already labeled: In the past two weeks, I have felt afraid something awful might happen.
# Question already labeled: I get upset easily.
# Question already labeled: I thrive in diverse environments
# Question already labeled: I have a vivid imagination.
# Question already labeled: I enjoy thinking about things.
# Question already labeled: I believe art is important.
# Question already labeled: I like to take things apart to see how they work.
# Question already labeled: I'm always willing to try something new if I think it will be fun.
# Question already labeled: It's important that I make my family proud of me.
# Question already labeled: I like a challenge.
# Question already labeled: I go out of my way to get things I want.
# Question already labeled: In the past couple of weeks, I have been fulfilling my potential.
# Question already labeled: I am easily bored.
# Question already labeled: I can easily connect with family and friends if I want.
# Question already labeled: I learn well in a study group.
# Question already labeled: I learn well when I'm alone.
# Question already labeled: In the past two weeks, I have felt so restless, it is hard to keep still.
# Question already labeled: I feel like my basic needs are met.
# Question already labeled: I like to read.
# Question already labeled: What is your race?
# Question already labeled: From which socio-economic group would you consider your family to be?
# Question already labeled: What are your living arrangements?
# Question already labeled: Are you currently in a relationship?
# Question already labeled: I worry about my finances.
# Question already labeled: Did either of your parents (including step parents/guardian) complete university?
# Question already labeled: Are you currently in a romantic relationship?
# Question already labeled: Do you have children?
# Question already labeled: Faith is important to me.
# Question already labeled: I have a safe place to live.
# Question already labeled: What is your gender?
# Question already labeled: How old are you?
# Question already labeled: Are you currently employed?
# Question already labeled: How many hours per week do you work?
# Question already labeled: Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?
# Question already labeled: Which of these learning preferences work best for you?
# Question already labeled: Have you had any significant problems with mental health in the past?
# Question already labeled: Have you had any significant problems with depression in the past?
# Question already labeled: Have you had any significant problems with anxiety in the past?
# Question already labeled: If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.
# Question already labeled: If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.
# Question already labeled: I take steps to work on my mental health regularly.
# Question already labeled: What country were you born in?
# Question already labeled: What activities do you do?
# Question already labeled: Is there anything else you'd like to tell us that may help us help you?
# Question already labeled: I worry about my physical health
# Question already labeled: My physical health is out of control
# Question already labeled: The people I care about take good care of their physical health.
# Question already labeled: Would you say you have a healthy diet?
# Question already labeled: How intense are your exercise sessions?
# Question already labeled: I have access to healthy food.
# Question already labeled: How often do you exercise?
# Question already labeled: On average, how many hours do you sleep in each 24-hour period?
# Question already labeled: If you have a physical disability, please select any category(ies) your physical disability falls into.
# Question already labeled: I get as much sleep as I need.
# Question already labeled: Is your diet healthy?
# Question already labeled: Do you feel confident in your resume?
# Question already labeled: Do you feel confident writing a cover letter?
# **************************************************
# Labeling question: Do you feel comfortable doing a job interview?
# Added labeled question: Do you feel comfortable doing a job interview?
# Length of labeled questions: 108
# **************************************************
# Question already labeled: Do you know what job you should work toward?
# Question already labeled: Do you know how to identify an organization that's a good fit for you?
# Question already labeled: I know what types of disability accommodations will support me.
# Question already labeled: I know when to disclose my disability.
# Question already labeled: I know how to create a disability accommodations plan with an employer.
# Question already labeled: I feel overwhelmed by my need to find a job.
# Question already labeled: When I look at a job description, I often feel I'm not qualified.
# Question already labeled: I am comfortable and competent using a computer.
# Question already labeled: I am comfortable and competent using apps on smartphones.
# Question already labeled: I feel connected to the university
# Question already labeled: What year of university are you in?
# Question already labeled: I am satisfied with my experience at university so far.
# Question already labeled: I am satisfied with the support I have been offered by the university.
# Question already labeled: How do you get to campus?
# Question already labeled: Would you be interested in accessing resources and learning more about any of the following?
# Question already labeled: I feel overwhelmed by university life.
# Question already labeled: I feel like I belong at university.
# Question already labeled: What program are you currently enrolled in?
# Total Cost: $0.00002200
# Number of Runs to Reach $1: 45455
# **************************************************

# %%
pretty_print(labeled_questions)
try:
    save_data(labeled_questions, "labeled_questions")
    print("Saved labeled questions")
except:
    print("Could not save labeled questions")
    print(f"Error Message: {sys.exc_info()[0]}")
# Out:
# [
#     {
#         "text": "I care what people close to me think is best",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Relationships",
#         "label_explain": "This question is asking about the importance placed on the opinions of people who are close to the person answering the question. It relates to the dynamics and dynamics and influence in their relationships.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I sympathize with others\u2019 feelings.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Empathy",
#         "label_explain": "This question is about the respondent's capacity to understand and share the feelings of others, indicating their level of empathy.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I can be pushy.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personality Traits ",
#         "label_explain": "This question is asking about the user's behavior and personality, specifically in relation to being pushy. The answer to this question will give insight into the user's tendency to assert themselves and how assertive they perceive themselves to be.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I follow a schedule.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Daily Routine",
#         "label_explain": "This question pertains to the individual's daily routine and how organized they are in following a schedule.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I leave my belongings around.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Organization and Tidiness",
#         "label_explain": "This question is related to how organized and tidy a person is in terms of their belongings. It is asking whether the person tends to leave their belongings around or if they are more organized and keep their belongings in their proper place.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I often act on the spur of the moment.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Behavior",
#         "label_explain": "This question pertains to the individual's tendency to make decisions or take actions impulsively, without much forethought or planning. It is asking about a specific aspect of personal behavior related to spontaneity and impulsivity.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am always prepared.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Traits",
#         "label_explain": "This question is asking about the personal trait of being prepared. The answer to this question will relate to how well the person feels they are able to plan and be ready for different situations.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I often forget to put things back in their proper place.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Organization/Forgetfulness",
#         "label_explain": "This question addresses an aspect of organization and forgetfulness. The user's answer will provide insight into their habits of putting things back in their proper place.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I find it difficult to remember appointments or obligations.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Memory and Organization",
#         "label_explain": "This question pertains to an individual's ability to remember and keep track of appointments or obligations. It relates to their memory and organizational skills.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I make careless mistakes while working on a boring or difficult project.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Productivity",
#         "label_explain": "This question falls under the label of productivity because it relates to how well the person is able to focus and perform tasks effectively during challenging or uninteresting projects.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I have trouble wrapping up the final details of a project once the challenging parts are done.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Work/Life Balance",
#         "label_explain": "This question is related to the aspect of work-life balance. It suggests difficulty in completing tasks and projects even after the challenging parts are done, indicating a potential imbalance between work and personal life.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "My social life is important to me",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Life",
#         "label_explain": "This question is asking about the importance of the user's social life in their life. The answer to this question will provide insight into the value the user places on their social relationships and interactions.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I like to talk with others when I'm trying to understand new things.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Interaction",
#         "label_explain": "This question is asking about the preference for engaging in conversation with others when trying to understand new things. The label \"Social Interaction\" captures the aspect of socializing and seeking help from others in the process of learning or gaining knowledge.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I talk to a lot of different people at social gatherings.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Life",
#         "label_explain": "This question relates to the social aspect of the user's life, specifically their interactions with different people at social gatherings.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I like being the center of attention.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Preferences",
#         "label_explain": "This question is about the individual's preference for being the center of attention. The answer to this question will reflect the individual's attitude towards being the focus of others' attention.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel I can be my most authentic self.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-Expression",
#         "label_explain": "This question is asking about the individual's ability to be true to themselves and express their authentic self. It is related to self-expression and how comfortable the person feels in being their true self.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am relaxed most of the time.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is asking about the respondent's overall level of relaxation, which is related to their mental well-being. Answering this question will provide insight into the respondent's state of mind and their ability to handle stress and anxiety.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I get stressed out easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being ",
#         "label_explain": "This question is about a person's emotional well-being and their ability to handle stress. The answer to this question will give insight into how easily someone becomes stressed and overwhelmed.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I change my mood a lot.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question relates to the individual's emotional well-being as it explores how frequently their mood changes.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I see myself as someone who has high self-esteem.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-Perception",
#         "label_explain": "This question pertains to an individual's perception of their own self-esteem. It relates to how they view themselves and their confidence level.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I get irritated easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions",
#         "label_explain": "This question is asking about the user's tendency to get easily irritated, which falls under the broad category of emotions.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel like I am in control of what happens to me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Growth",
#         "label_explain": "This question asks about the individual's perception of control over their own life and circumstances. It relates to their personal growth and self-determination.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel like powerful others have a lot of control over how my life will turn out.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Beliefs and Outlook",
#         "label_explain": "This question relates to an individual's perception of the influence that powerful individuals or entities have over their life outcomes. It explores their internal beliefs and outlook on the extent to which external forces can shape their life trajectory.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I worry about making mistakes.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is related to the individual's mental health as it addresses their propensity to worry about making mistakes.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Criticism hurts me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being ",
#         "label_explain": "This question is related to how criticism affects the emotional well-being of the individual.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel worried when somebody is angry.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions and Reactions",
#         "label_explain": "This question is asking about the user's emotional response to someone expressing anger. It falls under the category of emotions and reactions because it relates to how the user feels in response to a specific situation.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I have very few fears compared to my friends.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Traits/Qualities",
#         "label_explain": "This question asks about the level of fears compared to friends. It relates to the personal traits or qualities of the individual and how they perceive their fears in comparison to others.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past two weeks, I have felt nervous, anxious or on edge.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is asking about the respondent's mental state in the past two weeks. It focuses specifically on feelings of nervousness, anxiety, or being on edge, which are indicators of mental health. Therefore, the broad label for this question is \"Mental Health\".",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past two weeks, I have been unable to stop or control worrying.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is labeled as \"Mental Health\" because it pertains to the individual's ability to stop or control worrying, which is related to their mental well-being.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past two weeks, I have had trouble relaxing.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question relates to the emotional well-being of the individual, specifically their ability to relax. The answer to this question will provide insight into the level of relaxation the person has experienced in the past two weeks.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past two weeks, I have been easily annoyed or irritable.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question is related to the emotional well-being of the individual. It asks about their level of irritability or annoyance in the past two weeks, indicating their emotional state during that period.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I'm generally comfortable taking tests.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Academic Performance",
#         "label_explain": "This question is asking about the respondent's comfort level when it comes to taking tests. The answer to this question will provide insight into the respondent's attitudes and feelings regarding academic performance.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past two weeks, I have felt afraid something awful might happen.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Fear and Anxiety",
#         "label_explain": "I chose the label \"Fear and Anxiety\" for this question because it asks about feelings of fear and worry within a specific time frame. The answer to this question will provide insight into the level of fear and anxiety the individual has been experiencing recently.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I get upset easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions",
#         "label_explain": "This question is asking about the respondent's emotional tendencies, specifically their propensity to get upset easily. The answer to this question will provide insights into the individual's emotional stability and resilience.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I thrive in diverse environments",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Growth",
#         "label_explain": "This question is asking about an individual's preference for diverse environments and how they feel they perform in such settings. It relates to personal growth because thriving in diverse environments can lead to personal development by exposing individuals to different perspectives, cultures, and experiences.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I have a vivid imagination.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Imagination",
#         "label_explain": "This question is asking about the individual's level of vivid imagination.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I enjoy thinking about things.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Interest",
#         "label_explain": "This question is asking about the enjoyment a person gets from thinking about things. It is related to personal interests and preferences.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I believe art is important.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Opinion - Art",
#         "label_explain": "I chose the label \"Personal Opinion - Art\" because this question is asking for the user's personal belief about the importance of art. The answer will reflect the user's perspective on the value of art in their life.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I like to take things apart to see how they work.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Hobbies and Interests",
#         "label_explain": "This question asks about the respondent's preference for taking things apart to understand how they work. The label \"Hobbies and Interests\" accurately captures that this question relates to an aspect of someone's free-time activities and personal interests.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I'm always willing to try something new if I think it will be fun.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "New Experiences ",
#         "label_explain": "This question is about the willingness or openness to try new things or experiences for the sake of fun or enjoyment. The label \"New Experiences\" reflects the broad category of personal growth, exploration, and embracing novelty.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "It's important that I make my family proud of me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Family and Personal Relationships",
#         "label_explain": "This question pertains to the aspect of a person's life that involves their family and personal relationships. It explores the importance of someone's desire to make their family proud of them.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I like a challenge.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Growth",
#         "label_explain": "I chose the label \"Personal Growth\" for this question because it relates to one's attitude and preference towards facing challenges.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I go out of my way to get things I want.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Behavior/Desire",
#         "label_explain": "This question reflects an individual's personal behavior and desire to put in extra effort to attain things they want.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past couple of weeks, I have been fulfilling my potential.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Development",
#         "label_explain": "This question is related to the individual's personal growth and progress in maximizing their abilities and achieving their goals.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am easily bored.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Boredom",
#         "label_explain": "This question is labeled as \"Boredom\" because it directly asks about the individual's inclination towards getting bored easily. The answer to this question will provide insights into the person's level of boredom tolerance and their need for stimulation in different situations.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I can easily connect with family and friends if I want.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Relationships",
#         "label_explain": "This question is asking about the ease of connecting with family and friends, which is related to the quality of someone's social relationships.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I learn well in a study group.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Learning Preferences",
#         "label_explain": "This question is related to how the individual prefers to learn, specifically in relation to study groups. The label \"Learning Preferences\" encompasses the aspect of learning style and environment.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I learn well when I'm alone.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Preference",
#         "label_explain": "This question seeks to determine the preferred learning environment of the individual. It focuses on whether they have a preference for studying alone or if they prefer other settings.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "In the past two weeks, I have felt so restless, it is hard to keep still.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Restlessness in the past two weeks",
#         "label_explain": "I chose this label because the question is asking about the level of restlessness someone has felt in the past two weeks. The answer to this question would provide insights into the individual's experience of restlessness during that specific time period.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel like my basic needs are met.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Basic Needs",
#         "label_explain": "This question is asking about the individual's perception of whether their basic needs are met. It relates to the foundational aspects of their life such as food, shelter, and safety.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I like to read.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Hobbies and Interests - Reading",
#         "label_explain": "I chose this label because the question is asking about the user's interest in reading, which falls under hobbies and interests.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "What is your race?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Personal Identity",
#         "label_explain": "This question asks about the racial background or ethnicity of the respondent. It pertains to their personal identity and background.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "From which socio-economic group would you consider your family to be?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Socio-economic status",
#         "label_explain": "This question is asking for the respondent's perception of their family's socio-economic group. It aims to gather information about their social and economic standing within society. The answer to this question would provide insights into the respondent's perception of their own socio-economic status.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "What are your living arrangements?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Living Situation",
#         "label_explain": "I chose the label \"Living Situation\" for this question because it asks about the user's current living arrangements, which can give insights into their housing situation and lifestyle.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Are you currently in a relationship?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Relationship Status",
#         "label_explain": "This question is asking about the user's current relationship status. The answer to this question will provide insight into the user's personal life and whether they are currently in a committed relationship or not.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I worry about my finances.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Finances",
#         "label_explain": "I chose the label \"Finances\" for this question because it is specifically asking about the respondent's concerns or worries regarding their financial situation.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Did either of your parents (including step parents/guardian) complete university?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Education",
#         "label_explain": "This question is asking about the educational background of the user's parents or guardians. The answer to this question will provide information about the level of education attained by the user's parents or guardians.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Are you currently in a romantic relationship?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Relationship Status",
#         "label_explain": "This question is asking about the individual's current romantic relationship status. The answer to this question will provide information about whether the person is currently in a romantic relationship or not.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Do you have children?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Family",
#         "label_explain": "This question is asking about the presence or absence of children in the person's life, which is related to their family situation.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Faith is important to me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Spirituality/Religion",
#         "label_explain": "This question is asking about the significance of faith in one's life, specifically in relation to one's personal beliefs and spirituality.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I have a safe place to live.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Housing",
#         "label_explain": "This question relates to the aspect of one's life that pertains to their housing situation.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "What is your gender?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Demographics - Gender",
#         "label_explain": "This question is asking for the respondent's gender, which is a demographic characteristic of a person. The answer options typically include choices such as male, female, and non-binary.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "How old are you?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Personal Information",
#         "label_explain": "This question is asking for the age of the person. The answer to this question will provide personal information about the individual's age.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Are you currently employed?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Employment Status",
#         "label_explain": "I chose the label \"Employment Status\" for this question because it is asking about whether the person is currently employed or not. The answer to this question will provide information about the individual's employment status.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "How many hours per week do you work?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Work-Life Balance",
#         "label_explain": "This question is asking about the number of hours a person works per week, which is related to their  work-life balance. The answer to this question will provide insight into how much time a person dedicates to their work compared to other aspects of their life.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Academic Study Habits",
#         "label_explain": "This question pertains to the amount of time a person spends on studying or doing schoolwork outside of class. It provides insights into their academic study habits.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Which of these learning preferences work best for you?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Learning Styles",
#         "label_explain": "This question is asking about the different learning preferences that work best for the individual. The label \"Learning Styles\" captures the nature of this question, which is to understand how the person prefers to learn and what methods are most effective for them.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Have you had any significant problems with mental health in the past?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health History",
#         "label_explain": "This question is asking about the individual's past experiences with mental health issues. The label \"Mental Health History\" accurately captures the focus of the question, which relates to the individual's personal history of mental health problems.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Have you had any significant problems with depression in the past?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is asking about past experiences with depression, which is directly related to mental health.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Have you had any significant problems with anxiety in the past?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is asking about the individual's experience with anxiety, which falls under the category of mental health.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Mental Health Categories",
#         "label_explain": "I chose the label \"Mental Health Categories\" for this question because it is asking respondents to select the category or categories that their current mental health issues fall into. This question is seeking information related to the different types or classifications of mental health issues that individuals may be experiencing.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Mental Health History",
#         "label_explain": "This question is asking about the categories or types of mental health issues that the individual has experienced in the past. The answer options will provide insight into the individual's mental health history.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
# ...
#         "label": "Disabilities",
#         "label_explain": "This question is asking about the different categories or types of physical disabilities that the respondent may have. The label 'Disabilities' is appropriate because it captures the broad theme of physical disabilities that the answer to this question will relate to.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I get as much sleep as I need.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Sleep",
#         "label_explain": "This question is asking about the amount of sleep the person feels they need. The answer to this question will relate to the aspect of the person's life concerning their sleep habits.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Is your diet healthy?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Health and Wellness",
#         "label_explain": "I chose the label \"Health and Wellness\" for this question because it is asking about the overall healthiness of a person's diet. The answer to this question will provide insights into the individual's lifestyle and their commitment to maintaining a healthy diet.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Do you feel confident in your resume?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Career Development",
#         "label_explain": "This question is related to the user's level of confidence in their resume, which is directly connected to their career development.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Do you feel confident writing a cover letter?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Writing Skills",
#         "label_explain": "This question is related to the individual's writing skills. It asks about their confidence specifically in the context of writing a cover letter.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Do you know what job you should work toward?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Career Planning",
#         "label_explain": "I chose the label \"Career Planning\" for this question because it pertains to making decisions and setting goals related to one's career path. The question asks if the person has a clear understanding of the specific job they should aim for in their future.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Do you know how to identify an organization that's a good fit for you?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Career and Personal Development",
#         "label_explain": "This question is related to the individual's knowledge and understanding of what criteria to use in order to identify an organization that aligns with their values, goals, and preferences. It pertains to career and personal development as it addresses the process of finding a suitable organization for the individual's professional growth and personal satisfaction.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I know what types of disability accommodations will support me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Knowing One's Needs",
#         "label_explain": "This question is asking about the user's understanding and knowledge of the type of disability accommodations that would support them. This relates to their ability to identify and comprehend their own needs and requirements in order to access appropriate accommodations.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I know when to disclose my disability.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Growth and Self-Awareness",
#         "label_explain": "This question relates to an individual's understanding of when to share information about their disability with others. It reflects the individual's self-awareness and ability to make decisions regarding disclosure.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I know how to create a disability accommodations plan with an employer.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Skills",
#         "label_explain": "This question pertains to the individual's knowledge and abilities in creating a disability accommodations plan with an employer. It falls under the category of personal skills as it assesses the expertise of the person in this particular area.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel overwhelmed by my need to find a job.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Career/Work Life",
#         "label_explain": "This question is related to the aspect of a person's life concerning their career or work life. It addresses the emotional state of feeling overwhelmed in relation to the need to find a job.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "When I look at a job description, I often feel I'm not qualified.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Career",
#         "label_explain": "This question relates to the aspect of someone's career or professional life. It explores their feelings of being qualified or not when looking at job descriptions.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am comfortable and competent using a computer.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Computer Skills",
#         "label_explain": "This question is asking about the comfort and competence level in using a computer. The answer to this question would provide insights into the individual's computer skills.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am comfortable and competent using apps on smartphones.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Technology-Usage",
#         "label_explain": "I chose the label \"Technology-Usage\" for this question because it relates to the respondent's level of comfort and competence in using apps on smartphones. It pertains to their ability to navigate and utilize technology effectively, specifically in the context of smartphone applications.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel connected to the university",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "University Life",
#         "label_explain": "The question reflects the respondent's emotional connection to the university, suggesting their level of engagement and affiliation with university life.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "What year of university are you in?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Education/University Level",
#         "label_explain": "This question is asking about the level or year of education someone is currently at in university. It is seeking information about their academic progress and belongs to the Education category.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am satisfied with my experience at university so far.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Satisfaction in university experience",
#         "label_explain": "The question is asking about the individual's level of satisfaction with their experience at university. The answer to this question will provide insight into how the individual feels about their overall experience at university.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I am satisfied with the support I have been offered by the university.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "University Support Satisfaction",
#         "label_explain": "This question pertains to the satisfaction level of the support provided by the university.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "How do you get to campus?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Transportation",
#         "label_explain": "This question is related to transportation and asks how someone typically gets to campus.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Would you be interested in accessing resources and learning more about any of the following?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Personal Interests",
#         "label_explain": "This question is asking about the user's personal interests and what resources they would like to access for further learning.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel overwhelmed by university life.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question is related to the emotional well-being of the user. It is asking about their feelings of being overwhelmed specifically in the context of university life.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "I feel like I belong at university.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-perception",
#         "label_explain": "This question is related to the individual's perception of their sense of belonging at university. The answer to this question will provide insight into how the individual feels about their connection to the university environment.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "What program are you currently enrolled in?",
#         "answer_type": "open-ended, question_text is representative of how the user will answer",
#         "label": "Education",
#         "label_explain": "This question is related to the educational aspect of someone's life. The answer will provide information about the specific program or course the person is currently involved in.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     },
#     {
#         "text": "Do you feel comfortable doing a job interview?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Job/Work",
#         "label_explain": "This question is asking about the user's comfort level in completing a specific task related to their job or work.",
#         "primary_use": "",
#         "secondary_use": "",
#         "tertiary_use": "",
#         "primary_explain": "",
#         "secondary_explain": "",
#         "tertiary_explain": ""
#     }
# ]
# Saved labeled questions

# %% [markdown]
# #### Label a Specific Question - Demo Purpose

# %%
# Example to see how it works - THIS CELL COSTS MONEY TO RUN (PROMPT #1)
# Takes ~20 seconds to run

ex_q = questions[107]
#questions[99] # question 99 text: "I feel connected to the university."
ex_output, real_answer_type = gpt_question_label_prompt(ex_q['text'], ex_q['answer_type'])
# Out:
# Total Cost: $0.00002200
# Number of Runs to Reach $1: 45455

# %%
print(ex_output)
# Out:
# Question Text: What program are you currently enrolled in?
# Question Label: Academic/Career
# Label Explanation: This question is asking about the program the person is currently studying or participating in. It pertains to their academic or career-related activities.

# %%
#add_labeled_question(ex_q['text'], real_answer_type, parse_label_output(ex_output)[0], parse_label_output(ex_output)[1])
pretty_print(labeled_questions)
# Out:
# [
#     {
#         "text": "I care what people close to me think is best",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Relationships",
#         "label_explain": "This question is asking about the importance placed on the opinions of people who are close to the person answering the question. It relates to the dynamics and dynamics and influence in their relationships.",
#         "primary_use": "Assessing the importance placed on the opinions of people close to the user",
#         "secondary_use": "Understanding the user's decision-making process",
#         "tertiary_use": "Evaluating the user's level of independence in decision-making",
#         "primary_explain": "This question is asking about the extent to which the user values the opinions of people who are close to them. It provides insights into the importance the user gives to the perspectives and input of their loved ones when making decisions.",
#         "secondary_explain": "By understanding how much the user cares about the opinions of people close to them, we can gain insights into their decision-making process. If they strongly care about what others think, they may consider their opinions heavily in their decision-making. On the other hand, if they don't care much, they may have a more independent decision-making style.",
#         "tertiary_explain": "Additionally, the user's response to this question can provide an indication of their level of independence in decision-making. If they strongly agree, they may rely heavily on others for guidance and decision-making. If they strongly disagree, they may have a strong sense of autonomy and rely primarily on their own judgment."
#     },
#     {
#         "text": "I sympathize with others\u2019 feelings.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Empathy",
#         "label_explain": "This question is about the respondent's capacity to understand and share the feelings of others, indicating their level of empathy.",
#         "primary_use": "Assessing the level of empathy of the respondent.",
#         "secondary_use": "Understanding the respondent's ability to understand and connect with others emotionally.",
#         "tertiary_use": "Gaining insights into the respondent's interpersonal skills and emotional intelligence.",
#         "primary_explain": "This question is designed to gauge the respondent's capacity to understand and share the feelings of others, indicating their level of empathy. Empathy plays a crucial role in building strong relationships, fostering understanding, and cultivating emotional connections with others. By understanding one's level of empathy, we can gain insights into how they might respond to and interact with others in various social and personal contexts.",
#         "secondary_explain": "A person's ability to sympathize with others' feelings can provide valuable information about their emotional intelligence. It reflects their capacity to perceive and understand the emotions of others, allowing for more effective communication and connection. Empathy is a fundamental component of interpersonal relationships and is associated with positive outcomes such as increased trust, better conflict resolution, and enhanced social support.",
#         "tertiary_explain": "By assessing the respondent's level of empathy, we can gain insights into their interpersonal skills and their capacity to navigate social situations. Those who score high on this question may possess qualities such as sensitivity, compassion, and the ability to provide support to others. On the other hand, those who score low may benefit from developing their empathy skills, which can potentially enhance their relationships and overall well-being."
#     },
#     {
#         "text": "I can be pushy.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personality Traits ",
#         "label_explain": "This question is asking about the user's behavior and personality, specifically in relation to being pushy. The answer to this question will give insight into the user's tendency to assert themselves and how assertive they perceive themselves to be.",
#         "primary_use": "Assessing assertiveness level",
#         "secondary_use": "Understanding individual behavior",
#         "tertiary_use": "Identifying communication style",
#         "primary_explain": "This question is asking about the user's behavior and personality, specifically in relation to being pushy. The answer to this question will give insight into the user's tendency to assert themselves and how assertive they perceive themselves to be. By evaluating the user's response, it can provide an indication of their level of assertiveness in various situations.",
#         "secondary_explain": "Understanding an individual's behavior is essential in various contexts, such as work environments, personal relationships, and social interactions. This question helps to gauge the user's inclination towards assertiveness, which in turn helps to understand how they navigate through different situations and interact with others.",
#         "tertiary_explain": "Communication style is closely associated with assertiveness. By understanding an individual's level of assertiveness, it becomes easier to comprehend their communication style. This question can provide some insight into whether the user tends to be direct and assertive in their communication or if they are more passive and accommodating. Recognizing someone's communication style is valuable for effective communication and to tailor communication approaches to suit their preferences."
#     },
#     {
#         "text": "I follow a schedule.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Daily Routine",
#         "label_explain": "This question pertains to the individual's daily routine and how organized they are in following a schedule.",
#         "primary_use": "Assessing the user's level of organization and time management skills.",
#         "secondary_use": "Understanding the user's ability to adhere to routines and structure in their daily life.",
#         "tertiary_use": "Evaluating how the user manages their time and prioritizes tasks.",
#         "primary_explain": "The main use of this question is to gain insight into the user's level of organization and time management. By understanding if the user follows a schedule or not, we can gauge their ability to plan their day and allocate time for different tasks. This information can be useful in various contexts such as personal productivity, work performance, or overall efficiency in managing responsibilities.",
#         "secondary_explain": "Additionally, this question helps in understanding the user's inclination towards routines and structure. It provides an indication of whether they prefer a more spontaneous and flexible approach or thrive in a well-defined schedule. This insight can be relevant in areas like setting expectations, creating workflow systems, or even personal development.",
#         "tertiary_explain": "Lastly, by asking about following a schedule, we can assess how the user manages their time and prioritizes tasks. It gives an indication of their ability to allocate time effectively, set realistic goals, and maintain a balanced approach to various activities in their daily life. This understanding can be valuable in areas like time management coaching, resource allocation, or optimizing productivity routines."
#     },
#     {
#         "text": "I leave my belongings around.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Organization and Tidiness",
#         "label_explain": "This question is related to how organized and tidy a person is in terms of their belongings. It is asking whether the person tends to leave their belongings around or if they are more organized and keep their belongings in their proper place.",
#         "primary_use": "Assessing tidiness and organization habits",
#         "secondary_use": "Understanding personal living space habits",
#         "tertiary_use": "Assessing responsibility and care for personal belongings",
#         "primary_explain": "The question is used to assess a person's tidiness and organization habits. By asking whether someone tends to leave their belongings around, it gives insight into their level of organization and cleanliness. This information can be useful for understanding how someone manages their personal space and belongings.",
#         "secondary_explain": "Additionally, the question can provide insight into a person's living space habits. If someone tends to leave their belongings around, it may indicate that they have a more relaxed or casual approach to their living space. Understanding this aspect can be helpful for various scenarios, such as when organizing shared living spaces or planning events.",
#         "tertiary_explain": "Furthermore, the question can also be used to assess a person's responsibility and care for their personal belongings. If someone consistently leaves their belongings around, it may suggest a lack of attention to detail or a tendency to neglect their possessions. This information can be valuable in situations where trustworthiness and reliability are important, such as when considering roommates or potential employees."
#     },
#     {
#         "text": "I often act on the spur of the moment.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Behavior",
#         "label_explain": "This question pertains to the individual's tendency to make decisions or take actions impulsively, without much forethought or planning. It is asking about a specific aspect of personal behavior related to spontaneity and impulsivity.",
#         "primary_use": "Understanding the user's level of impulsivity and spontaneity.",
#         "secondary_use": "Assessing the user's ability to make impulsive decisions.",
#         "tertiary_use": "Identifying patterns in the user's behavior related to impulsivity.",
#         "primary_explain": "This question aims to gauge the frequency with which the user engages in impulsive actions or decisions without much prior thought or planning. By understanding the user's level of impulsivity, we can gain insights into their decision-making process and propensity for spontaneous behavior.",
#         "secondary_explain": "Additionally, this question can help assess the user's ability to make quick decisions and adapt to unexpected situations. It highlights their comfort with spontaneity and their readiness to embrace new opportunities without overthinking.",
#         "tertiary_explain": "Over time, analyzing the user's responses to this question can reveal patterns in their behavior related to impulsivity. By tracking changes in their level of spontaneity, we can gain insights into their personal growth, decision-making strategies, and potential areas for improvement."
#     },
#     {
#         "text": "I am always prepared.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Traits",
#         "label_explain": "This question is asking about the personal trait of being prepared. The answer to this question will relate to how well the person feels they are able to plan and be ready for different situations.",
#         "primary_use": "Assessing the level of preparedness.",
#         "secondary_use": "Evaluating organizational skills.",
#         "tertiary_use": "Gauging adaptability to changing situations.",
#         "primary_explain": "This question is asking about the personal trait of being prepared. The answer to this question will relate to how well the person feels they are able to plan and be ready for different situations. By understanding the individual's level of preparedness, it can provide insights into their ability to anticipate and handle various tasks and challenges effectively.",
#         "secondary_explain": "The question also indirectly assesses the individual's organizational skills. Being prepared often requires planning, prioritization, and managing resources efficiently. Therefore, the response to this question can shed light on the person's organizational abilities and their approach to structuring their daily life or work.",
#         "tertiary_explain": "Additionally, the question can provide some insight into the individual's adaptability to changing situations. The level of preparedness can indicate how well a person can quickly adjust their plans and strategies when unexpected events occur. It can show if they are comfortable with uncertainty or tend to be more rigid in their approach to situations."
#     },
#     {
#         "text": "I often forget to put things back in their proper place.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Organization/Forgetfulness",
#         "label_explain": "This question addresses an aspect of organization and forgetfulness. The user's answer will provide insight into their habits of putting things back in their proper place.",
#         "primary_use": "Assessing the user's level of forgetfulness and organization.",
#         "secondary_use": "Identifying potential causes for forgetfulness or disorganization.",
#         "tertiary_use": "Offering suggestions or strategies to improve organization and memory.",
#         "primary_explain": "This question is designed to understand the user's habits and tendencies when it comes to organizing and putting things back in their proper place. By knowing whether the user frequently forgets to do so or not, we can gain insight into their level of organization and attention to detail.",
#         "secondary_explain": "Additionally, the user's answer may shed light on potential reasons for their forgetfulness or disorganization. It could indicate factors such as stress, lack of attention, or a busy lifestyle that may contribute to the issue.",
#         "tertiary_explain": "Based on the user's response, we could provide practical suggestions or strategies to improve their organization and memory. This could include tips on creating reminders, implementing a routine, or finding organizational systems that work best for them."
#     },
#     {
#         "text": "I find it difficult to remember appointments or obligations.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Memory and Organization",
#         "label_explain": "This question pertains to an individual's ability to remember and keep track of appointments or obligations. It relates to their memory and organizational skills.",
#         "primary_use": "Assessing Memory and Organization Skills",
#         "secondary_use": "Determining Level of Difficulty with Time Management",
#         "tertiary_use": "Identifying Potential Stressors",
#         "primary_explain": "This question can be used to assess an individual's memory and organization skills. By understanding whether they find it difficult to remember appointments or obligations, we can gain insight into their ability to effectively manage their time and responsibilities.",
#         "secondary_explain": "Additionally, this question can help determine the level of difficulty an individual may have with time management. If they struggle to remember appointments or obligations, it suggests that they may face challenges in prioritizing tasks and allocating their time effectively.",
#         "tertiary_explain": "Furthermore, this question can aid in identifying potential stressors in an individual's life. Difficulty remembering appointments or obligations can contribute to feelings of being overwhelmed or anxious, highlighting potential areas for support or intervention."
#     },
#     {
#         "text": "I make careless mistakes while working on a boring or difficult project.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Productivity",
#         "label_explain": "This question falls under the label of productivity because it relates to how well the person is able to focus and perform tasks effectively during challenging or uninteresting projects.",
#         "primary_use": "Assessing Task Engagement",
#         "secondary_use": "Identifying Attentional Capacity",
#         "tertiary_use": "Evaluating Challenge Level",
#         "primary_explain": "This question can be used to assess the level of task engagement of an individual. If the person agrees that they make careless mistakes while working on a boring or difficult project, it suggests that they may have difficulty maintaining focus and attention when faced with challenging or uninteresting tasks. This information can be useful in understanding the person's overall level of engagement in their work or projects.",
#         "secondary_explain": "The question can also be used to identify the attentional capacity of an individual. If the person frequently makes careless mistakes while working on a boring or difficult project, it may indicate that their attentional resources are easily depleted or that they struggle to sustain attention for extended periods of time. This insight can be valuable in determining how to best optimize their work environment or design tasks that align with their attentional capacity.",
#         "tertiary_explain": "Additionally, this question can be used to evaluate the level of challenge provided by the project or task. If someone consistently makes careless mistakes while working on a boring or difficult project, it suggests that the project may be too challenging for their current skill level or that the task lacks sufficient engagement to maintain their interest. Understanding the challenge level can help in better matching individuals with tasks that are appropriately challenging and engaging."
#     },
#     {
#         "text": "I have trouble wrapping up the final details of a project once the challenging parts are done.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Work/Life Balance",
#         "label_explain": "This question is related to the aspect of work-life balance. It suggests difficulty in completing tasks and projects even after the challenging parts are done, indicating a potential imbalance between work and personal life.",
#         "primary_use": "Assessing Work/Life Balance",
#         "secondary_use": "Identifying Perfectionist Tendencies",
#         "tertiary_use": "Evaluating Attention to Detail",
#         "primary_explain": "This question can be used to assess the work/life balance of the individual. Their difficulty in completing the final details of a project may indicate that they are struggling to find the time or motivation to focus on these tasks, which could suggest they are prioritizing other aspects of their life over work. ",
#         "secondary_explain": "The question can also be used to identify perfectionist tendencies. If the individual finds it challenging to wrap up the final details of a project, it may suggest that they have a strong desire for perfection and struggle to let go of projects even when they are mostly complete.",
#         "tertiary_explain": "Additionally, this question can be used to evaluate attention to detail. If the individual has trouble completing the final details of a project, it may indicate that they struggle to pay attention to the smaller, finer aspects of their work. This could be important in certain fields where attention to detail is critical for success."
#     },
#     {
#         "text": "My social life is important to me",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Life",
#         "label_explain": "This question is asking about the importance of the user's social life in their life. The answer to this question will provide insight into the value the user places on their social relationships and interactions.",
#         "primary_use": "Assessing the importance of social life for the user",
#         "secondary_use": "Understanding the user's social priorities",
#         "tertiary_use": "Evaluating the user's level of social engagement",
#         "primary_explain": "This question is asking about the importance of social life in the user's life. The answer to this question will provide insight into the value the user places on their social relationships and interactions. It can help identify if the user values and prioritizes their social life as an important aspect of their overall well-being.",
#         "secondary_explain": "By understanding the importance of the user's social life, it can provide an understanding of their social priorities. This can help in tailoring recommendations or suggestions that align with their values and preferences in social activities, events, or interactions.",
#         "tertiary_explain": "The user's answer to this question can also provide an indication of their level of social engagement. A high rating on the slider (6-10) suggests that the user highly values their social life and is likely to be more socially active and engaged. Conversely, a low rating (0-4) may indicate that the user does not prioritize social interactions as much and may prefer solitary activities."
#     },
#     {
#         "text": "I like to talk with others when I'm trying to understand new things.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Interaction",
#         "label_explain": "This question is asking about the preference for engaging in conversation with others when trying to understand new things. The label \"Social Interaction\" captures the aspect of socializing and seeking help from others in the process of learning or gaining knowledge.",
#         "primary_use": "Understanding the user's preference for social interaction during the learning process.",
#         "secondary_use": "Assessing the user's willingness to seek help and engage in conversation with others.",
#         "tertiary_use": "Identifying the user's belief in the effectiveness of social interaction for learning.",
#         "primary_explain": "This question reveals whether the user prefers to engage in conversation with others when trying to understand new things. It provides insight into their inclination towards social interaction during the learning process.",
#         "secondary_explain": "By analyzing the user's response to this question, we can gauge their willingness to seek help and collaborate with others while learning. It helps us understand their openness to engaging in discussions and valuing different perspectives in the pursuit of knowledge.",
#         "tertiary_explain": "This question can also indicate the user's belief in the effectiveness of social interaction for learning. If they strongly agree, it suggests they perceive conversation and group discussion as beneficial for comprehension and acquiring new knowledge. Conversely, if they strongly disagree, it implies they favor independent learning methods over social interaction."
#     },
#     {
#         "text": "I talk to a lot of different people at social gatherings.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Life",
#         "label_explain": "This question relates to the social aspect of the user's life, specifically their interactions with different people at social gatherings.",
#         "primary_use": "Assessing social interaction level.",
#         "secondary_use": "Understanding social network.",
#         "tertiary_use": "Identifying extroversion level.",
#         "primary_explain": "The main use of this question is to assess the user's level of social interaction. By understanding if the user talks to a lot of different people at social gatherings, we can get an idea of how socially active they are and how comfortable they are in social settings.",
#         "secondary_explain": "Additionally, this question can help us understand the user's social network. If they talk to a lot of different people, it suggests that they have a wide network of connections and may be well-connected in their social circle.",
#         "tertiary_explain": "Lastly, this question can provide insight into the user's extroversion level. If they enjoy talking to a lot of different people at social gatherings, it indicates a preference for socializing and being around others."
#     },
#     {
#         "text": "I like being the center of attention.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Preferences",
#         "label_explain": "This question is about the individual's preference for being the center of attention. The answer to this question will reflect the individual's attitude towards being the focus of others' attention.",
#         "primary_use": "Understanding the individual's preference for being the center of attention.",
#         "secondary_use": "Evaluating the individual's level of self-confidence and extroversion.",
#         "tertiary_use": "Providing insights into the individual's willingness to take on leadership roles.",
#         "primary_explain": "This question is designed to assess the individual's preference for being the center of attention. The answer to this question will help understand whether the individual enjoys being the focus of others' attention or prefers to stay in the background.",
#         "secondary_explain": "By analyzing the answer to this question, one can also gain insights into the individual's level of self-confidence and extroversion. Those who strongly agree with the statement may have higher levels of self-confidence and enjoy social interactions, while those who strongly disagree may be more introverted and prefer to avoid attention.",
#         "tertiary_explain": "Additionally, the answer to this question can provide useful information about the individual's willingness to take on leadership roles. Those who enjoy being the center of attention may be more inclined to seek leadership positions and take charge in various situations. Conversely, those who prefer to avoid attention may be more comfortable in supportive or behind-the-scenes roles."
#     },
#     {
#         "text": "I feel I can be my most authentic self.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-Expression",
#         "label_explain": "This question is asking about the individual's ability to be true to themselves and express their authentic self. It is related to self-expression and how comfortable the person feels in being their true self.",
#         "primary_use": "Evaluating self-expression and personal authenticity.",
#         "secondary_use": "Assessing individual satisfaction and fulfillment.",
#         "tertiary_use": "Understanding personal growth and development.",
#         "primary_explain": "This question helps to gauge the extent to which an individual feels comfortable and confident in expressing their true self. It gives insight into their level of self-acceptance and authenticity in various aspects of their life, such as relationships, work, and personal pursuits.",
#         "secondary_explain": "By understanding how the user rates their ability to be authentic, we can gain insights into their overall satisfaction and fulfillment in life. Those who feel they can be their most authentic self are more likely to experience a sense of purpose and alignment with their values, leading to a higher sense of well-being.",
#         "tertiary_explain": "This question also provides valuable information about an individual's personal growth and development. If someone feels they can be their most authentic self, it suggests that they have likely done the self-reflection and introspection necessary to understand their true desires and values. It implies that they have worked on personal growth and self-acceptance, which are important factors in leading a fulfilling and meaningful life."
#     },
#     {
#         "text": "I am relaxed most of the time.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is asking about the respondent's overall level of relaxation, which is related to their mental well-being. Answering this question will provide insight into the respondent's state of mind and their ability to handle stress and anxiety.",
#         "primary_use": "Assessing mental well-being",
#         "secondary_use": "Identifying stress and anxiety levels",
#         "tertiary_use": "Understanding ability to handle challenges",
#         "primary_explain": "This question is asking about the respondent's overall level of relaxation, which is related to their mental well-being. Answering this question will provide insight into the respondent's state of mind and their ability to handle stress and anxiety. By understanding how relaxed someone is most of the time, we can gain a general understanding of their mental health and emotional stability.",
#         "secondary_explain": "In addition to assessing mental well-being, this question can also help identify stress and anxiety levels. Someone who is relaxed most of the time may have lower levels of stress and anxiety, while someone who is not relaxed most of the time may have higher levels of stress and anxiety. This information can be useful in determining potential areas of improvement or identifying individuals who may benefit from additional support or interventions.",
#         "tertiary_explain": "Another use of this question is to understand the individual's ability to handle challenges. If someone is relaxed most of the time, it suggests that they have a better capacity to manage stressors and navigate difficult situations. On the other hand, if someone is not relaxed most of the time, it may indicate that they struggle with coping mechanisms and may need assistance in developing effective stress management strategies. This understanding can help inform interventions and support systems tailored to individual needs."
#     },
#     {
#         "text": "I get stressed out easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being ",
#         "label_explain": "This question is about a person's emotional well-being and their ability to handle stress. The answer to this question will give insight into how easily someone becomes stressed and overwhelmed.",
#         "primary_use": "Understanding the user's stress levels.",
#         "secondary_use": "Assessing the user's ability to handle stress.",
#         "tertiary_use": "Identifying the user's emotional well-being.",
#         "primary_explain": "This question is designed to determine how easily the user becomes stressed. By understanding their stress levels, we can better assess their overall ability to handle difficult situations and challenges in life.",
#         "secondary_explain": "Additionally, this question can provide insight into the user's resilience and coping mechanisms. If they tend to get stressed out easily, it may indicate a need for stress management techniques or support to improve their overall well-being.",
#         "tertiary_explain": "The answer to this question can also give us a glimpse into the user's emotional well-being. If they consistently get stressed out easily, it may suggest that they are experiencing higher levels of stress and potentially impacting their mental health. Understanding this can help us provide appropriate resources or recommendations for support."
#     },
#     {
#         "text": "I change my mood a lot.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question relates to the individual's emotional well-being as it explores how frequently their mood changes.",
#         "primary_use": "Assessing the user's emotional stability.",
#         "secondary_use": "Identifying potential mental health issues.",
#         "tertiary_use": "Personalization of mental health support.",
#         "primary_explain": "This question is used to assess the user's emotional stability by exploring the frequency of mood changes. It provides an insight into how stable or unstable the user's emotions are on a day-to-day basis. This can help in understanding the user's emotional well-being and overall mental health status.",
#         "secondary_explain": "The response to this question can also provide information about potential mental health issues. If the user consistently indicates high levels of mood fluctuations, it may suggest the presence of mood disorders such as bipolar disorder or borderline personality disorder. This can help in early identification and intervention for such conditions.",
#         "tertiary_explain": "The user's response to this question can be used to personalize mental health support. If the user reports frequent mood changes, mental health interventions can be tailored to address emotional regulation, coping mechanisms, and stress management. It can help clinicians or mental health professionals to devise strategies that specifically target the user's needs, improving the effectiveness of the support provided."
#     },
#     {
#         "text": "I see myself as someone who has high self-esteem.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-Perception",
#         "label_explain": "This question pertains to an individual's perception of their own self-esteem. It relates to how they view themselves and their confidence level.",
#         "primary_use": "Assessing self-perception of self-esteem.",
#         "secondary_use": "Identifying potential areas of self-improvement.",
#         "tertiary_use": "Understanding how self-esteem may impact various aspects of life.",
#         "primary_explain": "This question is designed to assess an individual's perception of their own self-esteem. By asking how someone sees themselves in terms of self-esteem, it provides insight into their level of confidence and self-worth. This information can be useful in understanding their overall self-perception and how they may navigate different situations.",
#         "secondary_explain": "In addition to assessing self-perception, this question can also highlight areas where individuals may need to work on improving their self-esteem. If someone rates themselves low in terms of self-esteem, it may indicate that they struggle with confidence or have negative self-beliefs that could be addressed through self-development and personal growth.",
#         "tertiary_explain": "Understanding an individual's self-esteem can have broad implications in various aspects of their life. Self-esteem plays a role in relationships, career choices, decision-making, and mental well-being. By knowing an individual's self-perception of self-esteem, it can provide insights into how they may approach these different areas and what support or resources they may need to bolster their self-esteem."
#     },
#     {
#         "text": "I get irritated easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions",
#         "label_explain": "This question is asking about the user's tendency to get easily irritated, which falls under the broad category of emotions.",
#         "primary_use": "Understanding the user's tendency to get easily irritated.",
#         "secondary_use": "Identifying potential triggers or factors contributing to the user's irritability.",
#         "tertiary_use": "Assessing the user's emotional well-being.",
#         "primary_explain": "The main use of this question is to gain an understanding of the user's tendency to get easily irritated. By assessing their irritability levels, we can better understand their emotional state and potential challenges they may face in managing their emotions.",
#         "secondary_explain": "In addition to understanding the user's irritability levels, this question can provide insights into potential triggers or factors that contribute to their irritability. This information can be helpful in identifying situations or circumstances that may need to be addressed or managed differently to reduce irritability.",
#         "tertiary_explain": "This question also serves as a way to assess the user's overall emotional well-being. If they indicate a high level of irritability, it may indicate that they are experiencing challenges in regulating their emotions and may benefit from strategies or support to improve their emotional well-being."
#     },
#     {
#         "text": "I feel like I am in control of what happens to me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Growth",
#         "label_explain": "This question asks about the individual's perception of control over their own life and circumstances. It relates to their personal growth and self-determination.",
#         "primary_use": "Assessing the individual's perception of personal power and control.",
#         "secondary_use": "Gauging the individual's level of self-determination.",
#         "tertiary_use": "Exploring the individual's belief in their ability to influence outcomes.",
#         "primary_explain": "This question is used to understand the individual's subjective experience of control in their life. It provides insight into how much agency they perceive themselves to have in shaping their circumstances and influencing the outcomes of their actions.",
#         "secondary_explain": "By asking this question, we can gain a better understanding of the individual's level of self-determination and autonomy. It allows us to explore their sense of responsibility and power in directing their own life and making choices that align with their values and goals.",
#         "tertiary_explain": "This question also helps us assess the individual's belief in their ability to influence outcomes. It provides information about their mindset and whether they feel empowered or constrained in navigating their life circumstances and pursuing their aspirations."
#     },
#     {
#         "text": "I feel like powerful others have a lot of control over how my life will turn out.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Beliefs and Outlook",
#         "label_explain": "This question relates to an individual's perception of the influence that powerful individuals or entities have over their life outcomes. It explores their internal beliefs and outlook on the extent to which external forces can shape their life trajectory.",
#         "primary_use": "Assessing Perceived Locus of Control",
#         "secondary_use": "Understanding Personal Beliefs and Outlook",
#         "tertiary_use": "Identifying External Locus of Control",
#         "primary_explain": "This question is used to assess an individual's perceived locus of control, which refers to their belief in the amount of control they have over the outcomes in their life. By asking about the influence of powerful others on their life, we can gain insights into whether they perceive themselves as having a strong sense of control or if they believe external forces have more influence.",
#         "secondary_explain": "This question helps us understand an individual's personal beliefs and outlook. By examining their perception of the control exerted by powerful others, we can gain insight into how they view external influences on their life outcomes. It can provide a glimpse into their overall worldview and whether they tend to attribute success or failure to themselves or external factors.",
#         "tertiary_explain": "The question also helps us identify individuals who may have an external locus of control, meaning they believe that powerful others or external circumstances have significant control over their life outcomes. Understanding this propensity towards external control can help tailor interventions or support systems to empower individuals and foster a greater sense of personal agency and control."
#     },
#     {
#         "text": "I worry about making mistakes.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is related to the individual's mental health as it addresses their propensity to worry about making mistakes.",
#         "primary_use": "Assessing the user's level of anxiety or stress related to making mistakes.",
#         "secondary_use": "Identifying the user's self-confidence and perfectionistic tendencies.",
#         "tertiary_use": "Evaluating the user's potential for self-criticism and fear of judgment.",
#         "primary_explain": "This question is designed to gauge the user's level of concern or anxiety when it comes to making mistakes. By understanding the extent to which the user worries about making mistakes, it can provide insights into their overall mental well-being and potentially uncover underlying anxiety or stress-related issues.",
#         "secondary_explain": "The user's response to this question can also reveal their self-confidence and perfectionistic tendencies. Those who strongly agree or disagree with the statement may exhibit traits associated with perfectionism, where they may constantly strive for perfection or may avoid taking risks altogether.",
#         "tertiary_explain": "Additionally, the user's response to this question can shed light on their self-critical tendencies and fear of judgment. Those who express a high level of worry about making mistakes may have a tendency to be overly self-critical and fear the judgment or criticism of others. This information can be useful in understanding how the user perceives themselves and how they may react in situations where mistakes are made."
#     },
#     {
#         "text": "Criticism hurts me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being ",
#         "label_explain": "This question is related to how criticism affects the emotional well-being of the individual.",
#         "primary_use": "Understanding the impact of criticism on the user's emotional well-being.",
#         "secondary_use": "Identifying the user's vulnerability to criticism.",
#         "tertiary_use": "Assessing the user's coping mechanisms for dealing with criticism.",
#         "primary_explain": "This question can help us understand how criticism affects the emotional well-being of the individual. By analyzing the user's response, we can gain insights into whether criticism has a negative or positive impact on their overall well-being.",
#         "secondary_explain": "Additionally, the user's response to this question can indicate their level of vulnerability to criticism. Those who strongly agree that criticism hurts them may be more sensitive to negative feedback, while those who strongly disagree may be more resilient.",
#         "tertiary_explain": "Furthermore, the user's answer can provide insights into their coping mechanisms for dealing with criticism. If they indicate that criticism has a strong negative impact on them, it suggests that they may struggle with managing and processing criticisms effectively."
#     },
#     {
#         "text": "I feel worried when somebody is angry.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions and Reactions",
#         "label_explain": "This question is asking about the user's emotional response to someone expressing anger. It falls under the category of emotions and reactions because it relates to how the user feels in response to a specific situation.",
#         "primary_use": "Understanding the user's emotional response to anger.",
#         "secondary_use": "Assessing the user's level of empathy.",
#         "tertiary_use": "Identifying potential triggers for the user's worry.",
#         "primary_explain": "This question is used to gain insight into the user's emotional response to someone expressing anger. It helps understand how the user feels when others are angry, providing valuable information about their emotional sensitivity and empathy towards others.",
#         "secondary_explain": "By assessing the user's level of worry when somebody is angry, this question can provide a glimpse into the user's empathetic nature. It indicates whether the user is highly attuned to the emotions of those around them or if they are less affected by others' anger.",
#         "tertiary_explain": "Additionally, analyzing the user's response to this question can help identify potential triggers for their worry. For example, if the user consistently feels worried when somebody is angry, it may suggest that they have experienced uncomfortable or distressing situations in the past when others were angry. Understanding these triggers can help in creating a supportive and comfortable environment for the user."
#     },
#     {
#         "text": "I have very few fears compared to my friends.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Traits/Qualities",
#         "label_explain": "This question asks about the level of fears compared to friends. It relates to the personal traits or qualities of the individual and how they perceive their fears in comparison to others.",
#         "primary_use": "Understanding the level of fear in relation to friends",
#         "secondary_use": "Assessing personal perception of fear",
#         "tertiary_use": "Comparing personal traits with friends",
# ...
#         "label": "Satisfaction in university experience",
#         "label_explain": "The question is asking about the individual's level of satisfaction with their experience at university. The answer to this question will provide insight into how the individual feels about their overall experience at university.",
#         "primary_use": "Measuring satisfaction with university experience",
#         "secondary_use": "Evaluating the effectiveness of university programs and services",
#         "tertiary_use": "Identifying areas of improvement in the university experience",
#         "primary_explain": "The main use of this question is to measure the satisfaction level of the individual with their experience at university. By collecting responses on a slider ranging from negative to positive, we can understand whether the individual is generally satisfied or dissatisfied with their university experience. This information can be used to gauge overall student satisfaction and identify any areas where improvements may be needed.",
#         "secondary_explain": "In addition to gauging individual satisfaction, the question can also be used to evaluate the effectiveness of university programs and services. If a high percentage of students indicate satisfaction, it suggests that the university is meeting the needs and expectations of its students. On the other hand, if a significant number of students express dissatisfaction, it may indicate areas where programs and services need to be improved or revamped.",
#         "tertiary_explain": "The tertiary use of this question is to identify specific areas of improvement in the university experience. By analyzing the responses and looking at the distribution of satisfaction levels, patterns can emerge regarding which aspects of the university experience are most satisfying or dissatisfying for students. This information can then be used to prioritize and address areas where improvements are needed, whether it's in academics, campus facilities, student support services, or other areas."
#     },
#     {
#         "text": "I am satisfied with the support I have been offered by the university.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "University Support Satisfaction",
#         "label_explain": "This question pertains to the satisfaction level of the support provided by the university.",
#         "primary_use": "Measuring user satisfaction with university support.",
#         "secondary_use": "Identifying areas of improvement in university support.",
#         "tertiary_use": "Evaluating the effectiveness of university support programs.",
#         "primary_explain": "The main use of this question is to measure user satisfaction with the support provided by the university. By analyzing the responses on the 11-pt slider, we can gain insights into how satisfied the users are with the support they have received.",
#         "secondary_explain": "The secondary use of this question is to identify areas of improvement in university support. If a significant number of users express dissatisfaction through their responses, it indicates that there might be issues or gaps in the support services provided by the university.",
#         "tertiary_explain": "The tertiary use of this question is to evaluate the effectiveness of university support programs. By comparing the satisfaction levels of different users, we can assess the impact and success of various support initiatives implemented by the university. This can lead to further improvements and enhancements in the support services."
#     },
#     {
#         "text": "How do you get to campus?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Transportation",
#         "label_explain": "This question is related to transportation and asks how someone typically gets to campus.",
#         "primary_use": "Understanding transportation options and preferences.",
#         "secondary_use": "Gathering demographic information about transportation habits.",
#         "tertiary_use": "Assessing the effectiveness and accessibility of transportation infrastructure.",
#         "primary_explain": "The main use of this question is to understand the transportation methods that individuals use to get to campus. By asking this question, we can collect valuable information about the different modes of transportation people utilize, such as walking, biking, driving, taking public transportation, or carpooling. This can help in evaluating the availability and effectiveness of various transportation options and identifying areas for improvement.",
#         "secondary_explain": "The secondary use of this question is to gather demographic information about transportation habits. By analyzing the responses to this question, we can gain insights into the transportation preferences and behaviors of different demographics. For example, we can determine if there are any variations based on age, gender, or location. This information can be useful in developing targeted transportation initiatives or tailoring transportation services to specific groups.",
#         "tertiary_explain": "The tertiary use of this question is to assess the effectiveness and accessibility of transportation infrastructure. By understanding how people get to campus, we can evaluate the existing transportation infrastructure and identify any potential issues or areas of improvement. For instance, if a majority of people drive to campus, it may indicate a need for additional parking facilities. If public transportation is the preferred mode, it may highlight the need for better transit connectivity or increased frequency of service. This information can inform urban planning decisions and contribute to creating a more efficient and sustainable transportation system."
#     },
#     {
#         "text": "Would you be interested in accessing resources and learning more about any of the following?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Personal Interests",
#         "label_explain": "This question is asking about the user's personal interests and what resources they would like to access for further learning.",
#         "primary_use": "Understanding the user's interests and areas of curiosity.",
#         "secondary_use": "Tailoring recommendations and content to the user's preferences.",
#         "tertiary_use": "Collecting demographic information for analysis and targeting.",
#         "primary_explain": "This question is designed to understand the user's interests and what they would like to learn more about. By knowing the topics or areas they are interested in, we can provide them with relevant resources and recommendations to further their learning. This helps personalize their experience and ensures they receive information that aligns with their interests.",
#         "secondary_explain": "In addition to understanding the user's interests, this question can also be used to tailor recommendations and content to their preferences. By identifying the topics they are interested in, we can suggest relevant resources, articles, courses, or events that match their interests. This improves user engagement and satisfaction with the content being offered.",
#         "tertiary_explain": "Another use of this question is to collect demographic information for analysis and targeting purposes. By knowing what resources and topics different demographics are interested in, we can create targeted marketing campaigns, identify trends, and make data-driven decisions to better serve our users. This helps us understand the preferences and needs of different user segments, allowing us to improve our offerings and reach a wider audience."
#     },
#     {
#         "text": "I feel overwhelmed by university life.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question is related to the emotional well-being of the user. It is asking about their feelings of being overwhelmed specifically in the context of university life.",
#         "primary_use": "Assessing the user's emotional well-being.",
#         "secondary_use": "Identifying potential stressors or challenges in university life.",
#         "tertiary_use": "Determining the need for support or resources.",
#         "primary_explain": "This question is used to understand the user's emotional well-being specifically in the context of university life. It aims to assess if the user feels overwhelmed by the demands and challenges they are facing as a student.",
#         "secondary_explain": "By asking this question, we can gain insights into the specific stressors or challenges that university life may be presenting to the user. This can help us better understand their overall experience and identify areas where additional support or resources may be beneficial.",
#         "tertiary_explain": "The user's response to this question can also help determine if they need any immediate support or resources to cope with the feelings of overwhelm. It can inform interventions or strategies to help them manage their university life and improve their overall well-being."
#     },
#     {
#         "text": "I feel like I belong at university.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-perception",
#         "label_explain": "This question is related to the individual's perception of their sense of belonging at university. The answer to this question will provide insight into how the individual feels about their connection to the university environment.",
#         "primary_use": "Gauge self-perception of sense of belonging",
#         "secondary_use": "Assess overall satisfaction with university experience",
#         "tertiary_use": "Determine potential areas for improvement in the university environment",
#         "primary_explain": "This question is used to gauge the individual's self-perception of their sense of belonging at university. By providing an answer on the 11-point slider, ranging from negative to positive, it allows the individual to express their level of agreement or disagreement with the statement. This information can be valuable in understanding how the individual feels about their connection to the university environment.",
#         "secondary_explain": "In addition to understanding the individual's self-perception, the answer to this question can also provide insight into their overall satisfaction with their university experience. Those who strongly agree with the statement may feel a strong sense of belonging, suggesting a positive university experience, while those who strongly disagree may feel disconnected or dissatisfied.",
#         "tertiary_explain": "Furthermore, the question response can help identify potential areas for improvement in the university environment. If a significant number of individuals indicate a low sense of belonging, it could indicate that steps need to be taken to foster a more inclusive and supportive atmosphere, such as improving campus activities, implementing mentorship programs, or offering support services."
#     },
#     {
#         "text": "What program are you currently enrolled in?",
#         "answer_type": "open-ended, question_text is representative of how the user will answer",
#         "label": "Education",
#         "label_explain": "This question is related to the educational aspect of someone's life. The answer will provide information about the specific program or course the person is currently involved in.",
#         "primary_use": "Gathering information about the user's educational program.",
#         "secondary_use": "Assessing the user's educational background and interests.",
#         "tertiary_use": "Providing personalized recommendations or assistance related to the user's program.",
#         "primary_explain": "The main use of this question is to gather information about the user's educational program. By asking this question, we can learn about the specific program or course the person is currently enrolled in. This information can be useful for various purposes, such as understanding the user's educational background, tailoring recommendations or assistance related to their program, or identifying common interests among users in similar programs.",
#         "secondary_explain": "In addition to gathering information about the user's program, this question can also provide insights into the user's educational background and interests. Knowing the program the user is enrolled in can give us a glimpse into their academic pursuits and areas of expertise. This information can be helpful for various secondary purposes, such as targeting relevant educational resources, identifying potential mentorship opportunities, or understanding the user's career aspirations.",
#         "tertiary_explain": "Furthermore, knowing the user's program can enable us to provide personalized recommendations or assistance related to their program. For example, if the user is studying computer science, we can offer resources, tutorials, or mentoring opportunities specifically tailored to computer science students. This personalized approach can enhance the user's learning experience and help them make the most of their program. Additionally, by analyzing common programs among users, we can identify trends or patterns that might inform the development of new educational resources or initiatives."
#     },
#     {
#         "text": "Do you feel comfortable doing a job interview?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Job/Work",
#         "label_explain": "This question is asking about the user's comfort level in completing a specific task related to their job or work.",
#         "primary_use": "Assessing the user's confidence level in job interviews.",
#         "secondary_use": "Determining the user's level of preparedness for job interviews.",
#         "tertiary_use": "Providing opportunities for improvement in job interview skills.",
#         "primary_explain": "The main use of this question is to assess the user's comfort level in job interviews. This can provide valuable information about their confidence and ability to handle job interviews effectively. Depending on their response, further support and guidance can be provided to enhance their interview skills and boost their chances of success.",
#         "secondary_explain": "The secondary use of this question is to determine the user's level of preparedness for job interviews. If the user expresses discomfort or a lack of confidence, it may indicate that they need additional support and preparation to improve their interview skills. This can help guide the development of resources and strategies aimed at helping them feel more comfortable and confident during job interview situations.",
#         "tertiary_explain": "The tertiary use of this question is to provide opportunities for improvement in job interview skills. If the user indicates a lower comfort level, it can serve as a starting point for identifying areas where they may need assistance. This can include offering interview practice sessions, providing resources on interview techniques, or recommending workshops or courses focused on improving interview skills. By addressing any discomfort or lack of confidence, the user can enhance their job interview performance and increase their chances of securing employment."
#     }
# ]

# %% [markdown]
# ---
# ### Second Prompt: Generate Three Question Uses and Explanations

# %%
# PROMPT #2 - GENERAL QUESTION USES PROMPT

def gpt_question_uses_prompt(text, answer_type, label, label_explanation, answers=None):
    gpt_system_message = """
    You are going to interpret the meaning behind various questions. 
    You will be given the text of a question and the type of answer that is expected. 
    Your goal is to think about how the way the user answers the question could generally provide some usable information for the user. 
    Try to be general enough with the uses so that whether the question is answered extremely one way or extremely the 
    other way, there will still be some use in knowing the uses of the question overall. The context of the questions you are 
    analyzing is as follows:
    \t{question_context}
    The context of how this and further analysis will eventually be used is as follows:
    \t{eventual_use}
    You will just fill out the following information for each question:
    Question Text: {text}
    Question Main Use: {generated_main_use}
    Question Secondary Use: {generated_secondary_use}
    Question Tertiary Use: {generated_tertiary_use}
    Main Explanation: {main_explanation}
    Secondary Explanation: {secondary_explanation}
    Tertiary Explanation: {tertiary_explanation}"""
    
    if answers is None:
        prompt = f"""
        The question text is: {text}
        The answer type is '{answer_type}'. Answer type is important because it illustrates the options a user has to answer the question.
        The label is '{label}'. This is a general label that provides some insight into how the question relates to the user's life.
        Since the label is generated by a NLP model, there is also an explanation to provide better context as to why the model chose this label.
        The label explanation is '{label_explanation}'.
        Please fill out the template for this question and generate uses and explanations for this question."""

        example_output = """
        Question Text: This is just an example question text.
        Question Main Use: This is just an example main use.
        Question Secondary Use: This is just an example secondary use.
        Question Tertiary Use: This is just an example tertiary use.
        Main Explanation: This is just an example main explanation.
        Secondary Explanation: This is just an example secondary explanation.
        Tertiary Explanation: This is just an example tertiary explanation."""
        
        completion = client.chat.completions.create(
            messages=[
                {
                    "role":"system",
                    "content":gpt_system_message
                },
                {
                    "role":"user",
                    "content":prompt
                },
                {
                    "role":"assistant",
                    "content":example_output
                }
            ],
            model="gpt-3.5-turbo"
        )
        
        # Extract the generated text from the response
        generated_text = completion.choices[0].message.content.strip('\n')

        # Print usage cost
        cost = calculate_usage_cost(
                "gpt-3.5-turbo",
                chat_completion.usage.completion_tokens,
                chat_completion.usage.prompt_tokens
            )

        return generated_text, cost

# %% [markdown]
# #### Parse Generated Uses and Explanations

# %%
def parse_uses_output(output):
    output = output.strip('\n')
    output = output.split('\n')
    primary_use = output[1].split(': ')[1]
    secondary_use = output[2].split(': ')[1]
    tertiary_use = output[3].split(': ')[1]
    primary_explain = output[4].split(': ')[1]
    secondary_explain = output[5].split(': ')[1]
    tertiary_explain = output[6].split(': ')[1]
    return primary_use, secondary_use, tertiary_use, primary_explain, secondary_explain, tertiary_explain

# %% [markdown]
# #### Better Parsing (ChatGPT-4 Online Wrote This Function)

# %%
def better_uses_parsing(output):
    # Define default values for all fields
    fields = {
        'Question Main Use': 'N/A',
        'Question Secondary Use': 'N/A',
        'Question Tertiary Use': 'N/A',
        'Main Explanation': 'N/A',
        'Secondary Explanation': 'N/A',
        'Tertiary Explanation': 'N/A'
    }

    # Normalize the output by replacing double newlines with single newlines
    normalized_output = output.replace('\n\n', '\n').strip()

    # Split the output into lines
    lines = normalized_output.split('\n')

    # Iterate over each line, checking if it starts with one of the fields
    for line in lines:
        # Split the line into key and value based on the first colon found
        parts = line.split(': ', 1)
        if len(parts) == 2:
            key, value = parts
            # If the key is one of the fields we're looking for, update the dictionary
            if key in fields:
                fields[key] = value.strip()

    # Return the values in the order expected
    return (fields['Question Main Use'], fields['Question Secondary Use'], fields['Question Tertiary Use'],
            fields['Main Explanation'], fields['Secondary Explanation'], fields['Tertiary Explanation'])

# %% [markdown]
# #### Bulk Question Uses Generation

# %%
total_cost = 0
for question in labeled_questions:
    if question['primary_use'] == "" and question['label'] != "":
        print("*"*50)
        print("Generating uses for question: " + question['text'])
        output, cost = gpt_question_uses_prompt(question['text'], question['answer_type'], question['label'], question['label_explain'])
        total_cost += cost
        try:
            p,s,t,pe,se,te = better_uses_parsing(output) # parse_uses_output(output)
            add_uses_to_labeled_question(question['text'], p,s,t)
            add_explain_to_labeled_question(question['text'], pe,se,te)
        except IndexError:
            print("!"*50); print("!"*50)
            print("Error: Can't Parse Prompt Output")
            print("-"*50); print(output); print("-"*50); 
            print("!"*50); print("!"*50)

        print("*"*50)
    else:
        print(f"Question already has uses: {question['text']}")

print_cost(total_cost)
# Out:
# Question already has uses: I care what people close to me think is best
# Question already has uses: I sympathize with others’ feelings.
# **************************************************
# Generating uses for question: I can be pushy.
# Added uses to labeled question: I can be pushy.
# Added explain to labeled question: I can be pushy.
# **************************************************
# Question already has uses: I follow a schedule.
# Question already has uses: I leave my belongings around.
# Question already has uses: I often act on the spur of the moment.
# Question already has uses: I am always prepared.
# **************************************************
# Generating uses for question: I often forget to put things back in their proper place.
# Added uses to labeled question: I often forget to put things back in their proper place.
# Added explain to labeled question: I often forget to put things back in their proper place.
# **************************************************
# Question already has uses: I find it difficult to remember appointments or obligations.
# Question already has uses: I make careless mistakes while working on a boring or difficult project.
# Question already has uses: I have trouble wrapping up the final details of a project once the challenging parts are done.
# Question already has uses: My social life is important to me
# Question already has uses: I like to talk with others when I'm trying to understand new things.
# Question already has uses: I talk to a lot of different people at social gatherings.
# Question already has uses: I like being the center of attention.
# Question already has uses: I feel I can be my most authentic self.
# Question already has uses: I am relaxed most of the time.
# Question already has uses: I get stressed out easily.
# Question already has uses: I change my mood a lot.
# Question already has uses: I see myself as someone who has high self-esteem.
# Question already has uses: I get irritated easily.
# Question already has uses: I feel like I am in control of what happens to me.
# **************************************************
# Generating uses for question: I feel like powerful others have a lot of control over how my life will turn out.
# Added uses to labeled question: I feel like powerful others have a lot of control over how my life will turn out.
# Added explain to labeled question: I feel like powerful others have a lot of control over how my life will turn out.
# **************************************************
# Question already has uses: I worry about making mistakes.
# Question already has uses: Criticism hurts me.
# Question already has uses: I feel worried when somebody is angry.
# Question already has uses: I have very few fears compared to my friends.
# Question already has uses: In the past two weeks, I have felt nervous, anxious or on edge.
# Question already has uses: In the past two weeks, I have been unable to stop or control worrying.
# Question already has uses: In the past two weeks, I have had trouble relaxing.
# Question already has uses: In the past two weeks, I have been easily annoyed or irritable.
# Question already has uses: I'm generally comfortable taking tests.
# Question already has uses: In the past two weeks, I have felt afraid something awful might happen.
# Question already has uses: I get upset easily.
# Question already has uses: I thrive in diverse environments
# Question already has uses: I have a vivid imagination.
# **************************************************
# Generating uses for question: I enjoy thinking about things.
# Added uses to labeled question: I enjoy thinking about things.
# Added explain to labeled question: I enjoy thinking about things.
# **************************************************
# Question already has uses: I believe art is important.
# Question already has uses: I like to take things apart to see how they work.
# Question already has uses: I'm always willing to try something new if I think it will be fun.
# Question already has uses: It's important that I make my family proud of me.
# Question already has uses: I like a challenge.
# **************************************************
# Generating uses for question: I go out of my way to get things I want.
# Added uses to labeled question: I go out of my way to get things I want.
# Added explain to labeled question: I go out of my way to get things I want.
# **************************************************
# Question already has uses: In the past couple of weeks, I have been fulfilling my potential.
# Question already has uses: I am easily bored.
# Question already has uses: I can easily connect with family and friends if I want.
# Question already has uses: I learn well in a study group.
# **************************************************
# Generating uses for question: I learn well when I'm alone.
# Added uses to labeled question: I learn well when I'm alone.
# Added explain to labeled question: I learn well when I'm alone.
# **************************************************
# **************************************************
# Generating uses for question: In the past two weeks, I have felt so restless, it is hard to keep still.
# Added uses to labeled question: In the past two weeks, I have felt so restless, it is hard to keep still.
# Added explain to labeled question: In the past two weeks, I have felt so restless, it is hard to keep still.
# **************************************************
# **************************************************
# Generating uses for question: I feel like my basic needs are met.
# Added uses to labeled question: I feel like my basic needs are met.
# Added explain to labeled question: I feel like my basic needs are met.
# **************************************************
# **************************************************
# Generating uses for question: I like to read.
# Added uses to labeled question: I like to read.
# Added explain to labeled question: I like to read.
# **************************************************
# **************************************************
# Generating uses for question: What is your race?
# Added uses to labeled question: What is your race?
# Added explain to labeled question: What is your race?
# **************************************************
# **************************************************
# Generating uses for question: From which socio-economic group would you consider your family to be?
# Added uses to labeled question: From which socio-economic group would you consider your family to be?
# Added explain to labeled question: From which socio-economic group would you consider your family to be?
# **************************************************
# **************************************************
# Generating uses for question: What are your living arrangements?
# Added uses to labeled question: What are your living arrangements?
# Added explain to labeled question: What are your living arrangements?
# **************************************************
# **************************************************
# Generating uses for question: Are you currently in a relationship?
# Added uses to labeled question: Are you currently in a relationship?
# Added explain to labeled question: Are you currently in a relationship?
# **************************************************
# **************************************************
# Generating uses for question: I worry about my finances.
# Added uses to labeled question: I worry about my finances.
# Added explain to labeled question: I worry about my finances.
# **************************************************
# **************************************************
# Generating uses for question: Did either of your parents (including step parents/guardian) complete university?
# Added uses to labeled question: Did either of your parents (including step parents/guardian) complete university?
# Added explain to labeled question: Did either of your parents (including step parents/guardian) complete university?
# **************************************************
# **************************************************
# Generating uses for question: Are you currently in a romantic relationship?
# Added uses to labeled question: Are you currently in a romantic relationship?
# Added explain to labeled question: Are you currently in a romantic relationship?
# **************************************************
# **************************************************
# Generating uses for question: Do you have children?
# Added uses to labeled question: Do you have children?
# Added explain to labeled question: Do you have children?
# **************************************************
# **************************************************
# Generating uses for question: Faith is important to me.
# Added uses to labeled question: Faith is important to me.
# Added explain to labeled question: Faith is important to me.
# **************************************************
# **************************************************
# Generating uses for question: I have a safe place to live.
# Added uses to labeled question: I have a safe place to live.
# Added explain to labeled question: I have a safe place to live.
# **************************************************
# **************************************************
# Generating uses for question: What is your gender?
# Added uses to labeled question: What is your gender?
# Added explain to labeled question: What is your gender?
# **************************************************
# **************************************************
# Generating uses for question: How old are you?
# Added uses to labeled question: How old are you?
# Added explain to labeled question: How old are you?
# **************************************************
# **************************************************
# Generating uses for question: Are you currently employed?
# Added uses to labeled question: Are you currently employed?
# Added explain to labeled question: Are you currently employed?
# **************************************************
# **************************************************
# Generating uses for question: How many hours per week do you work?
# Added uses to labeled question: How many hours per week do you work?
# Added explain to labeled question: How many hours per week do you work?
# **************************************************
# **************************************************
# Generating uses for question: Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?
# Added uses to labeled question: Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?
# Added explain to labeled question: Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?
# **************************************************
# **************************************************
# Generating uses for question: Which of these learning preferences work best for you?
# Added uses to labeled question: Which of these learning preferences work best for you?
# Added explain to labeled question: Which of these learning preferences work best for you?
# **************************************************
# **************************************************
# Generating uses for question: Have you had any significant problems with mental health in the past?
# Added uses to labeled question: Have you had any significant problems with mental health in the past?
# Added explain to labeled question: Have you had any significant problems with mental health in the past?
# **************************************************
# **************************************************
# Generating uses for question: Have you had any significant problems with depression in the past?
# Added uses to labeled question: Have you had any significant problems with depression in the past?
# Added explain to labeled question: Have you had any significant problems with depression in the past?
# **************************************************
# **************************************************
# Generating uses for question: Have you had any significant problems with anxiety in the past?
# Added uses to labeled question: Have you had any significant problems with anxiety in the past?
# Added explain to labeled question: Have you had any significant problems with anxiety in the past?
# **************************************************
# **************************************************
# Generating uses for question: If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.
# Added uses to labeled question: If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.
# Added explain to labeled question: If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.
# **************************************************
# **************************************************
# Generating uses for question: If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.
# Added uses to labeled question: If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.
# Added explain to labeled question: If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.
# **************************************************
# **************************************************
# Generating uses for question: I take steps to work on my mental health regularly.
# Added uses to labeled question: I take steps to work on my mental health regularly.
# Added explain to labeled question: I take steps to work on my mental health regularly.
# **************************************************
# **************************************************
# Generating uses for question: What country were you born in?
# Added uses to labeled question: What country were you born in?
# Added explain to labeled question: What country were you born in?
# **************************************************
# **************************************************
# Generating uses for question: What activities do you do?
# Added uses to labeled question: What activities do you do?
# Added explain to labeled question: What activities do you do?
# **************************************************
# **************************************************
# Generating uses for question: Is there anything else you'd like to tell us that may help us help you?
# Added uses to labeled question: Is there anything else you'd like to tell us that may help us help you?
# Added explain to labeled question: Is there anything else you'd like to tell us that may help us help you?
# **************************************************
# **************************************************
# Generating uses for question: I worry about my physical health
# Added uses to labeled question: I worry about my physical health
# Added explain to labeled question: I worry about my physical health
# **************************************************
# **************************************************
# Generating uses for question: My physical health is out of control
# Added uses to labeled question: My physical health is out of control
# Added explain to labeled question: My physical health is out of control
# **************************************************
# **************************************************
# Generating uses for question: The people I care about take good care of their physical health.
# Added uses to labeled question: The people I care about take good care of their physical health.
# Added explain to labeled question: The people I care about take good care of their physical health.
# **************************************************
# **************************************************
# Generating uses for question: Would you say you have a healthy diet?
# Added uses to labeled question: Would you say you have a healthy diet?
# Added explain to labeled question: Would you say you have a healthy diet?
# **************************************************
# **************************************************
# Generating uses for question: How intense are your exercise sessions?
# Added uses to labeled question: How intense are your exercise sessions?
# Added explain to labeled question: How intense are your exercise sessions?
# **************************************************
# **************************************************
# Generating uses for question: I have access to healthy food.
# Added uses to labeled question: I have access to healthy food.
# Added explain to labeled question: I have access to healthy food.
# **************************************************
# **************************************************
# Generating uses for question: How often do you exercise?
# Added uses to labeled question: How often do you exercise?
# Added explain to labeled question: How often do you exercise?
# **************************************************
# **************************************************
# Generating uses for question: On average, how many hours do you sleep in each 24-hour period?
# Added uses to labeled question: On average, how many hours do you sleep in each 24-hour period?
# Added explain to labeled question: On average, how many hours do you sleep in each 24-hour period?
# **************************************************
# **************************************************
# Generating uses for question: If you have a physical disability, please select any category(ies) your physical disability falls into.
# Added uses to labeled question: If you have a physical disability, please select any category(ies) your physical disability falls into.
# Added explain to labeled question: If you have a physical disability, please select any category(ies) your physical disability falls into.
# **************************************************
# **************************************************
# Generating uses for question: I get as much sleep as I need.
# Added uses to labeled question: I get as much sleep as I need.
# Added explain to labeled question: I get as much sleep as I need.
# **************************************************
# **************************************************
# Generating uses for question: Is your diet healthy?
# Added uses to labeled question: Is your diet healthy?
# Added explain to labeled question: Is your diet healthy?
# **************************************************
# **************************************************
# Generating uses for question: Do you feel confident in your resume?
# Added uses to labeled question: Do you feel confident in your resume?
# Added explain to labeled question: Do you feel confident in your resume?
# **************************************************
# **************************************************
# Generating uses for question: Do you feel confident writing a cover letter?
# Added uses to labeled question: Do you feel confident writing a cover letter?
# Added explain to labeled question: Do you feel confident writing a cover letter?
# **************************************************
# **************************************************
# Generating uses for question: Do you know what job you should work toward?
# Added uses to labeled question: Do you know what job you should work toward?
# Added explain to labeled question: Do you know what job you should work toward?
# **************************************************
# **************************************************
# Generating uses for question: Do you know how to identify an organization that's a good fit for you?
# Added uses to labeled question: Do you know how to identify an organization that's a good fit for you?
# Added explain to labeled question: Do you know how to identify an organization that's a good fit for you?
# **************************************************
# **************************************************
# Generating uses for question: I know what types of disability accommodations will support me.
# Added uses to labeled question: I know what types of disability accommodations will support me.
# Added explain to labeled question: I know what types of disability accommodations will support me.
# **************************************************
# **************************************************
# Generating uses for question: I know when to disclose my disability.
# Added uses to labeled question: I know when to disclose my disability.
# Added explain to labeled question: I know when to disclose my disability.
# **************************************************
# **************************************************
# Generating uses for question: I know how to create a disability accommodations plan with an employer.
# Added uses to labeled question: I know how to create a disability accommodations plan with an employer.
# Added explain to labeled question: I know how to create a disability accommodations plan with an employer.
# **************************************************
# **************************************************
# Generating uses for question: I feel overwhelmed by my need to find a job.
# Added uses to labeled question: I feel overwhelmed by my need to find a job.
# Added explain to labeled question: I feel overwhelmed by my need to find a job.
# **************************************************
# **************************************************
# Generating uses for question: When I look at a job description, I often feel I'm not qualified.
# Added uses to labeled question: When I look at a job description, I often feel I'm not qualified.
# Added explain to labeled question: When I look at a job description, I often feel I'm not qualified.
# **************************************************
# **************************************************
# Generating uses for question: I am comfortable and competent using a computer.
# Added uses to labeled question: I am comfortable and competent using a computer.
# Added explain to labeled question: I am comfortable and competent using a computer.
# **************************************************
# **************************************************
# Generating uses for question: I am comfortable and competent using apps on smartphones.
# Added uses to labeled question: I am comfortable and competent using apps on smartphones.
# Added explain to labeled question: I am comfortable and competent using apps on smartphones.
# **************************************************
# **************************************************
# Generating uses for question: I feel connected to the university
# Added uses to labeled question: I feel connected to the university
# Added explain to labeled question: I feel connected to the university
# **************************************************
# **************************************************
# Generating uses for question: What year of university are you in?
# Added uses to labeled question: What year of university are you in?
# Added explain to labeled question: What year of university are you in?
# **************************************************
# **************************************************
# Generating uses for question: I am satisfied with my experience at university so far.
# Added uses to labeled question: I am satisfied with my experience at university so far.
# Added explain to labeled question: I am satisfied with my experience at university so far.
# **************************************************
# **************************************************
# Generating uses for question: I am satisfied with the support I have been offered by the university.
# Added uses to labeled question: I am satisfied with the support I have been offered by the university.
# Added explain to labeled question: I am satisfied with the support I have been offered by the university.
# **************************************************
# **************************************************
# Generating uses for question: How do you get to campus?
# Added uses to labeled question: How do you get to campus?
# Added explain to labeled question: How do you get to campus?
# **************************************************
# **************************************************
# Generating uses for question: Would you be interested in accessing resources and learning more about any of the following?
# Added uses to labeled question: Would you be interested in accessing resources and learning more about any of the following?
# Added explain to labeled question: Would you be interested in accessing resources and learning more about any of the following?
# **************************************************
# **************************************************
# Generating uses for question: I feel overwhelmed by university life.
# Added uses to labeled question: I feel overwhelmed by university life.
# Added explain to labeled question: I feel overwhelmed by university life.
# **************************************************
# **************************************************
# Generating uses for question: I feel like I belong at university.
# Added uses to labeled question: I feel like I belong at university.
# Added explain to labeled question: I feel like I belong at university.
# **************************************************
# **************************************************
# Generating uses for question: What program are you currently enrolled in?
# Added uses to labeled question: What program are you currently enrolled in?
# Added explain to labeled question: What program are you currently enrolled in?
# **************************************************
# **************************************************
# Generating uses for question: Do you feel comfortable doing a job interview?
# Added uses to labeled question: Do you feel comfortable doing a job interview?
# Added explain to labeled question: Do you feel comfortable doing a job interview?
# **************************************************
# Total Cost: $0.00145200
# Number of Runs to Reach $1: 689
# **************************************************

# %%
pretty_print(labeled_questions)
try:
    save_data(labeled_questions, "labeled_questions")
    print("Saved labeled questions")
except:
    print("Could not save labeled questions")
    print(f"Error Message: {sys.exc_info()[0]}")
# Out:
# [
#     {
#         "text": "I care what people close to me think is best",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Relationships",
#         "label_explain": "This question is asking about the importance placed on the opinions of people who are close to the person answering the question. It relates to the dynamics and dynamics and influence in their relationships.",
#         "primary_use": "Assessing the importance placed on the opinions of people close to the user",
#         "secondary_use": "Understanding the user's decision-making process",
#         "tertiary_use": "Evaluating the user's level of independence in decision-making",
#         "primary_explain": "This question is asking about the extent to which the user values the opinions of people who are close to them. It provides insights into the importance the user gives to the perspectives and input of their loved ones when making decisions.",
#         "secondary_explain": "By understanding how much the user cares about the opinions of people close to them, we can gain insights into their decision-making process. If they strongly care about what others think, they may consider their opinions heavily in their decision-making. On the other hand, if they don't care much, they may have a more independent decision-making style.",
#         "tertiary_explain": "Additionally, the user's response to this question can provide an indication of their level of independence in decision-making. If they strongly agree, they may rely heavily on others for guidance and decision-making. If they strongly disagree, they may have a strong sense of autonomy and rely primarily on their own judgment."
#     },
#     {
#         "text": "I sympathize with others\u2019 feelings.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Empathy",
#         "label_explain": "This question is about the respondent's capacity to understand and share the feelings of others, indicating their level of empathy.",
#         "primary_use": "Assessing the level of empathy of the respondent.",
#         "secondary_use": "Understanding the respondent's ability to understand and connect with others emotionally.",
#         "tertiary_use": "Gaining insights into the respondent's interpersonal skills and emotional intelligence.",
#         "primary_explain": "This question is designed to gauge the respondent's capacity to understand and share the feelings of others, indicating their level of empathy. Empathy plays a crucial role in building strong relationships, fostering understanding, and cultivating emotional connections with others. By understanding one's level of empathy, we can gain insights into how they might respond to and interact with others in various social and personal contexts.",
#         "secondary_explain": "A person's ability to sympathize with others' feelings can provide valuable information about their emotional intelligence. It reflects their capacity to perceive and understand the emotions of others, allowing for more effective communication and connection. Empathy is a fundamental component of interpersonal relationships and is associated with positive outcomes such as increased trust, better conflict resolution, and enhanced social support.",
#         "tertiary_explain": "By assessing the respondent's level of empathy, we can gain insights into their interpersonal skills and their capacity to navigate social situations. Those who score high on this question may possess qualities such as sensitivity, compassion, and the ability to provide support to others. On the other hand, those who score low may benefit from developing their empathy skills, which can potentially enhance their relationships and overall well-being."
#     },
#     {
#         "text": "I can be pushy.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personality Traits ",
#         "label_explain": "This question is asking about the user's behavior and personality, specifically in relation to being pushy. The answer to this question will give insight into the user's tendency to assert themselves and how assertive they perceive themselves to be.",
#         "primary_use": "Assessing assertiveness level",
#         "secondary_use": "Understanding individual behavior",
#         "tertiary_use": "Identifying communication style",
#         "primary_explain": "This question is asking about the user's behavior and personality, specifically in relation to being pushy. The answer to this question will give insight into the user's tendency to assert themselves and how assertive they perceive themselves to be. By evaluating the user's response, it can provide an indication of their level of assertiveness in various situations.",
#         "secondary_explain": "Understanding an individual's behavior is essential in various contexts, such as work environments, personal relationships, and social interactions. This question helps to gauge the user's inclination towards assertiveness, which in turn helps to understand how they navigate through different situations and interact with others.",
#         "tertiary_explain": "Communication style is closely associated with assertiveness. By understanding an individual's level of assertiveness, it becomes easier to comprehend their communication style. This question can provide some insight into whether the user tends to be direct and assertive in their communication or if they are more passive and accommodating. Recognizing someone's communication style is valuable for effective communication and to tailor communication approaches to suit their preferences."
#     },
#     {
#         "text": "I follow a schedule.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Daily Routine",
#         "label_explain": "This question pertains to the individual's daily routine and how organized they are in following a schedule.",
#         "primary_use": "Assessing the user's level of organization and time management skills.",
#         "secondary_use": "Understanding the user's ability to adhere to routines and structure in their daily life.",
#         "tertiary_use": "Evaluating how the user manages their time and prioritizes tasks.",
#         "primary_explain": "The main use of this question is to gain insight into the user's level of organization and time management. By understanding if the user follows a schedule or not, we can gauge their ability to plan their day and allocate time for different tasks. This information can be useful in various contexts such as personal productivity, work performance, or overall efficiency in managing responsibilities.",
#         "secondary_explain": "Additionally, this question helps in understanding the user's inclination towards routines and structure. It provides an indication of whether they prefer a more spontaneous and flexible approach or thrive in a well-defined schedule. This insight can be relevant in areas like setting expectations, creating workflow systems, or even personal development.",
#         "tertiary_explain": "Lastly, by asking about following a schedule, we can assess how the user manages their time and prioritizes tasks. It gives an indication of their ability to allocate time effectively, set realistic goals, and maintain a balanced approach to various activities in their daily life. This understanding can be valuable in areas like time management coaching, resource allocation, or optimizing productivity routines."
#     },
#     {
#         "text": "I leave my belongings around.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Organization and Tidiness",
#         "label_explain": "This question is related to how organized and tidy a person is in terms of their belongings. It is asking whether the person tends to leave their belongings around or if they are more organized and keep their belongings in their proper place.",
#         "primary_use": "Assessing tidiness and organization habits",
#         "secondary_use": "Understanding personal living space habits",
#         "tertiary_use": "Assessing responsibility and care for personal belongings",
#         "primary_explain": "The question is used to assess a person's tidiness and organization habits. By asking whether someone tends to leave their belongings around, it gives insight into their level of organization and cleanliness. This information can be useful for understanding how someone manages their personal space and belongings.",
#         "secondary_explain": "Additionally, the question can provide insight into a person's living space habits. If someone tends to leave their belongings around, it may indicate that they have a more relaxed or casual approach to their living space. Understanding this aspect can be helpful for various scenarios, such as when organizing shared living spaces or planning events.",
#         "tertiary_explain": "Furthermore, the question can also be used to assess a person's responsibility and care for their personal belongings. If someone consistently leaves their belongings around, it may suggest a lack of attention to detail or a tendency to neglect their possessions. This information can be valuable in situations where trustworthiness and reliability are important, such as when considering roommates or potential employees."
#     },
#     {
#         "text": "I often act on the spur of the moment.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Behavior",
#         "label_explain": "This question pertains to the individual's tendency to make decisions or take actions impulsively, without much forethought or planning. It is asking about a specific aspect of personal behavior related to spontaneity and impulsivity.",
#         "primary_use": "Understanding the user's level of impulsivity and spontaneity.",
#         "secondary_use": "Assessing the user's ability to make impulsive decisions.",
#         "tertiary_use": "Identifying patterns in the user's behavior related to impulsivity.",
#         "primary_explain": "This question aims to gauge the frequency with which the user engages in impulsive actions or decisions without much prior thought or planning. By understanding the user's level of impulsivity, we can gain insights into their decision-making process and propensity for spontaneous behavior.",
#         "secondary_explain": "Additionally, this question can help assess the user's ability to make quick decisions and adapt to unexpected situations. It highlights their comfort with spontaneity and their readiness to embrace new opportunities without overthinking.",
#         "tertiary_explain": "Over time, analyzing the user's responses to this question can reveal patterns in their behavior related to impulsivity. By tracking changes in their level of spontaneity, we can gain insights into their personal growth, decision-making strategies, and potential areas for improvement."
#     },
#     {
#         "text": "I am always prepared.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Traits",
#         "label_explain": "This question is asking about the personal trait of being prepared. The answer to this question will relate to how well the person feels they are able to plan and be ready for different situations.",
#         "primary_use": "Assessing the level of preparedness.",
#         "secondary_use": "Evaluating organizational skills.",
#         "tertiary_use": "Gauging adaptability to changing situations.",
#         "primary_explain": "This question is asking about the personal trait of being prepared. The answer to this question will relate to how well the person feels they are able to plan and be ready for different situations. By understanding the individual's level of preparedness, it can provide insights into their ability to anticipate and handle various tasks and challenges effectively.",
#         "secondary_explain": "The question also indirectly assesses the individual's organizational skills. Being prepared often requires planning, prioritization, and managing resources efficiently. Therefore, the response to this question can shed light on the person's organizational abilities and their approach to structuring their daily life or work.",
#         "tertiary_explain": "Additionally, the question can provide some insight into the individual's adaptability to changing situations. The level of preparedness can indicate how well a person can quickly adjust their plans and strategies when unexpected events occur. It can show if they are comfortable with uncertainty or tend to be more rigid in their approach to situations."
#     },
#     {
#         "text": "I often forget to put things back in their proper place.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Organization/Forgetfulness",
#         "label_explain": "This question addresses an aspect of organization and forgetfulness. The user's answer will provide insight into their habits of putting things back in their proper place.",
#         "primary_use": "Assessing the user's level of forgetfulness and organization.",
#         "secondary_use": "Identifying potential causes for forgetfulness or disorganization.",
#         "tertiary_use": "Offering suggestions or strategies to improve organization and memory.",
#         "primary_explain": "This question is designed to understand the user's habits and tendencies when it comes to organizing and putting things back in their proper place. By knowing whether the user frequently forgets to do so or not, we can gain insight into their level of organization and attention to detail.",
#         "secondary_explain": "Additionally, the user's answer may shed light on potential reasons for their forgetfulness or disorganization. It could indicate factors such as stress, lack of attention, or a busy lifestyle that may contribute to the issue.",
#         "tertiary_explain": "Based on the user's response, we could provide practical suggestions or strategies to improve their organization and memory. This could include tips on creating reminders, implementing a routine, or finding organizational systems that work best for them."
#     },
#     {
#         "text": "I find it difficult to remember appointments or obligations.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Memory and Organization",
#         "label_explain": "This question pertains to an individual's ability to remember and keep track of appointments or obligations. It relates to their memory and organizational skills.",
#         "primary_use": "Assessing Memory and Organization Skills",
#         "secondary_use": "Determining Level of Difficulty with Time Management",
#         "tertiary_use": "Identifying Potential Stressors",
#         "primary_explain": "This question can be used to assess an individual's memory and organization skills. By understanding whether they find it difficult to remember appointments or obligations, we can gain insight into their ability to effectively manage their time and responsibilities.",
#         "secondary_explain": "Additionally, this question can help determine the level of difficulty an individual may have with time management. If they struggle to remember appointments or obligations, it suggests that they may face challenges in prioritizing tasks and allocating their time effectively.",
#         "tertiary_explain": "Furthermore, this question can aid in identifying potential stressors in an individual's life. Difficulty remembering appointments or obligations can contribute to feelings of being overwhelmed or anxious, highlighting potential areas for support or intervention."
#     },
#     {
#         "text": "I make careless mistakes while working on a boring or difficult project.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Productivity",
#         "label_explain": "This question falls under the label of productivity because it relates to how well the person is able to focus and perform tasks effectively during challenging or uninteresting projects.",
#         "primary_use": "Assessing Task Engagement",
#         "secondary_use": "Identifying Attentional Capacity",
#         "tertiary_use": "Evaluating Challenge Level",
#         "primary_explain": "This question can be used to assess the level of task engagement of an individual. If the person agrees that they make careless mistakes while working on a boring or difficult project, it suggests that they may have difficulty maintaining focus and attention when faced with challenging or uninteresting tasks. This information can be useful in understanding the person's overall level of engagement in their work or projects.",
#         "secondary_explain": "The question can also be used to identify the attentional capacity of an individual. If the person frequently makes careless mistakes while working on a boring or difficult project, it may indicate that their attentional resources are easily depleted or that they struggle to sustain attention for extended periods of time. This insight can be valuable in determining how to best optimize their work environment or design tasks that align with their attentional capacity.",
#         "tertiary_explain": "Additionally, this question can be used to evaluate the level of challenge provided by the project or task. If someone consistently makes careless mistakes while working on a boring or difficult project, it suggests that the project may be too challenging for their current skill level or that the task lacks sufficient engagement to maintain their interest. Understanding the challenge level can help in better matching individuals with tasks that are appropriately challenging and engaging."
#     },
#     {
#         "text": "I have trouble wrapping up the final details of a project once the challenging parts are done.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Work/Life Balance",
#         "label_explain": "This question is related to the aspect of work-life balance. It suggests difficulty in completing tasks and projects even after the challenging parts are done, indicating a potential imbalance between work and personal life.",
#         "primary_use": "Assessing Work/Life Balance",
#         "secondary_use": "Identifying Perfectionist Tendencies",
#         "tertiary_use": "Evaluating Attention to Detail",
#         "primary_explain": "This question can be used to assess the work/life balance of the individual. Their difficulty in completing the final details of a project may indicate that they are struggling to find the time or motivation to focus on these tasks, which could suggest they are prioritizing other aspects of their life over work. ",
#         "secondary_explain": "The question can also be used to identify perfectionist tendencies. If the individual finds it challenging to wrap up the final details of a project, it may suggest that they have a strong desire for perfection and struggle to let go of projects even when they are mostly complete.",
#         "tertiary_explain": "Additionally, this question can be used to evaluate attention to detail. If the individual has trouble completing the final details of a project, it may indicate that they struggle to pay attention to the smaller, finer aspects of their work. This could be important in certain fields where attention to detail is critical for success."
#     },
#     {
#         "text": "My social life is important to me",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Life",
#         "label_explain": "This question is asking about the importance of the user's social life in their life. The answer to this question will provide insight into the value the user places on their social relationships and interactions.",
#         "primary_use": "Assessing the importance of social life for the user",
#         "secondary_use": "Understanding the user's social priorities",
#         "tertiary_use": "Evaluating the user's level of social engagement",
#         "primary_explain": "This question is asking about the importance of social life in the user's life. The answer to this question will provide insight into the value the user places on their social relationships and interactions. It can help identify if the user values and prioritizes their social life as an important aspect of their overall well-being.",
#         "secondary_explain": "By understanding the importance of the user's social life, it can provide an understanding of their social priorities. This can help in tailoring recommendations or suggestions that align with their values and preferences in social activities, events, or interactions.",
#         "tertiary_explain": "The user's answer to this question can also provide an indication of their level of social engagement. A high rating on the slider (6-10) suggests that the user highly values their social life and is likely to be more socially active and engaged. Conversely, a low rating (0-4) may indicate that the user does not prioritize social interactions as much and may prefer solitary activities."
#     },
#     {
#         "text": "I like to talk with others when I'm trying to understand new things.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Interaction",
#         "label_explain": "This question is asking about the preference for engaging in conversation with others when trying to understand new things. The label \"Social Interaction\" captures the aspect of socializing and seeking help from others in the process of learning or gaining knowledge.",
#         "primary_use": "Understanding the user's preference for social interaction during the learning process.",
#         "secondary_use": "Assessing the user's willingness to seek help and engage in conversation with others.",
#         "tertiary_use": "Identifying the user's belief in the effectiveness of social interaction for learning.",
#         "primary_explain": "This question reveals whether the user prefers to engage in conversation with others when trying to understand new things. It provides insight into their inclination towards social interaction during the learning process.",
#         "secondary_explain": "By analyzing the user's response to this question, we can gauge their willingness to seek help and collaborate with others while learning. It helps us understand their openness to engaging in discussions and valuing different perspectives in the pursuit of knowledge.",
#         "tertiary_explain": "This question can also indicate the user's belief in the effectiveness of social interaction for learning. If they strongly agree, it suggests they perceive conversation and group discussion as beneficial for comprehension and acquiring new knowledge. Conversely, if they strongly disagree, it implies they favor independent learning methods over social interaction."
#     },
#     {
#         "text": "I talk to a lot of different people at social gatherings.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Social Life",
#         "label_explain": "This question relates to the social aspect of the user's life, specifically their interactions with different people at social gatherings.",
#         "primary_use": "Assessing social interaction level.",
#         "secondary_use": "Understanding social network.",
#         "tertiary_use": "Identifying extroversion level.",
#         "primary_explain": "The main use of this question is to assess the user's level of social interaction. By understanding if the user talks to a lot of different people at social gatherings, we can get an idea of how socially active they are and how comfortable they are in social settings.",
#         "secondary_explain": "Additionally, this question can help us understand the user's social network. If they talk to a lot of different people, it suggests that they have a wide network of connections and may be well-connected in their social circle.",
#         "tertiary_explain": "Lastly, this question can provide insight into the user's extroversion level. If they enjoy talking to a lot of different people at social gatherings, it indicates a preference for socializing and being around others."
#     },
#     {
#         "text": "I like being the center of attention.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Preferences",
#         "label_explain": "This question is about the individual's preference for being the center of attention. The answer to this question will reflect the individual's attitude towards being the focus of others' attention.",
#         "primary_use": "Understanding the individual's preference for being the center of attention.",
#         "secondary_use": "Evaluating the individual's level of self-confidence and extroversion.",
#         "tertiary_use": "Providing insights into the individual's willingness to take on leadership roles.",
#         "primary_explain": "This question is designed to assess the individual's preference for being the center of attention. The answer to this question will help understand whether the individual enjoys being the focus of others' attention or prefers to stay in the background.",
#         "secondary_explain": "By analyzing the answer to this question, one can also gain insights into the individual's level of self-confidence and extroversion. Those who strongly agree with the statement may have higher levels of self-confidence and enjoy social interactions, while those who strongly disagree may be more introverted and prefer to avoid attention.",
#         "tertiary_explain": "Additionally, the answer to this question can provide useful information about the individual's willingness to take on leadership roles. Those who enjoy being the center of attention may be more inclined to seek leadership positions and take charge in various situations. Conversely, those who prefer to avoid attention may be more comfortable in supportive or behind-the-scenes roles."
#     },
#     {
#         "text": "I feel I can be my most authentic self.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-Expression",
#         "label_explain": "This question is asking about the individual's ability to be true to themselves and express their authentic self. It is related to self-expression and how comfortable the person feels in being their true self.",
#         "primary_use": "Evaluating self-expression and personal authenticity.",
#         "secondary_use": "Assessing individual satisfaction and fulfillment.",
#         "tertiary_use": "Understanding personal growth and development.",
#         "primary_explain": "This question helps to gauge the extent to which an individual feels comfortable and confident in expressing their true self. It gives insight into their level of self-acceptance and authenticity in various aspects of their life, such as relationships, work, and personal pursuits.",
#         "secondary_explain": "By understanding how the user rates their ability to be authentic, we can gain insights into their overall satisfaction and fulfillment in life. Those who feel they can be their most authentic self are more likely to experience a sense of purpose and alignment with their values, leading to a higher sense of well-being.",
#         "tertiary_explain": "This question also provides valuable information about an individual's personal growth and development. If someone feels they can be their most authentic self, it suggests that they have likely done the self-reflection and introspection necessary to understand their true desires and values. It implies that they have worked on personal growth and self-acceptance, which are important factors in leading a fulfilling and meaningful life."
#     },
#     {
#         "text": "I am relaxed most of the time.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is asking about the respondent's overall level of relaxation, which is related to their mental well-being. Answering this question will provide insight into the respondent's state of mind and their ability to handle stress and anxiety.",
#         "primary_use": "Assessing mental well-being",
#         "secondary_use": "Identifying stress and anxiety levels",
#         "tertiary_use": "Understanding ability to handle challenges",
#         "primary_explain": "This question is asking about the respondent's overall level of relaxation, which is related to their mental well-being. Answering this question will provide insight into the respondent's state of mind and their ability to handle stress and anxiety. By understanding how relaxed someone is most of the time, we can gain a general understanding of their mental health and emotional stability.",
#         "secondary_explain": "In addition to assessing mental well-being, this question can also help identify stress and anxiety levels. Someone who is relaxed most of the time may have lower levels of stress and anxiety, while someone who is not relaxed most of the time may have higher levels of stress and anxiety. This information can be useful in determining potential areas of improvement or identifying individuals who may benefit from additional support or interventions.",
#         "tertiary_explain": "Another use of this question is to understand the individual's ability to handle challenges. If someone is relaxed most of the time, it suggests that they have a better capacity to manage stressors and navigate difficult situations. On the other hand, if someone is not relaxed most of the time, it may indicate that they struggle with coping mechanisms and may need assistance in developing effective stress management strategies. This understanding can help inform interventions and support systems tailored to individual needs."
#     },
#     {
#         "text": "I get stressed out easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being ",
#         "label_explain": "This question is about a person's emotional well-being and their ability to handle stress. The answer to this question will give insight into how easily someone becomes stressed and overwhelmed.",
#         "primary_use": "Understanding the user's stress levels.",
#         "secondary_use": "Assessing the user's ability to handle stress.",
#         "tertiary_use": "Identifying the user's emotional well-being.",
#         "primary_explain": "This question is designed to determine how easily the user becomes stressed. By understanding their stress levels, we can better assess their overall ability to handle difficult situations and challenges in life.",
#         "secondary_explain": "Additionally, this question can provide insight into the user's resilience and coping mechanisms. If they tend to get stressed out easily, it may indicate a need for stress management techniques or support to improve their overall well-being.",
#         "tertiary_explain": "The answer to this question can also give us a glimpse into the user's emotional well-being. If they consistently get stressed out easily, it may suggest that they are experiencing higher levels of stress and potentially impacting their mental health. Understanding this can help us provide appropriate resources or recommendations for support."
#     },
#     {
#         "text": "I change my mood a lot.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question relates to the individual's emotional well-being as it explores how frequently their mood changes.",
#         "primary_use": "Assessing the user's emotional stability.",
#         "secondary_use": "Identifying potential mental health issues.",
#         "tertiary_use": "Personalization of mental health support.",
#         "primary_explain": "This question is used to assess the user's emotional stability by exploring the frequency of mood changes. It provides an insight into how stable or unstable the user's emotions are on a day-to-day basis. This can help in understanding the user's emotional well-being and overall mental health status.",
#         "secondary_explain": "The response to this question can also provide information about potential mental health issues. If the user consistently indicates high levels of mood fluctuations, it may suggest the presence of mood disorders such as bipolar disorder or borderline personality disorder. This can help in early identification and intervention for such conditions.",
#         "tertiary_explain": "The user's response to this question can be used to personalize mental health support. If the user reports frequent mood changes, mental health interventions can be tailored to address emotional regulation, coping mechanisms, and stress management. It can help clinicians or mental health professionals to devise strategies that specifically target the user's needs, improving the effectiveness of the support provided."
#     },
#     {
#         "text": "I see myself as someone who has high self-esteem.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-Perception",
#         "label_explain": "This question pertains to an individual's perception of their own self-esteem. It relates to how they view themselves and their confidence level.",
#         "primary_use": "Assessing self-perception of self-esteem.",
#         "secondary_use": "Identifying potential areas of self-improvement.",
#         "tertiary_use": "Understanding how self-esteem may impact various aspects of life.",
#         "primary_explain": "This question is designed to assess an individual's perception of their own self-esteem. By asking how someone sees themselves in terms of self-esteem, it provides insight into their level of confidence and self-worth. This information can be useful in understanding their overall self-perception and how they may navigate different situations.",
#         "secondary_explain": "In addition to assessing self-perception, this question can also highlight areas where individuals may need to work on improving their self-esteem. If someone rates themselves low in terms of self-esteem, it may indicate that they struggle with confidence or have negative self-beliefs that could be addressed through self-development and personal growth.",
#         "tertiary_explain": "Understanding an individual's self-esteem can have broad implications in various aspects of their life. Self-esteem plays a role in relationships, career choices, decision-making, and mental well-being. By knowing an individual's self-perception of self-esteem, it can provide insights into how they may approach these different areas and what support or resources they may need to bolster their self-esteem."
#     },
#     {
#         "text": "I get irritated easily.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions",
#         "label_explain": "This question is asking about the user's tendency to get easily irritated, which falls under the broad category of emotions.",
#         "primary_use": "Understanding the user's tendency to get easily irritated.",
#         "secondary_use": "Identifying potential triggers or factors contributing to the user's irritability.",
#         "tertiary_use": "Assessing the user's emotional well-being.",
#         "primary_explain": "The main use of this question is to gain an understanding of the user's tendency to get easily irritated. By assessing their irritability levels, we can better understand their emotional state and potential challenges they may face in managing their emotions.",
#         "secondary_explain": "In addition to understanding the user's irritability levels, this question can provide insights into potential triggers or factors that contribute to their irritability. This information can be helpful in identifying situations or circumstances that may need to be addressed or managed differently to reduce irritability.",
#         "tertiary_explain": "This question also serves as a way to assess the user's overall emotional well-being. If they indicate a high level of irritability, it may indicate that they are experiencing challenges in regulating their emotions and may benefit from strategies or support to improve their emotional well-being."
#     },
#     {
#         "text": "I feel like I am in control of what happens to me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Growth",
#         "label_explain": "This question asks about the individual's perception of control over their own life and circumstances. It relates to their personal growth and self-determination.",
#         "primary_use": "Assessing the individual's perception of personal power and control.",
#         "secondary_use": "Gauging the individual's level of self-determination.",
#         "tertiary_use": "Exploring the individual's belief in their ability to influence outcomes.",
#         "primary_explain": "This question is used to understand the individual's subjective experience of control in their life. It provides insight into how much agency they perceive themselves to have in shaping their circumstances and influencing the outcomes of their actions.",
#         "secondary_explain": "By asking this question, we can gain a better understanding of the individual's level of self-determination and autonomy. It allows us to explore their sense of responsibility and power in directing their own life and making choices that align with their values and goals.",
#         "tertiary_explain": "This question also helps us assess the individual's belief in their ability to influence outcomes. It provides information about their mindset and whether they feel empowered or constrained in navigating their life circumstances and pursuing their aspirations."
#     },
#     {
#         "text": "I feel like powerful others have a lot of control over how my life will turn out.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Beliefs and Outlook",
#         "label_explain": "This question relates to an individual's perception of the influence that powerful individuals or entities have over their life outcomes. It explores their internal beliefs and outlook on the extent to which external forces can shape their life trajectory.",
#         "primary_use": "Assessing Perceived Locus of Control",
#         "secondary_use": "Understanding Personal Beliefs and Outlook",
#         "tertiary_use": "Identifying External Locus of Control",
#         "primary_explain": "This question is used to assess an individual's perceived locus of control, which refers to their belief in the amount of control they have over the outcomes in their life. By asking about the influence of powerful others on their life, we can gain insights into whether they perceive themselves as having a strong sense of control or if they believe external forces have more influence.",
#         "secondary_explain": "This question helps us understand an individual's personal beliefs and outlook. By examining their perception of the control exerted by powerful others, we can gain insight into how they view external influences on their life outcomes. It can provide a glimpse into their overall worldview and whether they tend to attribute success or failure to themselves or external factors.",
#         "tertiary_explain": "The question also helps us identify individuals who may have an external locus of control, meaning they believe that powerful others or external circumstances have significant control over their life outcomes. Understanding this propensity towards external control can help tailor interventions or support systems to empower individuals and foster a greater sense of personal agency and control."
#     },
#     {
#         "text": "I worry about making mistakes.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Mental Health",
#         "label_explain": "This question is related to the individual's mental health as it addresses their propensity to worry about making mistakes.",
#         "primary_use": "Assessing the user's level of anxiety or stress related to making mistakes.",
#         "secondary_use": "Identifying the user's self-confidence and perfectionistic tendencies.",
#         "tertiary_use": "Evaluating the user's potential for self-criticism and fear of judgment.",
#         "primary_explain": "This question is designed to gauge the user's level of concern or anxiety when it comes to making mistakes. By understanding the extent to which the user worries about making mistakes, it can provide insights into their overall mental well-being and potentially uncover underlying anxiety or stress-related issues.",
#         "secondary_explain": "The user's response to this question can also reveal their self-confidence and perfectionistic tendencies. Those who strongly agree or disagree with the statement may exhibit traits associated with perfectionism, where they may constantly strive for perfection or may avoid taking risks altogether.",
#         "tertiary_explain": "Additionally, the user's response to this question can shed light on their self-critical tendencies and fear of judgment. Those who express a high level of worry about making mistakes may have a tendency to be overly self-critical and fear the judgment or criticism of others. This information can be useful in understanding how the user perceives themselves and how they may react in situations where mistakes are made."
#     },
#     {
#         "text": "Criticism hurts me.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being ",
#         "label_explain": "This question is related to how criticism affects the emotional well-being of the individual.",
#         "primary_use": "Understanding the impact of criticism on the user's emotional well-being.",
#         "secondary_use": "Identifying the user's vulnerability to criticism.",
#         "tertiary_use": "Assessing the user's coping mechanisms for dealing with criticism.",
#         "primary_explain": "This question can help us understand how criticism affects the emotional well-being of the individual. By analyzing the user's response, we can gain insights into whether criticism has a negative or positive impact on their overall well-being.",
#         "secondary_explain": "Additionally, the user's response to this question can indicate their level of vulnerability to criticism. Those who strongly agree that criticism hurts them may be more sensitive to negative feedback, while those who strongly disagree may be more resilient.",
#         "tertiary_explain": "Furthermore, the user's answer can provide insights into their coping mechanisms for dealing with criticism. If they indicate that criticism has a strong negative impact on them, it suggests that they may struggle with managing and processing criticisms effectively."
#     },
#     {
#         "text": "I feel worried when somebody is angry.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotions and Reactions",
#         "label_explain": "This question is asking about the user's emotional response to someone expressing anger. It falls under the category of emotions and reactions because it relates to how the user feels in response to a specific situation.",
#         "primary_use": "Understanding the user's emotional response to anger.",
#         "secondary_use": "Assessing the user's level of empathy.",
#         "tertiary_use": "Identifying potential triggers for the user's worry.",
#         "primary_explain": "This question is used to gain insight into the user's emotional response to someone expressing anger. It helps understand how the user feels when others are angry, providing valuable information about their emotional sensitivity and empathy towards others.",
#         "secondary_explain": "By assessing the user's level of worry when somebody is angry, this question can provide a glimpse into the user's empathetic nature. It indicates whether the user is highly attuned to the emotions of those around them or if they are less affected by others' anger.",
#         "tertiary_explain": "Additionally, analyzing the user's response to this question can help identify potential triggers for their worry. For example, if the user consistently feels worried when somebody is angry, it may suggest that they have experienced uncomfortable or distressing situations in the past when others were angry. Understanding these triggers can help in creating a supportive and comfortable environment for the user."
#     },
#     {
#         "text": "I have very few fears compared to my friends.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Personal Traits/Qualities",
#         "label_explain": "This question asks about the level of fears compared to friends. It relates to the personal traits or qualities of the individual and how they perceive their fears in comparison to others.",
#         "primary_use": "Understanding the level of fear in relation to friends",
#         "secondary_use": "Assessing personal perception of fear",
#         "tertiary_use": "Comparing personal traits with friends",
# ...
#         "label_explain": "The question is asking about the individual's level of satisfaction with their experience at university. The answer to this question will provide insight into how the individual feels about their overall experience at university.",
#         "primary_use": "Measuring satisfaction with university experience",
#         "secondary_use": "Evaluating the effectiveness of university programs and services",
#         "tertiary_use": "Identifying areas of improvement in the university experience",
#         "primary_explain": "The main use of this question is to measure the satisfaction level of the individual with their experience at university. By collecting responses on a slider ranging from negative to positive, we can understand whether the individual is generally satisfied or dissatisfied with their university experience. This information can be used to gauge overall student satisfaction and identify any areas where improvements may be needed.",
#         "secondary_explain": "In addition to gauging individual satisfaction, the question can also be used to evaluate the effectiveness of university programs and services. If a high percentage of students indicate satisfaction, it suggests that the university is meeting the needs and expectations of its students. On the other hand, if a significant number of students express dissatisfaction, it may indicate areas where programs and services need to be improved or revamped.",
#         "tertiary_explain": "The tertiary use of this question is to identify specific areas of improvement in the university experience. By analyzing the responses and looking at the distribution of satisfaction levels, patterns can emerge regarding which aspects of the university experience are most satisfying or dissatisfying for students. This information can then be used to prioritize and address areas where improvements are needed, whether it's in academics, campus facilities, student support services, or other areas."
#     },
#     {
#         "text": "I am satisfied with the support I have been offered by the university.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "University Support Satisfaction",
#         "label_explain": "This question pertains to the satisfaction level of the support provided by the university.",
#         "primary_use": "Measuring user satisfaction with university support.",
#         "secondary_use": "Identifying areas of improvement in university support.",
#         "tertiary_use": "Evaluating the effectiveness of university support programs.",
#         "primary_explain": "The main use of this question is to measure user satisfaction with the support provided by the university. By analyzing the responses on the 11-pt slider, we can gain insights into how satisfied the users are with the support they have received.",
#         "secondary_explain": "The secondary use of this question is to identify areas of improvement in university support. If a significant number of users express dissatisfaction through their responses, it indicates that there might be issues or gaps in the support services provided by the university.",
#         "tertiary_explain": "The tertiary use of this question is to evaluate the effectiveness of university support programs. By comparing the satisfaction levels of different users, we can assess the impact and success of various support initiatives implemented by the university. This can lead to further improvements and enhancements in the support services."
#     },
#     {
#         "text": "How do you get to campus?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Transportation",
#         "label_explain": "This question is related to transportation and asks how someone typically gets to campus.",
#         "primary_use": "Understanding transportation options and preferences.",
#         "secondary_use": "Gathering demographic information about transportation habits.",
#         "tertiary_use": "Assessing the effectiveness and accessibility of transportation infrastructure.",
#         "primary_explain": "The main use of this question is to understand the transportation methods that individuals use to get to campus. By asking this question, we can collect valuable information about the different modes of transportation people utilize, such as walking, biking, driving, taking public transportation, or carpooling. This can help in evaluating the availability and effectiveness of various transportation options and identifying areas for improvement.",
#         "secondary_explain": "The secondary use of this question is to gather demographic information about transportation habits. By analyzing the responses to this question, we can gain insights into the transportation preferences and behaviors of different demographics. For example, we can determine if there are any variations based on age, gender, or location. This information can be useful in developing targeted transportation initiatives or tailoring transportation services to specific groups.",
#         "tertiary_explain": "The tertiary use of this question is to assess the effectiveness and accessibility of transportation infrastructure. By understanding how people get to campus, we can evaluate the existing transportation infrastructure and identify any potential issues or areas of improvement. For instance, if a majority of people drive to campus, it may indicate a need for additional parking facilities. If public transportation is the preferred mode, it may highlight the need for better transit connectivity or increased frequency of service. This information can inform urban planning decisions and contribute to creating a more efficient and sustainable transportation system."
#     },
#     {
#         "text": "Would you be interested in accessing resources and learning more about any of the following?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Personal Interests",
#         "label_explain": "This question is asking about the user's personal interests and what resources they would like to access for further learning.",
#         "primary_use": "Understanding the user's interests and areas of curiosity.",
#         "secondary_use": "Tailoring recommendations and content to the user's preferences.",
#         "tertiary_use": "Collecting demographic information for analysis and targeting.",
#         "primary_explain": "This question is designed to understand the user's interests and what they would like to learn more about. By knowing the topics or areas they are interested in, we can provide them with relevant resources and recommendations to further their learning. This helps personalize their experience and ensures they receive information that aligns with their interests.",
#         "secondary_explain": "In addition to understanding the user's interests, this question can also be used to tailor recommendations and content to their preferences. By identifying the topics they are interested in, we can suggest relevant resources, articles, courses, or events that match their interests. This improves user engagement and satisfaction with the content being offered.",
#         "tertiary_explain": "Another use of this question is to collect demographic information for analysis and targeting purposes. By knowing what resources and topics different demographics are interested in, we can create targeted marketing campaigns, identify trends, and make data-driven decisions to better serve our users. This helps us understand the preferences and needs of different user segments, allowing us to improve our offerings and reach a wider audience."
#     },
#     {
#         "text": "I feel overwhelmed by university life.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Emotional Well-being",
#         "label_explain": "This question is related to the emotional well-being of the user. It is asking about their feelings of being overwhelmed specifically in the context of university life.",
#         "primary_use": "Assessing the user's emotional well-being.",
#         "secondary_use": "Identifying potential stressors or challenges in university life.",
#         "tertiary_use": "Determining the need for support or resources.",
#         "primary_explain": "This question is used to understand the user's emotional well-being specifically in the context of university life. It aims to assess if the user feels overwhelmed by the demands and challenges they are facing as a student.",
#         "secondary_explain": "By asking this question, we can gain insights into the specific stressors or challenges that university life may be presenting to the user. This can help us better understand their overall experience and identify areas where additional support or resources may be beneficial.",
#         "tertiary_explain": "The user's response to this question can also help determine if they need any immediate support or resources to cope with the feelings of overwhelm. It can inform interventions or strategies to help them manage their university life and improve their overall well-being."
#     },
#     {
#         "text": "I feel like I belong at university.",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Self-perception",
#         "label_explain": "This question is related to the individual's perception of their sense of belonging at university. The answer to this question will provide insight into how the individual feels about their connection to the university environment.",
#         "primary_use": "Gauge self-perception of sense of belonging",
#         "secondary_use": "Assess overall satisfaction with university experience",
#         "tertiary_use": "Determine potential areas for improvement in the university environment",
#         "primary_explain": "This question is used to gauge the individual's self-perception of their sense of belonging at university. By providing an answer on the 11-point slider, ranging from negative to positive, it allows the individual to express their level of agreement or disagreement with the statement. This information can be valuable in understanding how the individual feels about their connection to the university environment.",
#         "secondary_explain": "In addition to understanding the individual's self-perception, the answer to this question can also provide insight into their overall satisfaction with their university experience. Those who strongly agree with the statement may feel a strong sense of belonging, suggesting a positive university experience, while those who strongly disagree may feel disconnected or dissatisfied.",
#         "tertiary_explain": "Furthermore, the question response can help identify potential areas for improvement in the university environment. If a significant number of individuals indicate a low sense of belonging, it could indicate that steps need to be taken to foster a more inclusive and supportive atmosphere, such as improving campus activities, implementing mentorship programs, or offering support services."
#     },
#     {
#         "text": "What program are you currently enrolled in?",
#         "answer_type": "open-ended, question_text is representative of how the user will answer",
#         "label": "Education",
#         "label_explain": "This question is related to the educational aspect of someone's life. The answer will provide information about the specific program or course the person is currently involved in.",
#         "primary_use": "Gathering information about the user's educational program.",
#         "secondary_use": "Assessing the user's educational background and interests.",
#         "tertiary_use": "Providing personalized recommendations or assistance related to the user's program.",
#         "primary_explain": "The main use of this question is to gather information about the user's educational program. By asking this question, we can learn about the specific program or course the person is currently enrolled in. This information can be useful for various purposes, such as understanding the user's educational background, tailoring recommendations or assistance related to their program, or identifying common interests among users in similar programs.",
#         "secondary_explain": "In addition to gathering information about the user's program, this question can also provide insights into the user's educational background and interests. Knowing the program the user is enrolled in can give us a glimpse into their academic pursuits and areas of expertise. This information can be helpful for various secondary purposes, such as targeting relevant educational resources, identifying potential mentorship opportunities, or understanding the user's career aspirations.",
#         "tertiary_explain": "Furthermore, knowing the user's program can enable us to provide personalized recommendations or assistance related to their program. For example, if the user is studying computer science, we can offer resources, tutorials, or mentoring opportunities specifically tailored to computer science students. This personalized approach can enhance the user's learning experience and help them make the most of their program. Additionally, by analyzing common programs among users, we can identify trends or patterns that might inform the development of new educational resources or initiatives."
#     },
#     {
#         "text": "Do you feel comfortable doing a job interview?",
#         "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#         "label": "Job/Work",
#         "label_explain": "This question is asking about the user's comfort level in completing a specific task related to their job or work.",
#         "primary_use": "Assessing the user's confidence level in job interviews.",
#         "secondary_use": "Determining the user's level of preparedness for job interviews.",
#         "tertiary_use": "Providing opportunities for improvement in job interview skills.",
#         "primary_explain": "The main use of this question is to assess the user's comfort level in job interviews. This can provide valuable information about their confidence and ability to handle job interviews effectively. Depending on their response, further support and guidance can be provided to enhance their interview skills and boost their chances of success.",
#         "secondary_explain": "The secondary use of this question is to determine the user's level of preparedness for job interviews. If the user expresses discomfort or a lack of confidence, it may indicate that they need additional support and preparation to improve their interview skills. This can help guide the development of resources and strategies aimed at helping them feel more comfortable and confident during job interview situations.",
#         "tertiary_explain": "The tertiary use of this question is to provide opportunities for improvement in job interview skills. If the user indicates a lower comfort level, it can serve as a starting point for identifying areas where they may need assistance. This can include offering interview practice sessions, providing resources on interview techniques, or recommending workshops or courses focused on improving interview skills. By addressing any discomfort or lack of confidence, the user can enhance their job interview performance and increase their chances of securing employment."
#     }
# ]
# Saved labeled questions

# %%
def labeled_question_len(array):
    count = 0
    for question in array:
        if question['primary_use'] != "":
            count += 1
    return count

print(f"{labeled_question_len(labeled_questions)} out of {len(questions)} questions labeled")
# Out:
# 108 out of 108 questions labeled

# %% [markdown]
# #### Specific Question Uses Generation

# %%
# Example of generating uses for a question - THIS CELL COSTS MONEY TO RUN (PROMPT #2)
# Runtime is 30s-1min
ex_q = labeled_questions[0]
ex_output = gpt_question_uses_prompt(ex_q['text'], ex_q['answer_type'], ex_q['label'], ex_q['label_explain'])
# Out:
# Running Function - Usage: CompletionUsage(completion_tokens=204, prompt_tokens=555, total_tokens=759)

# %%
print(ex_output)
# Out:
# Question Text: How do you get to campus?
# Question Main Use: Gathering information about transportation methods to campus.
# Question Secondary Use: Understanding commuting patterns and transportation preferences.
# Question Tertiary Use: Identifying potential environmental impact and sustainability efforts.
# Main Explanation: The main use of this question is to gather information about the different transportation methods individuals use to commute to campus. This can provide insights into the overall transportation infrastructure and needs of the campus community.
# Secondary Explanation: By understanding how people get to campus, institutions can analyze commuting patterns and preferences. This information can be used to optimize transportation services, improve accessibility, and plan for future infrastructure developments. It can also help identify potential challenges or bottlenecks in transportation systems that need to be addressed.
# Tertiary Explanation: This question can provide valuable data for assessing the environmental impact of commuting to campus. By understanding the transportation choices people make, institutions can design initiatives and programs to promote more sustainable commuting options, reduce carbon emissions, and encourage alternative transportation methods such as cycling or public transit.

# %%
p,s,t,pe,se,te = parse_uses_output(ex_output)

add_uses_to_labeled_question(ex_q['text'], p, s, t)
add_explain_to_labeled_question(ex_q['text'], pe, se, te)

pretty_print(labeled_questions)
# Out:
# Added uses to labeled question: How do you get to campus?
# Added explain to labeled question: How do you get to campus?
# [
#     {
#         "text": "How do you get to campus?",
#         "answer_type": "multiple choice, question_text is representative of the choices, typically provides demographic information",
#         "label": "Transportation",
#         "label_explain": "I chose the label \"Transportation\" for this question because it pertains to how someone travels to campus. The answer to this question would provide insight into the different transportation methods used by individuals to commute to the campus.",
#         "primary_use": "Gathering information about transportation methods to campus.",
#         "secondary_use": "Understanding commuting patterns and transportation preferences.",
#         "tertiary_use": "Identifying potential environmental impact and sustainability efforts.",
#         "primary_explain": "The main use of this question is to gather information about the different transportation methods individuals use to commute to campus. This can provide insights into the overall transportation infrastructure and needs of the campus community.",
#         "secondary_explain": "By understanding how people get to campus, institutions can analyze commuting patterns and preferences. This information can be used to optimize transportation services, improve accessibility, and plan for future infrastructure developments. It can also help identify potential challenges or bottlenecks in transportation systems that need to be addressed.",
#         "tertiary_explain": "This question can provide valuable data for assessing the environmental impact of commuting to campus. By understanding the transportation choices people make, institutions can design initiatives and programs to promote more sustainable commuting options, reduce carbon emissions, and encourage alternative transportation methods such as cycling or public transit."
#     }
# ]

# %% [markdown]
# ---
# ## Second Pipeline: Generate Personalized Response to User's Question Answers

# %% [markdown]
# #### Example Set of User Answers

# %%
## All answers are ~ 2000 tokens long
## https://platform.openai.com/tokenizer

user_answers['kbrait']
# Out:
# {'I care what people close to me think is best': '1, (Yes)',
#  'I sympathize with others’ feelings.': '3, (YesYesYes)',
#  'I can be pushy.': '3, (YesYesYes)',
#  'I follow a schedule.': '-4, (NoNoNoNo)',
#  'I leave my belongings around.': '1, (Yes)',
#  'I often act on the spur of the moment.': '5, (YesYesYesYesYes)',
#  'I am always prepared.': '4, (YesYesYesYes)',
#  'I often forget to put things back in their proper place.': '0, (Indifferent)',
#  'I find it difficult to remember appointments or obligations.': '-2, (NoNo)',
#  'I make careless mistakes while working on a boring or difficult project.': '1, (Yes)',
#  'I have trouble wrapping up the final details of a project once the challenging parts are done.': '3, (YesYesYes)',
#  "I like to talk with others when I'm trying to understand new things.": '4, (YesYesYesYes)',
#  'I talk to a lot of different people at social gatherings.': '4, (YesYesYesYes)',
#  'I like being the center of attention.': '3, (YesYesYes)',
#  'I am relaxed most of the time.': '-2, (NoNo)',
#  'I get stressed out easily.': '-2, (NoNo)',
#  'I change my mood a lot.': '3, (YesYesYes)',
#  'I see myself as someone who has high self-esteem.': '5, (YesYesYesYesYes)',
#  'I get irritated easily.': '3, (YesYesYes)',
#  'I feel like I am in control of what happens to me.': '4, (YesYesYesYes)',
#  'I feel like powerful others have a lot of control over how my life will turn out.': '0, (Indifferent)',
#  'I worry about making mistakes.': '-1, (No)',
#  'Criticism hurts me.': '-4, (NoNoNoNo)',
#  'I feel worried when somebody is angry.': '-5, (NoNoNoNoNo)',
#  'I have very few fears compared to my friends.': '5, (YesYesYesYesYes)',
#  'In the past two weeks, I have felt nervous, anxious or on edge.': '2, (YesYes)',
#  'In the past two weeks, I have been unable to stop or control worrying.': '2, (YesYes)',
#  'In the past two weeks, I have had trouble relaxing.': '0, (Indifferent)',
#  'In the past two weeks, I have been easily annoyed or irritable.': '1, (Yes)',
#  "I'm generally comfortable taking tests.": '3, (YesYesYes)',
#  'In the past two weeks, I have felt afraid something awful might happen.': '-4, (NoNoNoNo)',
#  'I get upset easily.': '-2, (NoNo)',
#  'I thrive in diverse environments': '0, (Indifferent)',
#  'I have a vivid imagination.': '4, (YesYesYesYes)',
#  'I enjoy thinking about things.': '5, (YesYesYesYesYes)',
#  'I believe art is important.': '3, (YesYesYes)',
#  'I like to take things apart to see how they work.': '4, (YesYesYesYes)',
#  "I'm always willing to try something new if I think it will be fun.": '5, (YesYesYesYesYes)',
#  'I like a challenge.': '4, (YesYesYesYes)',
#  'I go out of my way to get things I want.': '1, (Yes)',
#  'In the past couple of weeks, I have been fulfilling my potential.': '5, (YesYesYesYesYes)',
#  'I am easily bored.': '-1, (No)',
#  'I can easily connect with family and friends if I want.': '4, (YesYesYesYes)',
#  'I learn well in a study group.': '2, (YesYes)',
#  'In the past two weeks, I have felt so restless, it is hard to keep still.': '3, (YesYesYes)',
#  'I feel like my basic needs are met.': '-2, (NoNo)',
#  'I like to read.': '3, (YesYesYes)',
#  'My social life is important to me': '2, (YesYes)',
#  'I feel I can be my most authentic self.': '4, (YesYesYesYes)',
#  "It's important that I make my family proud of me.": '5, (YesYesYesYesYes)',
#  "I learn well when I'm alone.": '4, (YesYesYesYes)',
#  'What is your race?': 'White',
#  'What are your living arrangements?': 'Living off campus with roommate(s)',
#  'I worry about my finances.': '4, (YesYesYesYes)',
#  'Did either of your parents (including step parents/guardian) complete university?': 'Both did',
#  'Faith is important to me.': '-4, (NoNoNoNo)',
#  'I have a safe place to live.': '3, (YesYesYes)',
#  'What is your gender?': 'Male',
#  'How old are you?': '22',
#  'Are you currently employed?': '-3, (NoNoNo)',
#  'Have you had any significant problems with mental health in the past?': '3, (YesYesYes)',
#  'Have you had any significant problems with depression in the past?': '3, (YesYesYes)',
#  'Have you had any significant problems with anxiety in the past?': '5, (YesYesYesYesYes)',
#  'What country were you born in?': 'United States of America',
#  'What activities do you do?': 'Rock Climbing, Coding, Writing, Cooking, Basketball and Soccer',
#  "Is there anything else you'd like to tell us that may help us help you?": "I'd love to know if I'm a weirdo or pretty normal...",
#  'I worry about my physical health': '0, (Indifferent)',
#  'My physical health is out of control': '-3, (NoNoNo)',
#  'The people I care about take good care of their physical health.': '-4, (NoNoNoNo)',
#  'Would you say you have a healthy diet?': '1, (Yes)',
#  'I have access to healthy food.': '1, (Yes)',
#  'I get as much sleep as I need.': '4, (YesYesYesYes)',
#  'Is your diet healthy?': '3, (YesYesYes)',
#  'Do you feel confident in your resume?': '1, (Yes)',
#  'Do you know what job you should work toward?': '-2, (NoNo)',
#  'I know what types of disability accommodations will support me.': '0, (Indifferent)',
#  'I know when to disclose my disability.': '0, (Indifferent)',
#  'I know how to create a disability accommodations plan with an employer.': '0, (Indifferent)',
#  'I feel overwhelmed by my need to find a job.': '2, (YesYes)',
#  "When I look at a job description, I often feel I'm not qualified.": '-3, (NoNoNo)',
#  'I am comfortable and competent using a computer.': '5, (YesYesYesYesYes)',
#  'I am comfortable and competent using apps on smartphones.': '5, (YesYesYesYesYes)',
#  'I feel connected to the university': '1, (Yes)',
#  'What year of university are you in?': '5th or higher',
#  'I am satisfied with my experience at university so far.': '3, (YesYesYes)',
#  'I am satisfied with the support I have been offered by the university.': '-2, (NoNo)',
#  'How do you get to campus?': 'Bike',
#  'I feel overwhelmed by university life.': '-5, (NoNoNoNoNo)',
#  'What program are you currently enrolled in?': 'Computer Science',
#  'From which socio-economic group would you consider your family to be?': 'High income',
#  'Are you currently in a relationship?': 'Sort of',
#  'Are you currently in a romantic relationship?': 'Sort of',
#  'Do you have children?': 'No',
#  'How many hours per week do you work?': '10',
#  'Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?': '10hrs',
#  'Which of these learning preferences work best for you?': 'Hands-On',
#  'I take steps to work on my mental health regularly.': '2, (YesYes)',
#  'How intense are your exercise sessions?': 'Pretty intense',
#  'How often do you exercise?': '7-10 times per week',
#  'On average, how many hours do you sleep in each 24-hour period?': '7',
#  'Do you feel confident writing a cover letter?': '5, (YesYesYesYesYes)',
#  'Do you feel comfortable doing a job interview?': '0, (Indifferent)',
#  "Do you know how to identify an organization that's a good fit for you?": '-5, (NoNoNoNoNo)',
#  'If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.': 'ignore',
#  'If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.': 'ignore',
#  'If you have a physical disability, please select any category(ies) your physical disability falls into.': 'ignore',
#  'Would you be interested in accessing resources and learning more about any of the following?': 'Time management',
#  'I feel like I belong at university.': '-4, (NoNoNoNo)'}

# %% [markdown]
# #### Prompt #3: Generate Goals for the User

# %%
def gpt_goal_generator(user_answers, subset_labeled_questions):

    gpt_system_message = """
    You are going to generate a goal for a user based on their answers to questions. 
    Each question will have a label, label explanation, and three uses with explanations. 
    These are to provide context about the question and how it can help you understand their answers. 
    You must use the following template in your response: 
    goal: <goal>
    goal explanation: <goal explanation>
    goal: <goal>
    goal explanation: <goal explanation>
    goal: <goal>
    goal explanation: <goal explanation>
    Please generate three goals and explanations for the user. Attempt to make the goals unique and 
    explicity relevant to the user as a whole rather than specific to a single question."""
    
    prompt = "The user's answers to the questions are as follows: \n"
    for question in subset_labeled_questions:
        prompt += f"Question: {question['text']}\n"
        prompt += f"Labeled: {question['label']}\n"
        prompt += f"Primary Use: {question['primary_use']}\n"
        prompt += f"Secondary Use: {question['secondary_use']}\n"
        prompt += f"Tertiary Use: {question['tertiary_use']}\n"
        prompt += f"Answer: {user_answers[question['text']]}\nEND QUESTION\n\n"

    completion = client.chat.completions.create(
            messages=[
                {
                    "role":"system",
                    "content":gpt_system_message
                },
                {
                    "role":"user",
                    "content":prompt
                }
            ],
            model="gpt-3.5-turbo-1106"
        )
    
    # Extract the generated text from the response
    generated_text = completion.choices[0].message.content.strip('\n')

    # Print usage cost
    cost = calculate_usage_cost(
            "gpt-3.5-turbo",
            chat_completion.usage.completion_tokens,
            chat_completion.usage.prompt_tokens
        )

    print(f"Input Tokens: {chat_completion.usage.prompt_tokens}")
    print(f"Output Tokens: {chat_completion.usage.completion_tokens}")

    return generated_text, cost

# %%
goal_response, cost = gpt_goal_generator(user_answers['kbrait'], labeled_questions)
# Out:
# Input Tokens: 12
# Output Tokens: 5

# %%
print_cost(cost)
# Out:
# Total Cost: $0.00002200
# Number of Runs to Reach $1: 45455
# **************************************************

# %%
print(goal_response)
# Out:
# goal: Improve decision-making independence
# goal explanation: Based on your responses indicating the importance you place on the opinions of people close to you and your level of assertiveness, it would be beneficial to work on developing more independence in your decision-making process. Balancing the value of others' perspectives with asserting your own opinions and preferences when making decisions can lead to a more well-rounded approach.
#
# goal: Enhance emotional resilience and stability
# goal explanation: Given your high empathy level, tendency to worry, and fluctuations in mood, focusing on enhancing emotional resilience and stability can be beneficial. Strengthening coping mechanisms, stress management, and self-regulation could help in navigating fluctuations in mood and emotional responses, leading to a more balanced and stable emotional state.
#
# goal: Explore new learning experiences and social opportunities
# goal explanation: With your strong preference for social interaction when trying to understand new things, a vivid imagination, and enjoyment in thinking, it could be enriching to explore new learning experiences and social opportunities. Engaging in creative or cultural activities may align with your interests and provide avenues for personal growth and fulfillment.

# %%
def gpt_goal_plan_creation(user_answers, goal):

    gpt_system_message = """
                        Based on a goal, you are going to generate a plan of action for a specific user to follow.
                        This plan should have actionable steps that the user can take to achieve their goal.
                        The plan must be personalized to the user, to do this you will be provided the user's answers
                        to question's that provide insight into their personality and individuality. You will provide
                        the following output, in this exact format:

                        plan_title: <plan_title>
                        plan_description: <plan_description>
                        number_of_steps: <number_of_steps>
                        steps: <step_1>, <step_2>, <step_3>, ...

                        It is important that you follow this format exactly as the parsing function relies on it.
                        It is also very important that the steps are comma separated with no newlines in between steps.
                        There should only be newlines between the plan_title, plan_description, number_of_steps, and steps."""
    
    prompt = "The user's answers to the questions are as follows: \n"
    for question_text in user_answers.keys():
        prompt += f"Question: {question_text}\nAnswer: {user_answers[question_text]}\n"
    prompt += f"The user's goal: {goal}"
    
    completion = client.chat.completions.create(
            messages=[
                {
                    "role":"system",
                    "content":gpt_system_message
                },
                {
                    "role":"user",
                    "content":prompt
                }
            ],
            model="gpt-3.5-turbo"
        )
    
    # Extract the generated text from the response
    generated_text = completion.choices[0].message.content.strip('\n')

    # Print usage cost
    cost = calculate_usage_cost(
            "gpt-3.5-turbo",
            chat_completion.usage.completion_tokens,
            chat_completion.usage.prompt_tokens
        )

    return generated_text, cost

# %%
generated_plans = []
total_cost = 0

for i, goal in enumerate(goal_response.split('\n')):
    if goal.startswith('goal: '):
        single_goal = goal[6:]
        print(f"Generating plan for goal #{i+1}: {single_goal}")
        plan_response, cost = gpt_goal_plan_creation(user_answers['kbrait'], single_goal)
        generated_plans.append(plan_response)
        total_cost += cost

#plan_response, cost = gpt_goal_plan_creation(user_answers['kbrait'], goal_response)
# Out:
# Generating plan for goal #1: Improve decision-making independence
# Generating plan for goal #4: Enhance emotional resilience and stability
# Generating plan for goal #7: Explore new learning experiences and social opportunities

# %%
print_cost(cost)
# Out:
# Total Cost: $0.00002200
# Number of Runs to Reach $1: 45455
# **************************************************

# %%
for plan in generated_plans:
    print(plan)
    print("*"*50)
# Out:
# plan_title: Improving Decision-Making Independence
# plan_description: This plan will help you become more confident and independent in making decisions.
# number_of_steps: 4
# steps: Step 1: Identify your decision-making style.
# Step 2: Start with small decisions and gradually increase their complexity.
# Step 3: Seek advice and gather information, but make the final decision on your own.
# Step 4: Reflect on your decisions and learn from them for future growth.
# **************************************************
# plan_title: Enhancing Emotional Resilience and Stability
# plan_description: This plan is designed to help you enhance your emotional resilience and stability. By following these actionable steps, you can develop strategies to cope with stress, manage your emotions, and build emotional well-being.
# number_of_steps: 5
# steps: Step 1: Practice mindfulness and self-reflection daily to become more aware of your emotions and thoughts. This can involve meditation, journaling, or simply taking a few moments each day to pause and check in with yourself.
# Step 2: Establish a self-care routine that prioritizes activities that promote emotional well-being, such as exercise, spending time with loved ones, engaging in hobbies, and getting enough sleep.
# Step 3: Seek support from a therapist or counselor who can provide you with tools and strategies to enhance your emotional resilience. Therapy can help you explore and address underlying issues and develop healthy coping mechanisms.
# Step 4: Learn and practice stress management techniques, such as deep breathing exercises, progressive muscle relaxation, and positive self-talk. These techniques can help you better cope with stressful situations and reduce anxiety.
# Step 5: Build a strong support network of friends, family, and peers who can offer emotional support and understanding. Engage in meaningful social connections to foster a sense of belonging and strengthen your resilience.
# **************************************************
# plan_title: Exploring New Learning Experiences and Social Opportunities
# plan_description: This plan will help you discover new learning experiences and social opportunities to expand your horizons and connect with others.
# number_of_steps: 5
# steps:
# 1. Research local courses and workshops in subjects that interest you. Look for community centers, adult education programs, and online platforms that offer classes in areas like art, photography, cooking, or writing. Make a list of the top 3 courses you want to explore.
# 2. Join social clubs or groups related to your hobbies or interests. Check if there are local meetup groups, clubs, or organizations centered around activities you enjoy, such as hiking, climbing, or writing. Attend at least one meeting or event to connect with like-minded individuals.
# 3. Attend networking events or professional meetups in your field of study or industry. Look for events or conferences related to your career aspirations or academic interests. These events can provide valuable learning opportunities and help you forge connections with professionals in your field.
# 4. Volunteer your time with organizations or causes you care about. Find local volunteer opportunities or charities that align with your values and interests. This will not only allow you to contribute to a cause you're passionate about but also provide chances to meet new people and network in a meaningful way.
# 5. Join online learning communities or forums. Explore online platforms and forums dedicated to specific subjects or interests. Engage in discussions, ask questions, and share your knowledge or experiences. This will allow you to connect with others who share your passion for learning and provide a platform for continuous growth and exploration.
# **************************************************

# %% [markdown]
# #### Prompt #4: Generate Personality Traits for the User

# %%
## Getting subset of personality based questions
labeled_questions = load_data("labeled_questions.pkl")

def filter_questions(questions, answer_type):
    return [question for question in questions if question['answer_type'] == answer_type]

slider_type = "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)"
slider_questions = filter_questions(labeled_questions, slider_type)

print(f"Number of slider questions: {len(slider_questions)}")
print("Example:")
pretty_print(slider_questions[0])
# Out:
# Number of slider questions: 91
# Example:
# {
#     "text": "I care what people close to me think is best",
#     "answer_type": "an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)",
#     "label": "Relationships",
#     "label_explain": "This question is asking about the importance placed on the opinions of people who are close to the person answering the question. It relates to the dynamics and dynamics and influence in their relationships.",
#     "primary_use": "Assessing the importance placed on the opinions of people close to the user",
#     "secondary_use": "Understanding the user's decision-making process",
#     "tertiary_use": "Evaluating the user's level of independence in decision-making",
#     "primary_explain": "This question is asking about the extent to which the user values the opinions of people who are close to them. It provides insights into the importance the user gives to the perspectives and input of their loved ones when making decisions.",
#     "secondary_explain": "By understanding how much the user cares about the opinions of people close to them, we can gain insights into their decision-making process. If they strongly care about what others think, they may consider their opinions heavily in their decision-making. On the other hand, if they don't care much, they may have a more independent decision-making style.",
#     "tertiary_explain": "Additionally, the user's response to this question can provide an indication of their level of independence in decision-making. If they strongly agree, they may rely heavily on others for guidance and decision-making. If they strongly disagree, they may have a strong sense of autonomy and rely primarily on their own judgment."
# }

# %%
user_answers['kbrait']
# Out:
# {'I sympathize with others’ feelings.': '3, (YesYesYes)',
#  'I can be pushy.': '2, (YesYes)',
#  'I follow a schedule.': '-2, (NoNo)',
#  'I leave my belongings around.': '4, (YesYesYesYes)',
#  'I often act on the spur of the moment.': '5, (YesYesYesYesYes)',
#  'I am always prepared.': '2, (YesYes)',
#  'I often forget to put things back in their proper place.': '0, (Indifferent)',
#  'I have trouble wrapping up the final details of a project once the challenging parts are done.': '5, (YesYesYesYesYes)',
#  'My social life is important to me': '3, (YesYesYes)',
#  "I like to talk with others when I'm trying to understand new things.": '4, (YesYesYesYes)',
#  'I talk to a lot of different people at social gatherings.': '2, (YesYes)',
#  'I like being the center of attention.': '2, (YesYes)',
#  'I feel I can be my most authentic self.': '3, (YesYesYes)',
#  'I am relaxed most of the time.': '1, (Yes)',
#  'I get stressed out easily.': '-3, (NoNoNo)',
#  'I change my mood a lot.': '1, (Yes)',
#  'I see myself as someone who has high self-esteem.': '4, (YesYesYesYes)',
#  'I get irritated easily.': '1, (Yes)',
#  'I feel like I am in control of what happens to me.': '3, (YesYesYes)',
#  'I feel like powerful others have a lot of control over how my life will turn out.': '-4, (NoNoNoNo)',
#  'I worry about making mistakes.': '-3, (NoNoNo)',
#  'Criticism hurts me.': '4, (YesYesYesYes)',
#  'I feel worried when somebody is angry.': '-5, (NoNoNoNoNo)',
#  'I have very few fears compared to my friends.': '4, (YesYesYesYes)',
#  'In the past two weeks, I have been unable to stop or control worrying.': '1, (Yes)',
#  'In the past two weeks, I have had trouble relaxing.': '1, (Yes)',
#  'In the past two weeks, I have been easily annoyed or irritable.': '-1, (No)',
#  "I'm generally comfortable taking tests.": '4, (YesYesYesYes)',
#  'In the past two weeks, I have felt afraid something awful might happen.': '1, (Yes)',
#  'I get upset easily.': '-2, (NoNo)',
#  'I thrive in diverse environments': '-1, (No)',
#  'I have a vivid imagination.': '5, (YesYesYesYesYes)',
#  'I enjoy thinking about things.': '5, (YesYesYesYesYes)',
#  'I believe art is important.': '5, (YesYesYesYesYes)',
#  "It's important that I make my family proud of me.": '4, (YesYesYesYes)',
#  'I like a challenge.': '3, (YesYesYes)',
#  'I go out of my way to get things I want.': '-2, (NoNo)',
#  'In the past couple of weeks, I have been fulfilling my potential.': '-1, (No)',
#  'I am easily bored.': '2, (YesYes)',
#  'I can easily connect with family and friends if I want.': '4, (YesYesYesYes)',
#  'I learn well in a study group.': '1, (Yes)',
#  "I learn well when I'm alone.": '3, (YesYesYes)',
#  'In the past two weeks, I have felt so restless, it is hard to keep still.': '1, (Yes)',
#  'I feel like my basic needs are met.': '5, (YesYesYesYesYes)',
#  'I like to read.': '4, (YesYesYesYes)',
#  'What is your race?': 'White',
#  'From which socio-economic group would you consider your family to be?': 'High income',
#  'Are you currently in a relationship?': 'Sort of',
#  'I worry about my finances.': '4, (YesYesYesYes)',
#  'Are you currently in a romantic relationship?': 'Sort of',
#  'Do you have children?': 'No',
#  'Faith is important to me.': '0, (Indifferent)',
#  'I have a safe place to live.': '5, (YesYesYesYesYes)',
#  'What is your gender?': 'Male',
#  'How old are you?': '22',
#  'Are you currently employed?': 'Unemployed and currently looking for work',
#  'How many hours per week do you work?': '0',
#  'Which of these learning preferences work best for you?': 'Hands-On',
#  'Have you had any significant problems with mental health in the past?': '3, (YesYesYes)',
#  'Have you had any significant problems with depression in the past?': '2, (YesYes)',
#  'Have you had any significant problems with anxiety in the past?': '4, (YesYesYesYes)',
#  'If you have mental health issues CURRENTLY, please choose the category(ies) that your current mental health issue(s) fall into.': '',
#  'If you have had mental health issues IN THE PAST, please select any category(ies) that your past mental health issue(s) fell into.': '',
#  'What country were you born in?': 'United States',
#  'What activities do you do?': 'Climbing, Hiking, Writing',
#  "Is there anything else you'd like to tell us that may help us help you?": 'No',
#  'I worry about my physical health': '-1, (No)',
#  'My physical health is out of control': '-3, (NoNoNo)',
#  'The people I care about take good care of their physical health.': '0, (Indifferent)',
#  'Would you say you have a healthy diet?': '-2, (NoNo)',
#  'I have access to healthy food.': '3, (YesYesYes)',
#  'On average, how many hours do you sleep in each 24-hour period?': '8',
#  'If you have a physical disability, please select any category(ies) your physical disability falls into.': '',
#  'Is your diet healthy?': '-1, (No)',
#  'Do you feel confident in your resume?': '1, (Yes)',
#  'Do you feel confident writing a cover letter?': '4, (YesYesYesYes)',
#  'Do you know what job you should work toward?': '-2, (NoNo)',
#  "Do you know how to identify an organization that's a good fit for you?": '-1, (No)',
#  'I know what types of disability accommodations will support me.': '0, (Indifferent)',
#  'I know when to disclose my disability.': '0, (Indifferent)',
#  'I know how to create a disability accommodations plan with an employer.': '0, (Indifferent)',
#  "When I look at a job description, I often feel I'm not qualified.": '1, (Yes)',
#  'I am comfortable and competent using apps on smartphones.': '5, (YesYesYesYesYes)',
#  'I feel connected to the university': '2, (YesYes)',
#  'I am satisfied with my experience at university so far.': '1, (Yes)',
#  'I am satisfied with the support I have been offered by the university.': '0, (Indifferent)',
#  'How do you get to campus?': 'Bike',
#  'Would you be interested in accessing resources and learning more about any of the following?': 'None of the above',
#  'I feel overwhelmed by university life.': '-3, (NoNoNo)',
#  'I feel like I belong at university.': '1, (Yes)',
#  'What program are you currently enrolled in?': 'computer science',
#  'I care what people close to me think is best': '1, (Yes)',
#  'I find it difficult to remember appointments or obligations.': '-5, (NoNoNoNoNo)',
#  'I make careless mistakes while working on a boring or difficult project.': '2, (YesYes)',
#  'In the past two weeks, I have felt nervous, anxious or on edge.': '-2, (NoNo)',
#  'I like to take things apart to see how they work.': '4, (YesYesYesYes)',
#  "I'm always willing to try something new if I think it will be fun.": '5, (YesYesYesYesYes)',
#  'What are your living arrangements?': 'Living off campus with roommate(s)',
#  'Did either of your parents (including step parents/guardian) complete university?': 'Both did',
#  'Each day, how many hours do you typically spend (outside of class) studying or doing schoolwork?': '2hrs',
#  'I take steps to work on my mental health regularly.': '0, (Indifferent)',
#  'How intense are your exercise sessions?': 'Pretty intense',
#  'How often do you exercise?': '5-6 times per week',
#  'I get as much sleep as I need.': '0, (Indifferent)',
#  'Do you feel comfortable doing a job interview?': '3, (YesYesYes)',
#  'I feel overwhelmed by my need to find a job.': '1, (Yes)',
#  'I am comfortable and competent using a computer.': '5, (YesYesYesYesYes)',
#  'What year of university are you in?': '5th or higher'}

# %% [markdown]
# #### Personality Trait Generation

# %%
def gpt_personality_trait_generator(user_answers, subset_labeled_questions):
    
    gpt_system_message = """
                        You are going to generate a set of personality traits for a user based on their answers to questions.
                        You must generate five "Big5" personality traits for the user. The five traits are: Openness, Conscientiousness,
                        Extraversion, Agreeableness, and Neuroticism. And you must score these on a scale from 0 to 100.

                        Then you must generate a list of ten additional personality traits that you think the user may have.

                        Finally, you must generate a list of ten personality traits that you think the user does not have.

                        You must use the following template in your response:
                        big5_traits: <big5_traits>
                        personality_traits_user_has: <personality_traits>
                        personality_traits_user_does_not_have: <personality_traits>

                        The context of this generation is that an individual user has answered a set of questions and you are
                        generating personality traits that they may have based on their answers. These traits will be able to be
                        selected or deselected by a user looking to build their in app profile. 

                        Additionally, some of the questions may not be applicable to identifying personality traits, please
                        ignore these questions when generating personality traits based on the question text and answer.
                        """
    
    prompt = "The user's answers to the questions are as follows: \n"
    for question in user_answers:
        if question in [question['text'] for question in subset_labeled_questions]:
            prompt += f"Question: {question}\nAnswer: {user_answers[question]}\n"

    completion = client.chat.completions.create(
            messages=[
                {
                    "role":"system",
                    "content":gpt_system_message
                },
                {
                    "role":"user",
                    "content":prompt
                }
            ],
            model="gpt-3.5-turbo"
        )

    # Extract the generated text from the response
    generated_text = completion.choices[0].message.content.strip('\n')

    # Print usage cost
    cost = calculate_usage_cost(
            "gpt-3.5-turbo",
            chat_completion.usage.completion_tokens,
            chat_completion.usage.prompt_tokens
        )

    return generated_text, cost

# %%
personality_traits_response, cost = gpt_personality_trait_generator(user_answers['kbrait'], slider_questions)

# %%
print_cost(cost); print(personality_traits_response)
# Out:
# Total Cost: $0.00002200
# Number of Runs to Reach $1: 45455
# **************************************************
# big5_traits:
# - Openness: 85
# - Conscientiousness: 60
# - Extraversion: 70
# - Agreeableness: 75
# - Neuroticism: 40
#
# personality_traits_user_has:
# - Empathetic
# - Organized
# - Social
# - Adventurous
# - Confident
# - Imaginative
# - Artistic
# - Ambitious
# - Assertive
# - Resilient
#
# personality_traits_user_does_not_have:
# - Reserved
# - Introverted
# - Timid
# - Careless
# - Insecure
# - Unadventurous
# - Unimaginative
# - Uncaring
# - Indifferent
# - Impulsive

# %% [markdown]
# #### Prompt #5: Generate Habits (Good & Bad) for the User

# %%
def gpt_habits_generator(user_answers, subset_labeled_questions):
    pass

# %% [markdown]
# ---
# ## Third Pipeline: Generate Personalized Content Recommendations for User

# %% [markdown]
# #### Prompt #6: Generate Recommendations for the User

# %% [markdown]
# # Leftovers from the original attempts at this project

# %%
import json

def get_question_samples():
    data = [
        {
            # Open-ended question
            "id": 1,
            "text": "What program are you currently enrolled in?",
            "answer_type": "Text, open-ended question",
            "state": "Activated"
        },
        {
            # Open-ended question
            "id": 2,
            "text": "What country were you born in?",
            "answer_type": "Text, open-ended question",
            "state": "Activated"
        },
        {
            # Open-ended question
            "id": 3,
            "text": "Is there anything else you'd like to tell us that may help us help you?",
            "answer_type": "Text, open-ended question",
            "state": "Activated"
        },
        {
            # Financial_Worry - Answers: YesYesYesYesYes ... Indifferent ... NoNoNoNoNo
            # 11-pt slider: -5 = No, 0 = Indifferent, +5 = Yes
            "id": 4,
            "text": "I worry about my finances.",
            "answer_type": "A slider displaying text values",
            "state": "Activated"
        },
        {
            # Physical_Health - Answers: YesYesYesYesYes ... Indifferent ... NoNoNoNoNo
            # 11-pt slider: -5 = No, 0 = Indifferent, +5 = Yes
            "id": 5,
            "text": "I worry about my physical health.",
            "answer_type": "A slider displaying text values",
            "state": "Activated"
        },
        {
            # University_Overwhelmed - Answers: YesYesYesYesYes ... Indifferent ... NoNoNoNoNo
            # 11-pt slider: -5 = No, 0 = Indifferent, +5 = Yes
            "id": 6,
            "text": "I feel overwhelmed by university life.",
            "answer_type": "A slider displaying text values",
            "state": "Activated"
        },
        {
            # University_Satisfaction - Answers: YesYesYesYesYes ... Indifferent ... NoNoNoNoNo
            # 11-pt slider: -5 = No, 0 = Indifferent, +5 = Yes
            "id": 7,
            "text": "I am satisfied with the support I have been offered by the university.",
            "answer_type": "A slider displaying text values",
            "state": "Activated"
        },
        {
            # University_Demographic - Answers: 1st, 2nd, 3rd, 4th, 5th or higher, Graduate program
            "id": 8,
            "text": "What year of university are you in?",
            "answer_type": "Multiple choices",
            "state": "Activated"
        },
        {
            # Demographic - Answers: Both did, One did, I don't know, No
            "id": 9,
            "text": "Did either of your parents (including step parents/guardian) complete university?",
            "answer_type": "Multiple choices",
            "state": "Activated"
        },
        {
            # Big5 personality - Answers: High Conscientiousness (+5) vs. Low Conscientiousness (-5)
            "id": 10,
            "text": "I follow a schedule.",
            "answer_type": "A slider displaying text values",
            "state": "Activated"
        }
    ]
    return json.dumps(data)

def get_plan_samples():
    data = [
        {
            # Co-Pilot generated these steps, and I really like this, it's simply, straightforward, less wordy than the
            # actual in-app version and it's more actionable.
            "id": 838,
            "title": "How to turn acquaintances into real friends",
            "description": "Turning acquaintances into real friends can be a great way to build a support system and make your college experience more enjoyable. Here are some tips to help you turn acquaintances into real friends:",
            "state": "Approved",
            "steps": [
                {
                    "id": 1,
                    "text": "Invite them to an event you are going to",
                    "state": "Approved"
                },
                {
                    "id": 2,
                    "text": "Ask them to study with you",
                    "state": "Approved"
                },
                {
                    "id": 3,
                    "text": "Ask them to grab a meal with you",
                    "state": "Approved"
                },
                {
                    "id": 4,
                    "text": "Ask them to join you in an activity you enjoy",
                    "state": "Approved"
                },
                {
                    "id": 5,
                    "text": "Ask them to join you in an activity they enjoy",
                    "state": "Approved"
                },
                {
                    "id": 6,
                    "text": "Ask them to join you in an activity you both enjoy",
                    "state": "Approved"
                }
            ]
        },
    ]
    return json.dumps(data)

# %%
import pandas as pd

question_data = get_questionnaire_questions()

# Convert JSON string to Python object
questions = json.loads(question_data)

# Extract id, text, and answer_type fields for each question
data = []
for question in questions:
    if question['state'] == 'Activated':
        data.append({'id': question['id'], 'text': question['text'], 'answer_type': question['answer_type']})

# Create pandas dataframe from extracted data
df = pd.DataFrame(data)

# Print dataframe
print("The ids are wrong, the text and answer_type is copied from the Django admin panel for now.")
display(df)
# Out:
# The ids are wrong, the text and answer_type is copied from the Django admin panel for now.
#    id                                               text  \
# 0   1        What program are you currently enrolled in?
# 1   2                     What country were you born in?
# 2   3  Is there anything else you'd like to tell us t...
# 3   4                         I worry about my finances.
# 4   5                  I worry about my physical health.
# 5   6             I feel overwhelmed by university life.
# 6   7  I am satisfied with the support I have been of...
# 7   8                What year of university are you in?
# 8   9  Did either of your parents (including step par...
# 9  10                               I follow a schedule.
#
#                        answer_type
# 0        Text, open-ended question
# 1        Text, open-ended question
# 2        Text, open-ended question
# 3  A slider displaying text values
# 4  A slider displaying text values
# 5  A slider displaying text values
# 6  A slider displaying text values
# 7                 Multiple choices
# 8                 Multiple choices
# 9  A slider displaying text values

# %%
# THIS CELL CALLS THE OPENAI API TO GENERATE QUESTION GROUPS FOR EACH QUESTION
# DONT RUN UNLESS YOU WANT TO SPEND MONEY ON OPENAI API CALLS
# PRICE PER RUN OF CELL: ~$0.02 

import pandas as pd
import openai
from dotenv import load_dotenv
import os

load_dotenv(".env")
openai.api_key = os.environ["OPENAI_API_KEY"]

# Get the first question from the dataframe
question_texts = df['text'].tolist()

# This function generates a list of question_groups for a single question
# This function uses the "text-davinci-002" engine
def generate_question_groups_for_single_question(question_text):
    # Define the prompt
    prompt = f"Given the answer to the question '{question_text}', what can we infer about the user? \
        Please provide a list of potential 'question_groups' that define what the answer to this question tells us about the user. \
        Please aim to keep each question_group to a maximum of 3 to 5 words. \
        Separate each question_group with a semicolon delimiter for parsing purposes."
    
    # Call the OpenAI API to generate a response
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )
    
    # Extract the generated text from the response
    generated_text = response.choices[0].text.strip()
    
    # Split the generated text into a list of question groups
    question_groups = generated_text.split(';')
    
    # Strip whitespace from each question group
    question_groups = [group.strip() for group in question_groups]
    
    return question_groups

# Loop through each question text and generate a list of question groups for each one
question_group_dict = {}
for question_text in question_texts:
    question_groups = generate_question_groups_for_single_question(question_text)
    question_group_dict[question_text] = question_groups

# Create pandas dataframe from extracted data
df_question_groups = pd.DataFrame(question_group_dict.items(), columns=['Question Text', 'Question Groups'])

# Print dataframe
display(df_question_groups)
# Out:
#                                        Question Text  \
# 0        What program are you currently enrolled in?
# 1                     What country were you born in?
# 2  Is there anything else you'd like to tell us t...
# 3                         I worry about my finances.
# 4                  I worry about my physical health.
# 5             I feel overwhelmed by university life.
# 6  I am satisfied with the support I have been of...
# 7                What year of university are you in?
# 8  Did either of your parents (including step par...
# 9                               I follow a schedule.
#
#                                      Question Groups
# 0  [The user is currently enrolled in a program.\...
# 1  [The user was born in a specific country.\n\nT...
# 2  [The user may be experiencing anxiety, The use...
# 3  [The user is worried about their finances.\n\n...
# 4  [The user is concerned about their physical he...
# 5  [The user is experiencing negative emotions re...
# 6  [The user is satisfied with the support they h...
# 7  [The user is in their first year of university...
# 8           [The user's parents' level of education]
# 9  [The user is:\n\n-Disciplined\n-Punctual\n-Org...

# %%
# Display Question Groups

for index, row in df_question_groups.iterrows():
    print(f"Question Text: {row['Question Text']}")
    print(f"Question Groups: {row['Question Groups']}")
    print("\n")
# Out:
# Question Text: What program are you currently enrolled in?
# Question Groups: ["The user is currently enrolled in a program.\n\nThis question tells us about the user's current enrollment status."]
#
#
# Question Text: What country were you born in?
# Question Groups: ['The user was born in a specific country.\n\nThis tells us that the user is from a specific country.']
#
#
# Question Text: Is there anything else you'd like to tell us that may help us help you?
# Question Groups: ['The user may be experiencing anxiety', 'The user may be experiencing depression', 'The user may be experiencing stress']
#
#
# Question Text: I worry about my finances.
# Question Groups: ["The user is worried about their finances.\n\nThis question tells us that the user is worried about their finances. question_groups about the user's finances", "about the user's worries"]
#
#
# Question Text: I worry about my physical health.
# Question Groups: ['The user is concerned about their physical health.', 'The user is worried about their physical wellbeing.']
#
#
# Question Text: I feel overwhelmed by university life.
# Question Groups: ['The user is experiencing negative emotions related to university life.', 'The user is struggling to cope with university life.', 'The user feels that university life is too much for them.']
#
#
# Question Text: I am satisfied with the support I have been offered by the university.
# Question Groups: ['The user is satisfied with the support they have been offered by the university.\n\nThis question tells us that the user is:\n\nSatisfied with support offered by the university']
#
#
# Question Text: What year of university are you in?
# Question Groups: ["The user is in their first year of university.\n\nThis question tells us about the user's:\n-academic level", '-university status.']
#
#
# Question Text: Did either of your parents (including step parents/guardian) complete university?
# Question Groups: ["The user's parents' level of education"]
#
#
# Question Text: I follow a schedule.
# Question Groups: ['The user is:\n\n-Disciplined\n-Punctual\n-Organized']

# %%
## COST TO RUN: ~$0.03

# What if we give the prompt more context? i.e. answer_type

answer_types = df['answer_type'].tolist()

# This function generates a list of question_groups for a single question
def generate_question_groups_for_single_question_answer_type(question_text, answer_type):
    real_answer_type = ''
    if answer_type == 'Text, open-ended question':
        real_answer_type = 'open-ended, question_text is representative of how the user will answer'
    elif answer_type == 'A slider displaying text values':
        real_answer_type = 'an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)'
    elif answer_type == 'Multiple choices':
        real_answer_type = 'multiple choice, question_text is representative of the choices, typically provides demographic information'

    # Better prompt?
    prompt = f"Given the answer to the question '{question_text}', what can we infer about the user? \
        The answer type is '{real_answer_type}'. Answer type is important because it tells us how the user will answer the question. \
        Please provide at least three different question groups describing what this question relates to in terms of the user. \
        Please aim to keep each question_group to a maximum of 3 to 5 words. \
        Separate each question_group with a semicolon delimiter for parsing purposes."
    
    # Call the OpenAI API to generate a response
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )
    
    # Extract the generated text from the response
    generated_text = response.choices[0].text.strip()
    
    # Split the generated text into a list of question groups
    question_groups = generated_text.split(';')
    
    # Strip whitespace from each question group
    question_groups = [group.strip() for group in question_groups]
    
    return question_groups

# Loop through each question text and generate a list of question groups for each one
# Loop through each question text and answer type and generate a list of question groups for each one
question_group_dict = {}
for question_text, answer_type in zip(question_texts, answer_types):
    question_groups = generate_question_groups_for_single_question_answer_type(question_text, answer_type)
    question_group_dict[question_text] = question_groups

# Create pandas dataframe from extracted data
df_question_groups = pd.DataFrame(question_group_dict.items(), columns=['Question Text', 'Question Groups'])

# Print dataframe
display(df_question_groups)
# Out:
#                                        Question Text  \
# 0        What program are you currently enrolled in?
# 1                     What country were you born in?
# 2  Is there anything else you'd like to tell us t...
# 3                         I worry about my finances.
# 4                  I worry about my physical health.
# 5             I feel overwhelmed by university life.
# 6  I am satisfied with the support I have been of...
# 7                What year of university are you in?
# 8  Did either of your parents (including step par...
# 9                               I follow a schedule.
#
#                                      Question Groups
# 0  [current program, enrolled program, current en...
# 1  [The user was born in a country.\n\nThis quest...
# 2  [The user is willing to share information that...
# 3  [-How the user feels about their current finan...
# 4  [-Health and fitness, -Diet and nutrition, -Ex...
# 5  [- How is the user feeling?\n- How is the user...
# 6                [satisfaction, support, university]
# 7                 [Demographics, University, Years.]
# 8  [Family background, Education level, Parental ...
# 9  [The user is reliable, The user is punctual, T...

# %%
# Display Question Groups

for index, row in df_question_groups.iterrows():
    print(f"Question Text: {row['Question Text']}")
    print(f"Question Groups: {row['Question Groups']}")
    print("\n")
# Out:
# Question Text: What program are you currently enrolled in?
# Question Groups: ['current program', 'enrolled program', 'current enrollment']
#
#
# Question Text: What country were you born in?
# Question Groups: ["The user was born in a country.\n\nThis question relates to:\n-The user's country of origin\n-The user's place of birth\n-The user's nationality"]
#
#
# Question Text: Is there anything else you'd like to tell us that may help us help you?
# Question Groups: ["The user is willing to share information that may help the company help them.\n\nThis question relates to:\n\n-Customer service\n-The user's needs\n-The company's ability to help the user"]
#
#
# Question Text: I worry about my finances.
# Question Groups: ['-How the user feels about their current financial situation\n-How the user feels about their ability to save money\n-How the user feels about their ability to spend money wisely']
#
#
# Question Text: I worry about my physical health.
# Question Groups: ['-Health and fitness', '-Diet and nutrition', '-Exercise and physical activity.']
#
#
# Question Text: I feel overwhelmed by university life.
# Question Groups: ['- How is the user feeling?\n- How is the user coping with university life?\n- How does the user feel about university life?']
#
#
# Question Text: I am satisfied with the support I have been offered by the university.
# Question Groups: ['satisfaction', 'support', 'university']
#
#
# Question Text: What year of university are you in?
# Question Groups: ['Demographics', 'University', 'Years.']
#
#
# Question Text: Did either of your parents (including step parents/guardian) complete university?
# Question Groups: ['Family background', 'Education level', 'Parental occupation']
#
#
# Question Text: I follow a schedule.
# Question Groups: ['The user is reliable', 'The user is punctual', 'The user is organized.']

# %%
## EXPENSIVE CELL
## ALL THE SAME BUT WE USE GPT-3.5-TURBO INSTEAD OF TEXT-DAVINCI-002

# This function generates a list of question_groups for a single question
def generate_question_groups_for_single_question_answer_type(question_text, answer_type):
    real_answer_type = ''
    if answer_type == 'Text, open-ended question':
        real_answer_type = 'open-ended, question_text is representative of how the user will answer'
    elif answer_type == 'A slider displaying text values':
        real_answer_type = 'an 11-pt slider where 0-4 is negative (disagreement with statement), 5 is neutral, 6-10 is positive (agreement with statement)'
    elif answer_type == 'Multiple choices':
        real_answer_type = 'multiple choice, question_text is representative of the choices, typically provides demographic information'

    # Better prompt?
    prompt = f"Given the answer to the question '{question_text}', what can we infer about the user? \
        The answer type is '{real_answer_type}'. Answer type is important because it tells us how the user will answer the question. \
        Please provide at least three different question groups describing what this question relates to in terms of the user. \
        Please aim to keep each question_group to a maximum of 3 to 5 words. \
        Separate each question_group with a semicolon delimiter for parsing purposes."
    
    # Call the OpenAI API to generate a response
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role":"system",
                "content":"you are a question_group generator, you don't return excess information, just the question groups"
            },
            {
                "role":"user",
                "content":prompt
            }
        ]
    )
    
    # Extract the generated text from the response
    generated_text = response.choices[0].message.content.strip()

    # Print token usage
    prompt_tokens = response.usage.prompt_tokens
    completion_tokens = response.usage.completion_tokens
    total_tokens = response.usage.total_tokens

    print(f"Prompt tokens: {prompt_tokens}\n")
    print(f"Completion tokens: {completion_tokens}\n")
    print(f"Total tokens: {total_tokens}\n")
    
    # Split the generated text into a list of question groups
    question_groups = generated_text.split(';')
    
    # Strip whitespace from each question group
    question_groups = [group.strip() for group in question_groups]
    
    return question_groups

# Loop through each question text and generate a list of question groups for each one
# Loop through each question text and answer type and generate a list of question groups for each one
question_group_dict = {}
for question_text, answer_type in zip(question_texts, answer_types):
    question_groups = generate_question_groups_for_single_question_answer_type(question_text, answer_type)
    question_group_dict[question_text] = question_groups

# Create pandas dataframe from extracted data
df_question_groups = pd.DataFrame(question_group_dict.items(), columns=['Question Text', 'Question Groups'])

# Print dataframe
display(df_question_groups)
# Out:
# Prompt tokens: 142
#
# Completion tokens: 60
#
# Total tokens: 202
#
# Prompt tokens: 141
#
# Completion tokens: 9
#
# Total tokens: 150
#
# Prompt tokens: 151
#
# Completion tokens: 140
#
# Total tokens: 291
#
# Prompt tokens: 163
#
# Completion tokens: 27
#
# Total tokens: 190
#
# Prompt tokens: 164
#
# Completion tokens: 20
#
# Total tokens: 184
#
# Prompt tokens: 164
#
# Completion tokens: 168
#
# Total tokens: 332
#
# Prompt tokens: 171
#
# Completion tokens: 27
#
# Total tokens: 198
#
# Prompt tokens: 144
#
# Completion tokens: 30
#
# Total tokens: 174
#
# Prompt tokens: 152
#
# Completion tokens: 17
#
# Total tokens: 169
#
# Prompt tokens: 162
#
# Completion tokens: 23
#
# Total tokens: 185
#                                        Question Text  \
# 0        What program are you currently enrolled in?
# 1                     What country were you born in?
# 2  Is there anything else you'd like to tell us t...
# 3                         I worry about my finances.
# 4                  I worry about my physical health.
# 5             I feel overwhelmed by university life.
# 6  I am satisfied with the support I have been of...
# 7                What year of university are you in?
# 8  Did either of your parents (including step par...
# 9                               I follow a schedule.
#
#                                      Question Groups
# 0  [User Background:\n- Field of Study in Program...
# 1  [Nationality, place of birth, cultural backgro...
# 2  [1. User's additional needs: \n- What specific...
# 3  [Question Group 1: Financial Stability, Questi...
# 4  [Level of concern for physical health, Attitud...
# 5  [Question Group 1: Emotional Well-being\n- How...
# 6  [User satisfaction with university support reg...
# 7  [Question Group 1: User's educational level\nQ...
# 8  [Parent's educational background, User's famil...
# 9  [How important is sticking to a schedule?, Are...

# %%
# Display Question Groups

for index, row in df_question_groups.iterrows():
    print(f"Question Text: {row['Question Text']}")
    print(f"Question Groups: {row['Question Groups']}")
    print("\n")
# Out:
# Question Text: What program are you currently enrolled in?
# Question Groups: ['User Background:\n- Field of Study in Program\n- Level of Education\n- Institution Attending\n\nUser Interests:\n- Career Goals\n- Passions and Hobbies\n- Future Aspirations\n\nUser Experience:\n- Duration in Program\n- Satisfaction with Program\n- Challenges Faced in Program']
#
#
# Question Text: What country were you born in?
# Question Groups: ['Nationality', 'place of birth', 'cultural background']
#
#
# Question Text: Is there anything else you'd like to tell us that may help us help you?
# Question Groups: ["1. User's additional needs: \n- What specific assistance would you like to request?\n- Are there any specific resources or tools you require?\n- Could you provide more details on how we can help you?\n\n2. User's feedback or suggestions: \n- Is there anything you would like to suggest to enhance our service?\n- Do you have any feedback on our current offerings?\n- Are there any improvements you would like to see?\n\n3. User's personal circumstances: \n- Is there any personal information or situation that we should be aware of?\n- Are there any relevant details about your background that would be helpful for us to know?\n- Does anything else impact your situation that we should consider?"]
#
#
# Question Text: I worry about my finances.
# Question Groups: ['Question Group 1: Financial Stability', 'Question Group 2: Financial Concerns', 'Question Group 3: Money Management Skills']
#
#
# Question Text: I worry about my physical health.
# Question Groups: ['Level of concern for physical health', 'Attitude towards physical well-being', 'Emotional impact of physical health', '']
#
#
# Question Text: I feel overwhelmed by university life.
# Question Groups: ['Question Group 1: Emotional Well-being\n- How often do you feel overwhelmed by university life?\n- Are there specific aspects of university life that make you feel overwhelmed?\n- Have you sought any support or resources to cope with feeling overwhelmed by university life?\n\nQuestion Group 2: Time Management\n- How well do you currently manage your university workload?\n- Do you feel that you have enough time for other activities besides academics?\n- Are there any strategies or techniques you use to handle the feeling of being overwhelmed by university life?\n\nQuestion Group 3: Support System\n- Do you have a support system (family, friends, peers) to help you navigate university life?\n- Have you reached out to anyone for support when feeling overwhelmed by university life?\n- Are there specific individuals or resources that you find helpful in managing the feeling of overwhelm?']
#
#
# Question Text: I am satisfied with the support I have been offered by the university.
# Question Groups: ['User satisfaction with university support regarding academics', 'User satisfaction with university support regarding mental health', 'User satisfaction with university support regarding financial aid.']
#
#
# Question Text: What year of university are you in?
# Question Groups: ["Question Group 1: User's educational level\nQuestion Group 2: User's academic progress\nQuestion Group 3: User's experience and knowledge"]
#
#
# Question Text: Did either of your parents (including step parents/guardian) complete university?
# Question Groups: ["Parent's educational background", "User's family education level", "User's access to education."]
#
#
# Question Text: I follow a schedule.
# Question Groups: ['How important is sticking to a schedule?', 'Are you organized and punctual?', 'Do you thrive on routine?']
