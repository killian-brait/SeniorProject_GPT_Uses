# %% [markdown]
# ## Data Analysis for Trees.app
#
# This Notebook provides interactive data analysis of how the Trees application stores data about users and content used and created in the name of providing student's and people with the resources they need to be successful.

# %% [markdown]
# #### Understanding the Questionnaire
#
# Big Five Personality Traits:
#
# 1. Openness to Experience: High openness (curious) vs. Low openness (practical)
# 2. Conscientiousness: High (organized) vs. Low (spontaneous)
# 3. Extraversion: High vs. Low (Introversion)
# 4. Agreeableness: High (compassionate) vs. Low (competitive)
# 5. Neuroticism: High (emotionally sensitive) vs. Low (emotionally stable)
#
# If you view each of these traits on a binary scale, there are 2^5 = 32 "general" user
# profiles that these five traits represent:
#
# - practical, organized, introverted, competitive, stable
# - practical, organized, extroverted, competitive, stable
# - curious, organized, extroverted, compassionate, sensitive
# - curious, spontaneous, introverted, compassionate, sensitive
# - ...
#
# These traits aren't binary, and the slider questions provide 11 options for answers that
# fall on a scale between these extremes. On this 11 point scale we really have,
# 161,051 unique combinations.
#
# However, simplifying to 32 makes it easier to develop some baseline recommendations for
# each generalized personality. By creating an object for each of the 32 "user-types" we
# can (1) aim to predict the question answers that correlate with the "user-type".
#
# Additionally, we can process content to see which of the 32 user-types the content is
# most aligned with.
#
# Then we can pull from this baseline to generate recommendations for content that falls
# within a specific user type.

# %%
# Objects that can be made for user's based on data in the trees database schema

class UserAnswersClass:
    def __init__(self, user_id):
        self.user_id = user_id
        self.answers = {}  # Dictionary with question_id as key and answer details as value

    def add_answer(self, question_id, answer, reactions_ms, timestamp):
        self.answers[question_id] = {
            "answer": answer,
            "reactions_ms": reactions_ms,
            "timestamp": timestamp
        }


class QuestionContentClass:
    def __init__(self, question_id, question_text, order=None):
        self.question_id = question_id
        self.question_text = question_text
        self.order = order


class ContentUserInteractionClass:
    def __init__(self, content_id):
        self.content_id = content_id
        self.user_interactions = []
        self.user_ratings = []
        self.user_step_feedback = []

    def add_interaction(self, interaction):
        self.user_interactions.append(interaction)

    def add_rating(self, score):
        self.user_ratings.append(score)

    def add_step_feedback(self, feedback):
        self.user_step_feedback.append(feedback)

# The idea behind these three classes is that different use cases can be clearly defined within a 
# combination of three objects of these classes that can be passed into an openai prompt that returns
# a personalized output based on the inputted use case:

# Ex:
# extrovert_wanting_better_grades = new UserAnswersClass(); extrovert_wanting_better_grades.add_answer(questions relating to that)

# extrovert_questions = new QuestionContentClass();
# education_questions = new QuestionContentClass();
# habit_questions = new QuestionContentClass(); or, school_habits_qs = new QuestionContentClass()

# hypothesis_user_interactions = ContentUserInteractionClass(); # use human experience to hypothesize what these might be, i.e which
# plans this type of user would interact with more than others

# predicted_user_interactions = ContentUserInteractionClass(); # use GPT to create a class, see what the AI would predict

# actual_user_interactions = ContentUserInteractionClass(); # with enough data, the actual is able to be used to supervised training
# of a recommendation engine that predicts content interactions for a user with this use case

# %%
admin_email = 'admin@trees.app'
admin_password = 'amazatic@123'

api_path = 'http://api-dev.trees.app/'

# %%
import json

def pretty_print_response(response):
    """
    Takes a response object and prints its JSON content in a readable format.
    
    Args:
    - response: A response object, like one from the requests library.
    """
    # Load JSON content from response
    content = response.json()
    
    # Pretty print the content
    print(json.dumps(content, indent=4, sort_keys=False))

# Example usage:
# response = requests.get('https://api.example.com/data')
# pretty_print_response(response)

# %% [markdown]
# Get the Access & Refresh Tokens for API access with admin credentials.

# %%
import requests

url = api_path + "account/token/"

headers = {
    "accept": "application/json",
    "Content-Type": "application/json",
    "X-CSRFToken": "o9GfnnIqyB6rkOOMJYBvvLLtWWI1Y0bKxVbg5t32eUsTvccpDo2HZxV1B9qWXMNc"
}

data = {
    "email": admin_email,
    "password": admin_password  # Never hardcode or expose passwords like this.
}

response = requests.post(url, headers=headers, json=data)

# To see the response:
print(f'Status: {response.status_code}')
pretty_print_response(response)
refresh_token = response.json()["refresh"]
token = response.json()["access"]
print(f'\nAccess Token: {token}')
# Out:
# Status: 200
# {
#     "refresh": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTY5ODM0OTI1MCwianRpIjoiZjU2NTA5YWI1Njg5NGZjNGIzYWFlOWE5MzYxMzU3ODEiLCJ1c2VyX2lkIjoxLCJpc19zdXBlcnVzZXIiOnRydWUsImlzX29yZ2FuaXphdGlvbl9hZG1pbiI6ZmFsc2V9.GW1-vSKGsfHLtZEhwjO1kcxpbqDC8lrgEdAyoGF3gaA",
#     "access": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk3NTcxNjUwLCJqdGkiOiI3NDQ1YTM2NThiZDc0ZDk1YTZkYzk1Yjg3ZDVjNjEwNSIsInVzZXJfaWQiOjEsImlzX3N1cGVydXNlciI6dHJ1ZSwiaXNfb3JnYW5pemF0aW9uX2FkbWluIjpmYWxzZX0.lJHgjEcQ0f6kb3rfWdCSSKl1BNnhFmte6vhozhB4464"
# }
#
# Access Token: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk3NTcxNjUwLCJqdGkiOiI3NDQ1YTM2NThiZDc0ZDk1YTZkYzk1Yjg3ZDVjNjEwNSIsInVzZXJfaWQiOjEsImlzX3N1cGVydXNlciI6dHJ1ZSwiaXNfb3JnYW5pemF0aW9uX2FkbWluIjpmYWxzZX0.lJHgjEcQ0f6kb3rfWdCSSKl1BNnhFmte6vhozhB4464

# %%
url = api_path + "account/token/refresh/"

headers = {
    "accept": "application/json",
    "Content-Type": "application/json",
    "X-CSRFToken": "o9GfnnIqyB6rkOOMJYBvvLLtWWI1Y0bKxVbg5t32eUsTvccpDo2HZxV1B9qWXMNc"
}

data = {
    "refresh": refresh_token
}

response = requests.post(url, headers=headers, json=data)

# To see the response:
print(f'Status: {response.status_code}')
pretty_print_response(response)
token = response.json()["access"]
print(f'\nAccess Token: {token}')
# Out:
# Status: 200
# {
#     "access": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk3NTcxNjUyLCJqdGkiOiI4MTU0MTQ2YWY0MzA0MTU3ODUxZDA0ZDI4NjIwYTNmZCIsInVzZXJfaWQiOjEsImlzX3N1cGVydXNlciI6dHJ1ZSwiaXNfb3JnYW5pemF0aW9uX2FkbWluIjpmYWxzZX0.P4BqgVvosGTVvCsvfUsv06fXRPF0Qyub3cbfMM0DXlY"
# }
#
# Access Token: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk3NTcxNjUyLCJqdGkiOiI4MTU0MTQ2YWY0MzA0MTU3ODUxZDA0ZDI4NjIwYTNmZCIsInVzZXJfaWQiOjEsImlzX3N1cGVydXNlciI6dHJ1ZSwiaXNfb3JnYW5pemF0aW9uX2FkbWluIjpmYWxzZX0.P4BqgVvosGTVvCsvfUsv06fXRPF0Qyub3cbfMM0DXlY

# %% [markdown]
# Let's get the account information as it is returned by api.trees.app/account/profile

# %%
url = api_path + "account/profile/"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {token}",
    "X-CSRFToken": "o9GfnnIqyB6rkOOMJYBvvLLtWWI1Y0bKxVbg5t32eUsTvccpDo2HZxV1B9qWXMNc"
}

response = requests.get(url, headers=headers)

print(f'Status: {response.status_code}')
pretty_print_response(response)
# Out:
# Status: 200
# {
#     "username": "admin",
#     "email": "admin@trees.app",
#     "profile_image": null,
#     "name": "",
#     "description": "Wo",
#     "location": "wo",
#     "password": "pbkdf2_sha256$216000$aT9JTy9MWJ3O$5K/LExZnVJp1d9FVM00rcC3WLuubFmcRZqB7tvkA0hI=",
#     "email_verified": true,
#     "university": 2,
#     "id": 1,
#     "is_organization_admin": false
# }

# %% [markdown]
# Now let's get all the user's on the app from a super admin endpoint.

# %%
url = api_path + "super-admin/login/"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json",
    "X-CSRFToken": "o9GfnnIqyB6rkOOMJYBvvLLtWWI1Y0bKxVbg5t32eUsTvccpDo2HZxV1B9qWXMNc"
}

data = {
    "email": admin_email,
    "password": admin_password
}

response = requests.post(url, headers=headers, json=data)

status = response.status_code

print(f'Status: {status}')

if status != 200:
    print(f'Error: {response.text}')

pretty_print_response(response)

sap_token = response.json()['token']
sap_refresh_token = response.json()['refresh']
# Out:
# Status: 200
# {
#     "id": 1,
#     "password": "pbkdf2_sha256$216000$aT9JTy9MWJ3O$5K/LExZnVJp1d9FVM00rcC3WLuubFmcRZqB7tvkA0hI=",
#     "last_login": "2023-10-16T19:40:52.640733Z",
#     "is_superuser": true,
#     "username": "admin",
#     "first_name": "",
#     "last_name": "",
#     "is_staff": true,
#     "is_active": true,
#     "date_joined": "2021-01-18T16:34:26Z",
#     "profile_image": null,
#     "email": "admin@trees.app",
#     "is_organization_admin": false,
#     "email_verified": true,
#     "verify_email_sent": false,
#     "name": "",
#     "description": "Wo",
#     "location": "wo",
#     "university": 2,
#     "groups": [],
#     "user_permissions": [],
#     "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk3NTcxNjU4LCJqdGkiOiJhMDc1NDc1OWJiZDk0YWVlYWQyMzVhMTc4OTkyM2I5NiIsInVzZXJfaWQiOjF9.gJzuRg83eDTgqq9cTPNC3zVJ3-W5CexiBnJNdxvu2Fc",
#     "refresh": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTY5ODM0OTI1OCwianRpIjoiNTk4OTYyYTYwY2NhNDc0ODgwYjU2ZjFiNTE5ZjYwNTIiLCJ1c2VyX2lkIjoxfQ.CCsY0edFlfo4QrLUR5Ui-CQaskGHSJeSDV6dRkp1W1c"
# }

# %%
url = api_path + "super-admin/path/"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {sap_token}",
    "X-CSRFToken": "o9GfnnIqyB6rkOOMJYBvvLLtWWI1Y0bKxVbg5t32eUsTvccpDo2HZxV1B9qWXMNc"
}

response = requests.get(url, headers=headers)
status = response.status_code

print(f'Status: {status}')

if status != 200:
    print(f'Error: {response.text}')

paths = response
pretty_print_response(paths)
# Out:
# Status: 200
# {
#     "count": 565,
#     "next": 2,
#     "previous": null,
#     "results": [
#         {
#             "id": 10,
#             "details": [
#                 {
#                     "id": 17,
#                     "language": "en",
#                     "title": "Staying energized without caffeinee30",
#                     "description": "<p>I know, it seems like everyone drinks coffee. Maybe I'm an oddball, who knows. Personally, working at a desk can get monotonous and repetitive, even if I have many different tasks to work on. Since remote work began, I've been looking for a way to stay engaged with my projects minus the caffeine. Here is what has been working for me.</p>\n",
#                     "path": 10
#                 }
#             ],
#             "creator": null,
#             "university": {
#                 "id": 4,
#                 "name": "Not Available GH",
#                 "icon": "https://storage.googleapis.com/trees-userdata/university_icons/colorful-neon-computer-keyboards-wallpaper-preview.jpg",
#                 "primary_color": "#268253",
#                 "secondary_color": "#55a654",
#                 "tertiary_color": "#22ce24",
#                 "is_active": "activated",
#                 "domain": null
#             },
#             "average_rating": 4.333333333333333,
#             "users_count": 6,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": true,
#             "steps_count": 3,
#             "steps": [
#                 {
#                     "completed": true,
#                     "rating": 1,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 17,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Quick naps",
#                             "description": "<p>20 minutes or less, usually. For me, this is like a midday reset, and I come back wide awake and energized - don't sleep too long, or you will wake up groggy and potentially offset your sleep schedule.</p>\n",
#                             "path_step": 15
#                         }
#                     ],
#                     "avg_rating": 3.75,
#                     "id": 15,
#                     "order": 2,
#                     "path": 10
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 16,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Moving around",
#                             "description": "<p>Every hour or so I get up and move around a bit. You can take a quick walk around your house or neighborhood, do some push ups, or perform whatever exercises you prefer. A little activity gets the blood moving and re-engages me when I am running on fumes.</p>\n",
#                             "path_step": 14
#                         }
#                     ],
#                     "avg_rating": 4.25,
#                     "id": 14,
#                     "order": 1,
#                     "path": 10
#                 },
#                 {
#                     "completed": true,
#                     "rating": 4,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 15,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Cold water",
#                             "description": "<p>You probably already know this, but most people do not drink nearly enough water throughout the day. I try to always have a glass or bottle of ice water at my work station to sip on. The cold water can give you a jolt when you're feeling tired, and the health benefits are great.  You should be drinking between 0.5-1 oz of water for every pound you weigh.   <br><br>\"Mild dehydration (fluid loss of 1\u20133%) can impair energy levels, impair mood, and lead to major reductions in memory and brain performance.\" <br><br>- https://www.healthline.com/nutrition/7-health-benefits-of-water#1.-Helps-maximize-physical-performance</p>\n",
#                             "path_step": 13
#                         }
#                     ],
#                     "avg_rating": 4.75,
#                     "id": 13,
#                     "order": 0,
#                     "path": 10
#                 }
#             ],
#             "path_to_university": [
#                 {
#                     "id": 22,
#                     "name": "health awareness",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/1653302374023.JPEG",
#                     "primary_color": "#000000",
#                     "secondary_color": "#000000",
#                     "tertiary_color": "#000000",
#                     "is_active": "activated",
#                     "domain": "test.org"
#                 }
#             ],
#             "path_to_category": [
#                 {
#                     "id": 630,
#                     "category": "Health1",
#                     "order": null,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/image_2022_02_17T17_20_23_678Z.png",
#                     "color": "#c03030",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         20,
#                         19,
#                         21,
#                         8,
#                         9,
#                         22,
#                         5,
#                         4,
#                         3,
#                         1,
#                         16,
#                         17,
#                         18,
#                         15,
#                         2
#                     ]
#                 },
#                 {
#                     "id": 633,
#                     "category": "Health3",
#                     "order": null,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Trees1.jpg",
#                     "color": "#000000",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         20,
#                         19,
#                         21,
#                         8,
#                         9,
#                         22,
#                         5,
#                         4,
#                         3,
#                         1,
#                         16,
#                         17,
#                         18,
#                         15,
#                         2
#                     ]
#                 }
#             ],
#             "state": "deactivated",
#             "video_link": "test"
#         },
#         {
#             "id": 15,
#             "details": [
#                 {
#                     "id": 18,
#                     "language": "en",
#                     "title": "COVID testing in Halifax - I do not have symptoms",
#                     "description": "If you don't have symptoms of COVID 19 but would like to be tested, please follow the link in step 1. Anyone seeking a test can get one, especially those who have a lot of close social interaction through gatherings or many social contacts. If you do not fall into this category but would like to learn more about other COVID-19 testing options, you can learn more at the link below: \r\n\r\nhttp://www.nshealth.ca/coronavirustesting",
#                     "path": 15
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": null,
#             "users_count": 1,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": false,
#             "steps_count": 1,
#             "steps": [
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 18,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Follow these instructions",
#                             "description": "Walk-in COVID testing is available at Zatzman Sportsplex for people with no symptoms. It is mainly recommended for people who have a lot of close social interaction through gatherings or many social contacts. \r\n\r\nPeople who come for testing are asked to bring a health card if they have one. They will not need to self-isolate while they wait for test results. The testing method will be the standard PCR swab.\r\n\r\nAnyone is welcome if they:\r\n\u2022 have no symptoms\r\n\u2022 have not been at an exposure site identified by public health\r\n\u2022 are not a close contact of a person with COVID-19\r\n\r\nThis testing will be available:\r\n\u2022 11 a.m. to 9:30 p.m.\r\n\u2022 Zatzman Sportsplex, 110 Wyse Rd., Dartmouth.\r\n\r\nFind more testing locations in Nova Scotia at the link below.\r\nhttp://www.nshealth.ca/1635Asymptomatic",
#                             "path_step": 16
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 16,
#                     "order": 0,
#                     "path": 15
#                 }
#             ],
#             "path_to_university": [],
#             "path_to_category": [
#                 {
#                     "id": 622,
#                     "category": "health",
#                     "order": 0,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Screenshot_from_2022-02-15_17-17-09.png",
#                     "color": "#ff9999",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         8,
#                         9,
#                         5,
#                         4,
#                         3,
#                         1,
#                         15
#                     ]
#                 }
#             ],
#             "state": "moderation",
#             "video_link": null
#         },
#         {
#             "id": 16,
#             "details": [
#                 {
#                     "id": 19,
#                     "language": "en",
#                     "title": "COVID Testing in Halifax - I have symptoms",
#                     "description": "Nova Scotia offers online screening to determine if you or your friends & family need to get tested. You can use this service for one person at a time. If more than 1 person in your family needs a test for COVID-19, complete a separate assessment for each person. Based on your answers to COVID-19 screening questions, you may need to enter some personal information. Nova Scotia Health or IWK will use this information to schedule a COVID-19 test.\r\n\r\nSymptoms include:\r\nSevere difficulty breathing (e.g., struggling for each breath, speaking in single words)\r\nSevere chest pain\r\nHaving a very hard time waking up\r\nFeeling confused\r\nLost consciousness",
#                     "path": 16
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": null,
#             "users_count": 0,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": false,
#             "steps_count": 1,
#             "steps": [
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 19,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Visit this website and complete the self-assessment",
#                             "description": "Individuals having symptoms will be securely connected with Nova Scotia Health Authority\u2019s website for booking the COVID-19 test appointment.\r\n\r\nhttps://covid-self-assessment.novascotia.ca/en/TestingRequest/Questionnair",
#                             "path_step": 17
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 17,
#                     "order": 0,
#                     "path": 16
#                 }
#             ],
#             "path_to_university": [],
#             "path_to_category": [
#                 {
#                     "id": 622,
#                     "category": "health",
#                     "order": 0,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Screenshot_from_2022-02-15_17-17-09.png",
#                     "color": "#ff9999",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         8,
#                         9,
#                         5,
#                         4,
#                         3,
#                         1,
#                         15
#                     ]
#                 }
#             ],
#             "state": "moderation",
#             "video_link": null
#         },
#         {
#             "id": 18,
#             "details": [
#                 {
#                     "id": 21,
#                     "language": "en",
#                     "title": "Halifax COVID testing and information",
#                     "description": "Need to get tested, feeling symptoms or just want some information? This path contains links to the Nova Scotia Health Authority site, where you can find out how and where to get tested, what to do if you have been exposed, and learn about the province's current guidelines.",
#                     "path": 18
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": 5.0,
#             "users_count": 2,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": false,
#             "steps_count": 3,
#             "steps": [
#                 {
#                     "completed": true,
#                     "rating": 1,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 21,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "See current restrictions and guidelines",
#                             "description": "https://novascotia.ca/coronavirus/",
#                             "path_step": 19
#                         }
#                     ],
#                     "avg_rating": 1.0,
#                     "id": 19,
#                     "order": 0,
#                     "path": 18
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 22,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Testing information and scheduling",
#                             "description": "http://www.nshealth.ca/coronavirustesting",
#                             "path_step": 20
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 20,
#                     "order": 1,
#                     "path": 18
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 23,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Additional information and resources",
#                             "description": "http://www.nshealth.ca/coronavirus-home/coronavirus-covid-19-resources",
#                             "path_step": 21
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 21,
#                     "order": 2,
#                     "path": 18
#                 }
#             ],
#             "path_to_university": [],
#             "path_to_category": [
#                 {
#                     "id": 622,
#                     "category": "health",
#                     "order": 0,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Screenshot_from_2022-02-15_17-17-09.png",
#                     "color": "#ff9999",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         8,
#                         9,
#                         5,
#                         4,
#                         3,
#                         1,
#                         15
#                     ]
#                 }
#             ],
#             "state": "moderation",
#             "video_link": null
#         },
#         {
#             "id": 19,
#             "details": [
#                 {
#                     "id": 22,
#                     "language": "en",
#                     "title": "Use Access-A-Bus for those with disabilities",
#                     "description": "Access-A-Bus is a shared ride, door-to-door, transit service for persons who are unable to use the conventional transit system due to physical or cognitive disabilities. Learn more about Access-A-Bus to provide individuals with transportation to medical appointments and to allow you to participate in social, personal, and recreational activities.",
#                     "path": 19
#                 }
#             ],
#             "creator": null,
#             "university": {
#                 "id": 3,
#                 "name": "Access Ability",
#                 "icon": "https://storage.googleapis.com/trees-userdata/university_icons/pexels-pixabay-60597.jpg",
#                 "primary_color": "#e0de8f",
#                 "secondary_color": "#f0f344",
#                 "tertiary_color": "#98a300",
#                 "is_active": "activated",
#                 "domain": null
#             },
#             "average_rating": null,
#             "users_count": 2,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": false,
#             "steps_count": 2,
#             "steps": [
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 24,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "How to register for Access-A-Bus",
#                             "description": "You must apply for access-a-bus before becoming a passenger on this service. To register, complete the Access-A-Bus application form, linked below. \r\n\r\nhttps://www.halifax.ca/sites/default/files/documents/transportation/halifax-transit/Access-A-Bus%20-%20Application%20Form%20-%20Sept18.pdf\r\n\r\nComplete the application and return via mail to:\r\n\r\nHalifax Transit\r\nAttn: Access-A-Bus Registration\r\n200 Ilsley Avenue\r\nDartmouth, Nova Scotia, B3b 1V1\r\n\r\nContact 902-490-6999 or contact us at (311.halifax.ca) with questions.",
#                             "path_step": 22
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 22,
#                     "order": 0,
#                     "path": 19
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 25,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "How to request Access-A-Bus service",
#                             "description": "Call 902-490-6999 to request Access-A-Bus service.\r\n\r\nYou can book a trip 24 hours prior to the intended travel date, or anytime within a 7-day period if you have standing medical appointments and/or weekly errands. For regular appointments or errands, you need to book two trips\u2014one to and one from the location.\r\n\r\nYou can book up to five trips per day and you will receive an immediate confirmation of the booking.\r\n\r\nAccess-A-Bus allows mobility scooters. Maximum size restrictions are:\r\n\r\n- Three-wheeled scooters: 40\u201d X 21.125\u201d\r\n- Four-wheeled scooters: 40.25\u201d X 21.25\u201d\r\n- All mobility scooters will require four anchors or tie down points to secure the device on the bus.",
#                             "path_step": 23
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 23,
#                     "order": 1,
#                     "path": 19
#                 }
#             ],
#             "path_to_university": [],
#             "path_to_category": [
#                 {
#                     "id": 14,
#                     "category": "social2",
#                     "order": 0,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Screenshot_from_2022-02-03_15-10-44.png",
#                     "color": "#ffa8a8",
#                     "is_active": false,
#                     "categoryToUniversity": [
#                         8,
#                         9,
#                         5,
#                         4,
#                         3,
#                         1,
#                         15
#                     ]
#                 }
#             ],
#             "state": "approved",
#             "video_link": null
#         },
#         {
#             "id": 20,
#             "details": [
#                 {
#                     "id": 23,
#                     "language": "en",
#                     "title": "Bicycling in Halifax",
#                     "description": "<p>The Halifax Cycling Handbook is a handy pocket-sized guide containing all you need to know about getting around Halifax by bike, from what kind of bike to buy to winter riding tips. You can access an online copy at the link below, or visit Long Alley Bicycles, Giant Bikes, Halifax Cycles, Cyclesmith, or a Halifax Library branch for a free printed copy!<br><br>https://drive.google.com/file/d/1g1pm1r0kunagQkEnj5FkMufN3sxPggGh/view?usp=sharing</p>\n",
#                     "path": 20
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": 3.5,
#             "users_count": 2,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": true,
#             "steps_count": 3,
#             "steps": [
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 28,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Get involved with the Halifax cycling coalition",
#                             "description": "<p>The Halifax Cycling Coalition works hard to make cycling attractive, safe, and convenient in Halifax. Becoming a member is a great way to show your support and have a say in the work they do. View their website here: https://cyclehalifax.ca/</p>\n",
#                             "path_step": 26
#                         }
#                     ],
#                     "avg_rating": 3.5,
#                     "id": 26,
#                     "order": 2,
#                     "path": 20
#                 },
#                 {
#                     "completed": true,
#                     "rating": 4,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 26,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Read the handbook",
#                             "description": "<p>Use the link below to access the Halifax cycling handbook: <br><br>https://drive.google.com/file/d/1g1pm1r0kunagQkEnj5FkMufN3sxPggGh/view</p>\n",
#                             "path_step": 24
#                         }
#                     ],
#                     "avg_rating": 3.5,
#                     "id": 24,
#                     "order": 0,
#                     "path": 20
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 27,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Save the Halifax bicycle map",
#                             "description": "<p>https://www.arcgis.com/apps/webappviewer/index.html?id=a0c8d2ddd531482b837b2cf95b354e6b</p>\n",
#                             "path_step": 25
#                         }
#                     ],
#                     "avg_rating": 3.0,
#                     "id": 25,
#                     "order": 1,
#                     "path": 20
#                 }
#             ],
#             "path_to_university": [
#                 {
#                     "id": 2,
#                     "name": "Cal Poly",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Calpolylogosports.png",
#                     "primary_color": "#8b3232",
#                     "secondary_color": "#a34343",
#                     "tertiary_color": "#a81f1f",
#                     "is_active": "activated",
#                     "domain": null
#                 }
#             ],
#             "path_to_category": [
#                 {
#                     "id": 630,
#                     "category": "Health1",
#                     "order": null,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/image_2022_02_17T17_20_23_678Z.png",
#                     "color": "#c03030",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         20,
#                         19,
#                         21,
#                         8,
#                         9,
#                         22,
#                         5,
#                         4,
#                         3,
#                         1,
#                         16,
#                         17,
#                         18,
#                         15,
#                         2
#                     ]
#                 },
#                 {
#                     "id": 638,
#                     "category": "Testing Category",
#                     "order": null,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/download.jpg",
#                     "color": "#000000",
#                     "is_active": true,
#                     "categoryToUniversity": [
#                         2
#                     ]
#                 }
#             ],
#             "state": "approved",
#             "video_link": ""
#         },
#         {
#             "id": 21,
#             "details": [
#                 {
#                     "id": 24,
#                     "language": "en",
#                     "title": "Call a taxi in Halifax",
#                     "description": "Halifax does not currently offer Uber ride services. Taxis and limousines are readily available in downtown Halifax, Dartmouth, and most neighborhoods and communities throughout the Halifax region.",
#                     "path": 21
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": 5.0,
#             "users_count": 4,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": true,
#             "steps_count": 2,
#             "steps": [
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": true,
#                     "step_details": [
#                         {
#                             "id": 29,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "See available services",
#                             "description": "Yellow Cab 24/7 service - \r\n902-420-000\r\nOnline booking - https://yellowcabhalifax.ca/\r\nInstant booking through their mobile app\r\n\r\nCasino taxi\r\n902-429-6666\r\nInstant booking through their mobile app\r\n\r\nBobs Taxi\r\n902-463-2222\r\nInstant booking through their mobile app\r\nOnline booking - https://bobstaxi.ca/",
#                             "path_step": 27
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 27,
#                     "order": 0,
#                     "path": 21
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 30,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Select a service, download their app, and start riding",
#                             "description": "Yellow Cab\r\nAppStore: https://itunes.apple.com/ca/app/yellow-cab-halifax/id803451180?mt=8\r\nGoogle Play: https://play.google.com/store/apps/details?id=com.appypie.yelloocab\r\n\r\nCasino Taxi\r\nAppStore: https://itunes.apple.com/ca/app/casino-taxi/id628069338?mt=8\r\nGoogle Play: https://play.google.com/store/apps/details?id=com.apcurium.MK.CasinoTaxi&hl=en\r\n\r\nBob\u2019s Taxi\r\nAppStore: https://itunes.apple.com/gd/app/bobs-taxi/id1450309078\r\nGoogle Play: https://play.google.com/store/apps/details?id=com.mti.bobstaxihalifax",
#                             "path_step": 28
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 28,
#                     "order": 1,
#                     "path": 21
#                 }
#             ],
#             "path_to_university": [
#                 {
#                     "id": 2,
#                     "name": "Cal Poly",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Calpolylogosports.png",
#                     "primary_color": "#8b3232",
#                     "secondary_color": "#a34343",
#                     "tertiary_color": "#a81f1f",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 3,
#                     "name": "Access Ability",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/pexels-pixabay-60597.jpg",
#                     "primary_color": "#e0de8f",
#                     "secondary_color": "#f0f344",
#                     "tertiary_color": "#98a300",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 4,
#                     "name": "Not Available GH",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/colorful-neon-computer-keyboards-wallpaper-preview.jpg",
#                     "primary_color": "#268253",
#                     "secondary_color": "#55a654",
#                     "tertiary_color": "#22ce24",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 5,
#                     "name": "Not Available GS",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/WhatsApp_Image_2021-11-10_at_6.13.02_PM.jpeg",
#                     "primary_color": "#6d2c2c",
#                     "secondary_color": "#ec7474",
#                     "tertiary_color": "#cb1a1a",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 8,
#                     "name": "Transitions",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/WhatsApp_Image_2021-12-06_at_3.36.18_PM.jpeg",
#                     "primary_color": "#cb4848",
#                     "secondary_color": "#0e0707",
#                     "tertiary_color": "#000000",
#                     "is_active": "activated",
#                     "domain": "testtransition.in"
#                 },
#                 {
#                     "id": 9,
#                     "name": "Test Org",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/bg-login.png",
#                     "primary_color": "#711919",
#                     "secondary_color": "#158e76",
#                     "tertiary_color": "#ffe5e5",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 17,
#                     "name": "DAV New",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/bg-login.png",
#                     "primary_color": "#000000",
#                     "secondary_color": "#000000",
#                     "tertiary_color": "#000000",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 15,
#                     "name": "Wonderland",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/images.jpg",
#                     "primary_color": "#ad1a1a",
#                     "secondary_color": "#1536b7",
#                     "tertiary_color": "#646464",
#                     "is_active": "activated",
#                     "domain": null
#                 }
#             ],
#             "path_to_category": [],
#             "state": "approved",
#             "video_link": null
#         },
#         {
#             "id": 22,
#             "details": [
#                 {
#                     "id": 25,
#                     "language": "en",
#                     "title": "Halifax Transit: How to ride",
#                     "description": "As part of Halifax Transit's ongoing commitment to a create an accessible and inclusive transit system for all, we welcome you to enjoy How to Ride: A Guide to Using Halifax Transit, a collection of easy-to-follow guides and videos in multiple languages that cover information about how to:\r\n\u2022    Access bus route maps and schedules\r\n\u2022    Plan a trip on buses and ferries\r\n\u2022    Pay fares and transfer\r\n\u2022    Ride safely\r\n\r\nThis series of guides and videos have been designed to help familiarize new users with how to access the Halifax Transit network.\r\n\r\nIf you prefer, the Halifax transit website has a series of translated videos in Arabic, Swahili, Somali, Nepali, and Tigrinya. Written guides are available in Arabic, Farsi, French, Korean, Simplified Chinese, and Spanish. Both can be found here: \r\n\r\nhttps://www.halifax.ca/transportation/halifax-transit/passenger-information/how-ride-transit",
#                     "path": 22
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": null,
#             "users_count": 0,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": true,
#             "steps_count": 3,
#             "steps": [
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 31,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "How to pay",
#                             "description": "View the payment tutorial in English using the youtube link below:\r\n\r\nhttps://www.youtube.com/watch?v=szs-mziFgWQ&feature=youtu.be",
#                             "path_step": 29
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 29,
#                     "order": 0,
#                     "path": 22
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 33,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "How to plan your trip",
#                             "description": "https://www.youtube.com/watch?v=C87KMkWjv_w&feature=youtu.be",
#                             "path_step": 31
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 31,
#                     "order": 2,
#                     "path": 22
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 32,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "How to ride the bus or ferry",
#                             "description": "https://www.youtube.com/watch?v=W6F5tZalL7Y&feature=youtu.be",
#                             "path_step": 30
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 30,
#                     "order": 1,
#                     "path": 22
#                 }
#             ],
#             "path_to_university": [
#                 {
#                     "id": 2,
#                     "name": "Cal Poly",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Calpolylogosports.png",
#                     "primary_color": "#8b3232",
#                     "secondary_color": "#a34343",
#                     "tertiary_color": "#a81f1f",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 3,
#                     "name": "Access Ability",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/pexels-pixabay-60597.jpg",
#                     "primary_color": "#e0de8f",
#                     "secondary_color": "#f0f344",
#                     "tertiary_color": "#98a300",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 4,
#                     "name": "Not Available GH",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/colorful-neon-computer-keyboards-wallpaper-preview.jpg",
#                     "primary_color": "#268253",
#                     "secondary_color": "#55a654",
#                     "tertiary_color": "#22ce24",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 5,
#                     "name": "Not Available GS",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/WhatsApp_Image_2021-11-10_at_6.13.02_PM.jpeg",
#                     "primary_color": "#6d2c2c",
#                     "secondary_color": "#ec7474",
#                     "tertiary_color": "#cb1a1a",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 8,
#                     "name": "Transitions",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/WhatsApp_Image_2021-12-06_at_3.36.18_PM.jpeg",
#                     "primary_color": "#cb4848",
#                     "secondary_color": "#0e0707",
#                     "tertiary_color": "#000000",
#                     "is_active": "activated",
#                     "domain": "testtransition.in"
#                 },
#                 {
#                     "id": 9,
#                     "name": "Test Org",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/bg-login.png",
#                     "primary_color": "#711919",
#                     "secondary_color": "#158e76",
#                     "tertiary_color": "#ffe5e5",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 17,
#                     "name": "DAV New",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/bg-login.png",
#                     "primary_color": "#000000",
#                     "secondary_color": "#000000",
#                     "tertiary_color": "#000000",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 15,
#                     "name": "Wonderland",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/images.jpg",
#                     "primary_color": "#ad1a1a",
#                     "secondary_color": "#1536b7",
#                     "tertiary_color": "#646464",
#                     "is_active": "activated",
#                     "domain": null
#                 }
#             ],
#             "path_to_category": [],
#             "state": "approved",
#             "video_link": null
#         },
#         {
#             "id": 23,
#             "details": [
#                 {
#                     "id": 26,
#                     "language": "en",
#                     "title": "Dispute a parking ticket in Halifax",
#                     "description": "You can appeal a parking ticket within 14 days of it being issued by requesting an administrative review for a number of violations. The parking charges listed below are the most common violations you can appeal.  The following types of parking tickets can be disputed, but you\u2019ll need to provide supporting documentation (as indicated) to prove.",
#                     "path": 23
#                 }
#             ],
#             "creator": null,
#             "university": null,
#             "average_rating": null,
#             "users_count": 0,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": true,
#             "steps_count": 2,
#             "steps": [
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 34,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Know which tickets can be appealed.",
#                             "description": "For a list of disputable parking violations and ways they can be appealed visit the link below to the Halifax municipal website: \r\n\r\nhttps://www.halifax.ca/transportation/parking/disputing-a-parking-ticket",
#                             "path_step": 32
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 32,
#                     "order": 0,
#                     "path": 23
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 35,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Dispute tickets by mail, email, or in person.",
#                             "description": "If you wish to appeal a parking ticket, you can do so online, via email, by mail, or in person. Allow 7\u201314 business days for Parking Enforcement to advise you of the outcome. Remember you must submit your appeal within 14 days of it being issued. \r\n\r\nTo dispute a ticket online use the self service portal:\r\nhttps://hrm.aimsparking.com/tickets/?cmd=view_all_appeal_eligible\r\n\r\nTo dispute by mail print and submit a ticket review form located here: \r\nhttps://www.halifax.ca/sites/default/files/documents/transportation/parking/TicketReviewForm-Fillable%20REVISED%202020.pdf. \r\n\r\nSend to Parking Enforcement, PO Box 1749, Halifax NS, B3J 3A5        \r\n\r\nTo dispute in person print the ticket review form: \r\nhttps://www.halifax.ca/sites/default/files/documents/transportation/parking/TicketReviewForm-Fillable%20REVISED%202020.pdf. \r\n\r\nDrop the form off at any municipal customer service center.",
#                             "path_step": 33
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 33,
#                     "order": 1,
#                     "path": 23
#                 }
#             ],
#             "path_to_university": [
#                 {
#                     "id": 2,
#                     "name": "Cal Poly",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/Calpolylogosports.png",
#                     "primary_color": "#8b3232",
#                     "secondary_color": "#a34343",
#                     "tertiary_color": "#a81f1f",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 3,
#                     "name": "Access Ability",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/pexels-pixabay-60597.jpg",
#                     "primary_color": "#e0de8f",
#                     "secondary_color": "#f0f344",
#                     "tertiary_color": "#98a300",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 4,
#                     "name": "Not Available GH",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/colorful-neon-computer-keyboards-wallpaper-preview.jpg",
#                     "primary_color": "#268253",
#                     "secondary_color": "#55a654",
#                     "tertiary_color": "#22ce24",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 5,
#                     "name": "Not Available GS",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/WhatsApp_Image_2021-11-10_at_6.13.02_PM.jpeg",
#                     "primary_color": "#6d2c2c",
#                     "secondary_color": "#ec7474",
#                     "tertiary_color": "#cb1a1a",
#                     "is_active": "activated",
#                     "domain": null
#                 },
#                 {
#                     "id": 8,
#                     "name": "Transitions",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/WhatsApp_Image_2021-12-06_at_3.36.18_PM.jpeg",
#                     "primary_color": "#cb4848",
#                     "secondary_color": "#0e0707",
#                     "tertiary_color": "#000000",
#                     "is_active": "activated",
#                     "domain": "testtransition.in"
#                 },
#                 {
#                     "id": 9,
#                     "name": "Test Org",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/bg-login.png",
# ...
#                             "path_step": 564
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 564,
#                     "order": 2,
#                     "path": 175
#                 }
#             ],
#             "path_to_university": [],
#             "path_to_category": [],
#             "state": "moderation",
#             "video_link": null
#         },
#         {
#             "id": 176,
#             "details": [
#                 {
#                     "id": 171,
#                     "language": "en",
#                     "title": "Eight financial tips for young adults",
#                     "description": "Here are eight personal finance tips from Investopedia for young adults.\r\n\r\nLink to full article: https://www.investopedia.com/articles/younginvestors/08/eight-tips.asp",
#                     "path": 176
#                 }
#             ],
#             "creator": {
#                 "id": 1,
#                 "username": "admin",
#                 "email": "admin@trees.app",
#                 "profile_image": null,
#                 "name": "",
#                 "is_organization_admin": false,
#                 "is_superuser": true
#             },
#             "university": {
#                 "id": 4,
#                 "name": "Not Available GH",
#                 "icon": "https://storage.googleapis.com/trees-userdata/university_icons/colorful-neon-computer-keyboards-wallpaper-preview.jpg",
#                 "primary_color": "#268253",
#                 "secondary_color": "#55a654",
#                 "tertiary_color": "#22ce24",
#                 "is_active": "activated",
#                 "domain": null
#             },
#             "average_rating": null,
#             "users_count": 3,
#             "tags": "",
#             "hidden_tags": "",
#             "is_specific": true,
#             "steps_count": 9,
#             "steps": [
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 547,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Guard your health",
#                             "description": "If meeting monthly health insurance premiums seems impossible, what will you do if you have to go to the emergency room, where a single visit for a minor injury like a broken bone can cost thousands of dollars? If you're uninsured, don't wait another day to apply for health insurance; it's easier than you think to wind up in a car accident or trip down the stairs.\r\n\r\nYou can save money by getting quotes from different insurance providers to find the lowest rates. Also, by taking daily steps now to keep yourself healthy\u2014like eating fruits and vegetables, maintaining a healthy weight, exercising, not smoking, not consuming alcohol in excess, and even driving defensively\u2014you could benefit down the road when you aren't paying exorbitant medical bills.",
#                             "path_step": 573
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 573,
#                     "order": 6,
#                     "path": 176
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 543,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Know where your money goes",
#                             "description": "Once you've gone through a few personal finance books, you'll realize how important it is to make sure your expenses aren't exceeding your income. The best way to do this is by budgeting.\r\n\r\nOnce you see how the cost of your morning java adds up over the course of a month, you'll realize that making small, manageable changes in your everyday expenses can have just as big an impact on your financial situation as getting a raise.\r\n\r\nIn addition, keeping your recurring monthly expenses as low as possible will also save you big bucks over time. If you don't waste your money on a posh apartment now, you might be able to afford a nice condo or a house before you know it.",
#                             "path_step": 569
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 569,
#                     "order": 2,
#                     "path": 176
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 541,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Learn self-control",
#                             "description": "If you're lucky, your parents taught you this skill when you were a kid. If not, keep in mind that the sooner you learn the fine art of delaying gratification, the sooner you'll find it easy to keep your finances in order. Although you can effortlessly buy an item on credit the minute you want it, it's better to wait until you've actually saved up the money for the purchase. Do you really want to pay interest on a pair of jeans or a box of cereal? \r\n\r\nIf you make a habit of putting all your purchases on credit cards, regardless of whether you can pay your bill in full at the end of the month, you might still be paying for those items in 10 years.\r\n\r\nIf you want to keep your credit cards for the convenience factor or the rewards they offer, make sure to always pay your balance in full when the bill arrives, and don't carry more cards than you can keep track of. This financial tip is crucial for creating a healthy credit history.",
#                             "path_step": 567
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 567,
#                     "order": 0,
#                     "path": 176
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 549,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "The bottom line",
#                             "description": "Remember, you don't need any fancy degrees or special background to become an expert at managing your finances. If you use these eight financial rules and financial tips for your life, you can be as personally prosperous as someone with a hard-won MBA in finance.",
#                             "path_step": 575
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 575,
#                     "order": 8,
#                     "path": 176
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 548,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Protect your wealth",
#                             "description": "If you want to make sure that all of your hard-earned money doesn't vanish, you'll need to take steps to protect it. If you rent, get renters insurance to protect the contents of your place from events like burglary or fire. Disability income insurance protects your greatest asset\u2014the ability to earn an income\u2014by providing you with a steady income if you ever become unable to work for an extended period of time due to illness or injury.\r\n\r\nIf you want help managing your money, find a fee-only financial planner to provide unbiased advice that's in your best interest, rather than a commission-based financial advisor, who earns money when you sign up with the investments their company backs.",
#                             "path_step": 574
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 574,
#                     "order": 7,
#                     "path": 176
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 545,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Start saving for retirement",
#                             "description": "Just as your parents sent you off to kindergarten with their hopes to prepare you for success in a world that seemed eons away, you need to prepare for your retirement well in advance. Because of the way compound interest works, the sooner you start saving, the less principal you'll need to invest to end up with the amount you require to retire and the sooner you'll be able to call working an \"option\" rather than a \"necessity.\"\r\n\r\nCompany-sponsored retirement plans are a particularly great choice because you get to put in pre-tax dollars, companies will often match part of your contribution (which is like free money), and the contribution limits tend to be high (much more than you can contribute to an individual retirement plan).",
#                             "path_step": 571
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 571,
#                     "order": 4,
#                     "path": 176
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 542,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Control your financial future",
#                             "description": "If you don't learn to manage your own money, other people will find ways to (mis)manage it for you. Some of these people may be ill-intentioned, like unscrupulous commission-based financial planners. Others may be well-meaning, but may not know what they're doing, like Grandma Betty who really wants you to own your own house even though you can only afford one by taking on a treacherous adjustable-rate mortgage.\r\n\r\nInstead of relying on others for advice, take charge and read a few basic books on personal finance. Once you're armed with personal finance knowledge, don't let anyone catch you off guard\u2014whether it's a significant other who slowly siphons your bank account or friends who want you to go out and blow tons of money with them every weekend.",
#                             "path_step": 568
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 568,
#                     "order": 1,
#                     "path": 176
#                 },
#                 {
#                     "completed": true,
#                     "rating": 5,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 546,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Get a grip on taxes",
#                             "description": "It's important to understand how income taxes work even before you get your first paycheck. When a company offers you a starting salary, you need to know how to calculate whether that salary will give you enough money after taxes to meet your financial goals and obligations.\r\n\r\nFortunately, there are plenty of online calculators that have taken the dirty work out of determining your own payroll taxes, such as PaycheckCity.com. These calculators will show you your gross pay, how much goes to taxes, and how much you'll be left with, which is also known as net, or take-home pay.",
#                             "path_step": 572
#                         }
#                     ],
#                     "avg_rating": 5.0,
#                     "id": 572,
#                     "order": 5,
#                     "path": 176
#                 },
#                 {
#                     "completed": false,
#                     "rating": null,
#                     "is_skipped": false,
#                     "step_details": [
#                         {
#                             "id": 544,
#                             "media": [],
#                             "language": "en",
#                             "step_name": "Start an emergency fund",
#                             "description": "One of personal finance's oft-repeated mantras is \"pay yourself first.\" No matter how much you owe in student loans or credit card debt, and no matter how low your salary may seem, it's wise to find some amount\u2014any amount\u2014of money in your budget to sock away in an emergency fund every month.\r\n\r\nHaving money in savings to use for emergencies can really keep you out of trouble financially and help you sleep better at night. Also, if you get into the habit of saving money and treating it as a non-negotiable monthly \"expense,\" pretty soon you'll have more than just emergency money saved up: You'll have retirement money, vacation money, and even money for a down payment on a home.\r\n\r\nDon't just hide this money under your mattress; put it in a high-interest online savings account, a certificate of deposit (CD), or a money market account. Otherwise, inflation will erode the value of your savings.",
#                             "path_step": 570
#                         }
#                     ],
#                     "avg_rating": null,
#                     "id": 570,
#                     "order": 3,
#                     "path": 176
#                 }
#             ],
#             "path_to_university": [
#                 {
#                     "id": 1,
#                     "name": "SMU",
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/smu_icon.png",
#                     "primary_color": "#85b7d5",
#                     "secondary_color": "#4a7eb5",
#                     "tertiary_color": "#0c345f",
#                     "is_active": "activated",
#                     "domain": null
#                 }
#             ],
#             "path_to_category": [
#                 {
#                     "id": 534,
#                     "category": "money",
#                     "order": 1,
#                     "icon": "https://storage.googleapis.com/trees-userdata/university_icons/icon-upload.png",
#                     "color": "#46c4dd",
#                     "is_active": false,
#                     "categoryToUniversity": [
#                         8,
#                         9,
#                         5,
#                         4,
#                         3,
#                         1,
#                         15
#                     ]
#                 }
#             ],
#             "state": "approved",
#             "video_link": null
#         }
#     ]
# }

# %%
import pandas as pd

# Assuming the JSON data you provided is stored in a variable called data
data = paths.json()

rows = []

# Extracting required data from each JSON object
for result in data['results']:
    plan_id = result['id']
    title = result['details'][0]['title']
    description = result['details'][0]['description']
    users_count = result['users_count']
    average_rating = result['average_rating']
    state = result['state']
    
    for step in result['steps']:
        step_name = step['step_details'][0]['step_name']
        step_description = step['step_details'][0]['description']

        # Constructing a dictionary and appending to the rows list
        rows.append({
            'plan_id': plan_id,
            'title': title,
            'description': description,
            'step_name': step_name,
            'step_description': step_description,
            'users_count': users_count,
            'average_rating': average_rating,
            'state': state
        })

# Creating a pandas DataFrame from the list of dictionaries
df = pd.DataFrame(rows)

display(df)
# Out:
#      plan_id                                              title  \
# 0         10                 Staying energized without caffeine
# 1         10                 Staying energized without caffeine
# 2         10                 Staying energized without caffeine
# 3         15  COVID testing in Halifax - I do not have symptoms
# 4         16         COVID Testing in Halifax - I have symptoms
# ..       ...                                                ...
# 423      181               Four mental and physical health tips
# 424      182               Research using Patrick Power Library
# 425      182               Research using Patrick Power Library
# 426      182               Research using Patrick Power Library
# 427      182               Research using Patrick Power Library
#
#                                            description  \
# 0    I know, it seems like everyone drinks coffee. ...
# 1    I know, it seems like everyone drinks coffee. ...
# 2    I know, it seems like everyone drinks coffee. ...
# 3    If you don't have symptoms of COVID 19 but wou...
# 4    Nova Scotia offers online screening to determi...
# ..                                                 ...
# 423  Students attending college right now are facin...
# 424  <p>The library provides tons of valuable schol...
# 425  <p>The library provides tons of valuable schol...
# 426  <p>The library provides tons of valuable schol...
# 427  <p>The library provides tons of valuable schol...
#
#                                              step_name  \
# 0                                           Quick naps
# 1                                        Moving around
# 2                                           Cold water
# 3                            Follow these instructions
# 4    Visit this website and complete the self-asses...
# ..                                                 ...
# 423                    Look for opportunities to serve
# 424                                      Using Novanet
# 425                            Research subject guides
# 426                                    Asking for help
# 427                   Using subject-specific databases
#
#                                       step_description  users_count  \
# 0    20 minutes or less, usually. For me, this is l...           34
# 1    Every hour or so I get up and move around a bi...           34
# 2    You probably already know this, but most peopl...           34
# 3    Walk-in COVID testing is available at Zatzman ...            5
# 4    Individuals having symptoms will be securely c...            1
# ..                                                 ...          ...
# 423  So many people have so many needs right now. T...            3
# 424  <p>When using Novanet, or another database, fo...            2
# 425  <p>For example, when you navigate to the accou...            2
# 426  <p>Email a librarian for assistance with your ...            2
# 427  <p>SMU also has access to over one hundred spe...            2
#
#      average_rating        state
# 0               4.0     approved
# 1               4.0     approved
# 2               4.0     approved
# 3               4.5  deactivated
# 4               NaN  deactivated
# ..              ...          ...
# 423             5.0     approved
# 424             NaN   moderation
# 425             NaN   moderation
# 426             NaN   moderation
# 427             NaN   moderation
#
# [428 rows x 8 columns]

# %%
import pandas as pd

# Assuming the JSON data you provided is stored in a variable called data
data = paths.json()

rows = []

# Extracting required data from each JSON object
for result in data['results']:
    row = {}
    plan_id = result['id']
    title = result['details'][0]['title']
    description = result['details'][0]['description']
    users_count = result['users_count']
    average_rating = result['average_rating']
    state = result['state']

    row['plan_id'] = plan_id
    row['title'] = title
    row['description'] = description
    row['users_count'] = users_count
    row['average_rating'] = average_rating
    row['state'] = state
    
    # Populating each step's data into the row dictionary
    for idx, step in enumerate(result['steps']):
        step_name_key = f'step_name_{idx+1}'
        step_description_key = f'step_description_{idx+1}'
        row[step_name_key] = step['step_details'][0]['step_name']
        row[step_description_key] = step['step_details'][0]['description']

    rows.append(row)

# Creating a pandas DataFrame from the list of dictionaries
df = pd.DataFrame(rows)

display(df)
# Out:
#     plan_id                                              title  \
# 0        10                 Staying energized without caffeine
# 1        15  COVID testing in Halifax - I do not have symptoms
# 2        16         COVID Testing in Halifax - I have symptoms
# 3        18              Halifax COVID testing and information
# 4        19       Use Access-A-Bus for those with disabilities
# ..      ...                                                ...
# 95      177  How to maintain mental and physical health in ...
# 96      178                              Tips to improve sleep
# 97      179                        Tips for getting good sleep
# 98      181               Four mental and physical health tips
# 99      182               Research using Patrick Power Library
#
#                                           description  users_count  \
# 0   I know, it seems like everyone drinks coffee. ...           34
# 1   If you don't have symptoms of COVID 19 but wou...            5
# 2   Nova Scotia offers online screening to determi...            1
# 3   Need to get tested, feeling symptoms or just w...            4
# 4   <p>Access-A-Bus is a shared ride, door-to-door...            2
# ..                                                ...          ...
# 95  This plan details tips for first-year students...            4
# 96  Most college students struggle with healthy sl...            6
# 97  Check out these quick tips to help improve the...           13
# 98  Students attending college right now are facin...            3
# 99  <p>The library provides tons of valuable schol...            2
#
#     average_rating        state  \
# 0         4.000000     approved
# 1         4.500000  deactivated
# 2              NaN  deactivated
# 3         5.000000  deactivated
# 4              NaN   moderation
# ..             ...          ...
# 95        4.500000   moderation
# 96        5.000000     approved
# 97        4.666667     approved
# 98        5.000000     approved
# 99             NaN   moderation
#
#                                           step_name_1  \
# 0                                          Quick naps
# 1                           Follow these instructions
# 2   Visit this website and complete the self-asses...
# 3             See current restrictions and guidelines
# 4                    How to register for Access-A-Bus
# ..                                                ...
# 95                              Prioritize your sleep
# 96                         Avoid caffeine and alcohol
# 97        Avoid alcohol and nicotine close to bedtime
# 98                               Get moving regularly
# 99                                      Using Novanet
#
#                                    step_description_1  \
# 0   20 minutes or less, usually. For me, this is l...
# 1   Walk-in COVID testing is available at Zatzman ...
# 2   Individuals having symptoms will be securely c...
# 3                  https://novascotia.ca/coronavirus/
# 4   <p>You must apply for access-a-bus before beco...
# ..                                                ...
# 95  Seemingly every day I advise students to sleep...
# 96  For many students, caffeine interferes with th...
# 97  Substances interfere with deep sleep.\r\nAltho...
# 98  With remote learning and physical distancing, ...
# 99  <p>When using Novanet, or another database, fo...
#
#                                   step_name_2  \
# 0                               Moving around
# 1                                         NaN
# 2                                         NaN
# 3          Testing information and scheduling
# 4         How to request Access-A-Bus service
# ..                                        ...
# 95                                   Exercise
# 96        Fine-tune your sleeping environment
# 97  Eat 2-3 hours before your planned bedtime
# 98                             Stay connected
# 99                    Research subject guides
#
#                                    step_description_2  ...  \
# 0   Every hour or so I get up and move around a bi...  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3           http://www.nshealth.ca/coronavirustesting  ...
# 4   <p>Call 902-490-6999 to request Access-A-Bus s...  ...
# ..                                                ...  ...
# 95  Exercise can help with your sleep and also imp...  ...
# 96  Noise, light, excessive heat or cold, drafts, ...  ...
# 97  Avoid heartburn and other discomforts.\r\n\r\n...  ...
# 98  Isolation can be difficult for everyone—now is...  ...
# 99  <p>For example, when you navigate to the accou...  ...
#
#                                          step_name_8  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 95                                               NaN
# 96  Exercise regularly, three times or more per week
# 97                         Avoid caffeine before bed
# 98                                               NaN
# 99                                               NaN
#
#                                    step_description_8  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  Studies confirm that people in good physical c...
# 97  Caffeine is a stimulant.\r\n\r\nThis means it ...
# 98                                                NaN
# 99                                                NaN
#
#                                           step_name_9  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  Lie down to go to sleep only when you feel sleepy
# 98                                                NaN
# 99                                                NaN
#
#                                    step_description_9  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  Don't ruin your sleep-friendly environment.\r\...
# 98                                                NaN
# 99                                                NaN
#
#                            step_name_10  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 95                                  NaN
# 96                                  NaN
# 97  Create a sleep-friendly environment
# 98                                  NaN
# 99                                  NaN
#
#                                   step_description_10 step_name_11  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# ..                                                ...          ...
# 95                                                NaN          NaN
# 96                                                NaN          NaN
# 97  A sleep-friendly environment is dark, cool, qu...          NaN
# 98                                                NaN          NaN
# 99                                                NaN          NaN
#
#    step_description_11 step_name_12 step_description_12
# 0                  NaN          NaN                 NaN
# 1                  NaN          NaN                 NaN
# 2                  NaN          NaN                 NaN
# 3                  NaN          NaN                 NaN
# 4                  NaN          NaN                 NaN
# ..                 ...          ...                 ...
# 95                 NaN          NaN                 NaN
# 96                 NaN          NaN                 NaN
# 97                 NaN          NaN                 NaN
# 98                 NaN          NaN                 NaN
# 99                 NaN          NaN                 NaN
#
# [100 rows x 30 columns]

# %% [markdown]
# ### Current Problems:
#
# 1. Not getting all the plans from the /super-admin/path/ endpoint, which I need because then I can easily start to work on building dataframes to do clustering with the paths.
# 2. Unable to get users from /super-admin/users/ at all, this is a **major** blocker currently.
#
# ### Next Steps:
# 1. Try different queries in the request to get ALL the plans from the /super-admin/path/ endpoint.
# 2. Write a series of functions to loop through each user and get their question answers, then store them in a dataframe.
# 3. Write a series of functions to loop through each user and get their path interaction data, then store them in a dataframe.

# %%
## Running this cell seems to cause an error in the server, specifically in trees_api/web_admin/views/auth.py line 24 where it reutnrs the Response(serializer.data):
# 19. def login(self, request):
# 20.     """ used to login the admin users """
# 21.     serializer = self.get_serializer_class()(data=request.data)
# 22.     serializer.is_valid(raise_exception=True)
# 23.     serializer.save()
# 24.     return Response(serializer.data)



url = "https://api.trees.app/super-admin/users/"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {sap_token}",
    "X-CSRFToken": "o9GfnnIqyB6rkOOMJYBvvLLtWWI1Y0bKxVbg5t32eUsTvccpDo2HZxV1B9qWXMNc"
}

response = requests.get(url, headers=headers)
status = response.status_code

print(f'Status: {status}')

if status != 200:
    print(f'Error: {response.text}')

pretty_print_response(response)
# Out:
# Status: 502
# Error: <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/requests/models.py:972, in Response.json(self, **kwargs)
#     971 try:
# --> 972     return complexjson.loads(self.text, **kwargs)
#     973 except JSONDecodeError as e:
#     974     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     975     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/miniconda3/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/miniconda3/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[47], line 27
#      24 if status != 200:
#      25     print(f'Error: {response.text}')
# ---> 27 pretty_print_response(response)
#
# Cell In[31], line 11, in pretty_print_response(response)
#       4 """
#       5 Takes a response object and prints its JSON content in a readable format.
#       6
#       7 Args:
#       8 - response: A response object, like one from the requests library.
#       9 """
#      10 # Load JSON content from response
# ---> 11 content = response.json()
#      13 # Pretty print the content
#      14 print(json.dumps(content, indent=4, sort_keys=False))
#
# File ~/miniconda3/lib/python3.9/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     972     return complexjson.loads(self.text, **kwargs)
#     973 except JSONDecodeError as e:
#     974     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     975     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 976     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
class User:
    def __init__(self, username, email):
        self.username = username
        self.email = email
        self.answers = {}  # Dictionary to store question-answer pairs
        self.plan_ratings = {}  # Dictionary to store plan-rating pairs
    
    def add_answer(self, question, answer):
        self.answers[question] = answer
    
    def add_rating(self, plan_name, rating):
        self.plan_ratings[plan_name] = rating
    
    def to_dict(self):
        return {
            'username': self.username,
            'email': self.email,
            'answers': self.answers,
            'plan_ratings': self.plan_ratings
        }

# %%
users = {}
users[response.json()["id"]] = User(response.json()["username"], response.json()["email"])
