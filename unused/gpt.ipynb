# %% [markdown]
# ## Using GPT For Trees.app

# %%
import openai
from dotenv import load_dotenv
import os

# %%
load_dotenv(".env")
openai.api_key = os.environ["OPENAI_API_KEY"]
print(f"API KEY: {openai.api_key}")
# Out:
# API KEY: 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

# %%
function_purpose = "This is the purpose of the function"

openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"user", "content": "write a python function to {function_purpose}"},
        {"role":"assistant", "content": "Here's an example response..."},
        {"role":"system", "content":"You are a {purpose} analyzer. Given {...} you {...}."}
    ]
)

# %%
def huntingtons_biologist_response(link_pred_results, cluster_results):

    purpose_msg = "You are a subject matter expert in the field of Biology. \
            You specialize in research on Huntingtons and are working with a team \
            of computer scientists to develop a novel method for understanding the \
            complexities of Huntingtons disease. Given data generated by using \
            algorithms to find links and clusters within a knowledge graph, you will \
            return some knowledge that the links/clusters give you, as a biology subject \
            matter expert, into what might be occurring to generate this data."

    openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages = [
            {"role":"system", "content":purpose_msg},
            {"role":"user", "content":""},
            {"role":"chat"}
        ]
    )

# %%
def create_function(purpose):
    # call GPT to return a code snippet that creates a function with the purpose

def create_test_for_function(function, test_cases, ):
    # call GPT to create tests

def
